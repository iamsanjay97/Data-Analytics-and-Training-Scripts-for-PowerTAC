# %%
import os
import sys
import numpy as np

# %%
# parameters for the experiments

number_of_samples = 100000

# %%
def auction_clearing(bids_list, asks_list):
    
    clearing_price_list = list()
    clearing_quantity_list = list()
    
    for i in range(number_of_samples):
        
        bids = list(bids_list[:, i])
        asks = list(asks_list[:, i])
        
        clearing_price = -1.0;
        clearing_quantity = 0;

        asks.sort()
        bids.sort(reverse=True)
        
        # print("asks", asks)
        # print("bids", bids)

        if(bids[1] >= asks[1]):
            clearing_price = (bids[1] + asks[1]) / 2;
            clearing_quantity = 2;
        elif(bids[0] >= asks[0]):
            clearing_price = (bids[0] + asks[0]) / 2;        
            clearing_quantity = 1;
        
        clearing_price_list.append(clearing_price)
        clearing_quantity_list.append(clearing_quantity)
        
        # print("cp", clearing_price)
        # print("cq", clearing_quantity)
    
    return clearing_price_list, clearing_quantity_list

# %%
def seller_strategy(alpha_s1, alpha_s2):
        
    theta_s = np.random.uniform(0, 1, number_of_samples)
    # print("theta_s", theta_s)
    
    s1 = alpha_s1 * theta_s
    s2 = alpha_s2 * theta_s
    
    s = np.vstack((s1, s2))
    # print("asks_list", s)
    
    return theta_s, s

# %%
def buyer_strategy(alpha_b1, alpha_b2):
    
    theta_b = np.random.uniform(0, 1, number_of_samples)
    # print("theta_b", theta_b)
        
    b1 = alpha_b1 * theta_b
    b2 = alpha_b2 * theta_b
    
    b = np.vstack((b1, b2))
    # print("bids_list", b)
    
    return theta_b, b

# %%
def seller_expected_utility(theta_s_list, clearing_price_list, clering_quantity_list):
    
    utility = 0.0;
    
    for theta_s, cp, cq in zip(theta_s_list, clearing_price_list, clering_quantity_list):
        # print("Utilty", ((cq * (cp - theta_s)) - ((2 - cq)*theta_s)))
        utility += ((cq * (cp - theta_s)) - ((2 - cq)*theta_s))
        
    return (utility/number_of_samples)

# %%
def buyer_expected_utility(theta_b_list, clearing_price_list, clering_quantity_list):
    
    utility = 0.0;
    
    for theta_b, cp, cq in zip(theta_b_list, clearing_price_list, clering_quantity_list):
        # print("Utility", ((cq * (theta_b - cp)) - ((2 - cq)*theta_b)))
        utility += ((cq * (theta_b - cp)) - ((2 - cq)*theta_b))
        
    return (utility/number_of_samples)

# %% [markdown]
# ### Theoretical equilibrium when buyer/seller places same bids/asks both the items

# %%
alpha_b1 = 0.666667;
alpha_b2 = 0.666667;

alpha_s1 = 1.0;
alpha_s2 = 1.0;

theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
theta_s, S = seller_strategy(alpha_s1, alpha_s2)

cp_list, cq_list = auction_clearing(B, S)

U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
U_s = seller_expected_utility(theta_s, cp_list, cq_list)

print("Buyer's expected utilty: ", U_b)
print("Seller's expected utilty: ", U_s)

best_Ub1 = U_b
best_Us1 = U_s
# Out:
# Buyer's expected utilty:  -0.33452169727393727
# Seller's expected utilty:  -0.7801692491853587

# %%
# Checking if some randomly selected scaler values can yeild better utility

for i in range(1000):
    
    alpha_b1 = np.random.uniform(0.5, 1, 1)[0];
    alpha_b2 = alpha_b1;

    alpha_s1 = np.random.uniform(1, 1.5, 1)[0];
    alpha_s2 = alpha_s1;

    theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
    theta_s, S = seller_strategy(alpha_s1, alpha_s2)

    cp_list, cq_list = auction_clearing(B, S)

    U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
    U_s = seller_expected_utility(theta_s, cp_list, cq_list)

    if((U_b >= best_Ub1) and (U_s >= best_Us1)):
        print(alpha_b1, alpha_s1)
        print("Buyer's expected utilty: ", U_b)
        print("Seller's expected utilty: ", U_s)
        print("\n")
# Out:
# 0.7551338562655536 1.0125502740711736
# Buyer's expected utilty:  -0.2864155827427483
# Seller's expected utilty:  -0.7181719692838721
#
#
# 0.878018259478613 1.1073511627871686
# Buyer's expected utilty:  -0.2875469974982409
# Seller's expected utilty:  -0.6502037923173665
#
#
# 0.7959259229964069 1.0311138077027124
# Buyer's expected utilty:  -0.28032283446156486
# Seller's expected utilty:  -0.6958455243424188
#
#
# 0.981295800069528 1.1059473929371497
# Buyer's expected utilty:  -0.24958524685467134
# Seller's expected utilty:  -0.5612745653497815
#
#
# 0.9918670890220105 1.2469860620097206
# Buyer's expected utilty:  -0.33366149631209135
# Seller's expected utilty:  -0.6088203208668775
#
#
# 0.9660432171738729 1.1150432211305263
# Buyer's expected utilty:  -0.26212028757457667
# Seller's expected utilty:  -0.5800635200681734
#
#
# 0.7071076690672425 1.030723083190741
# Buyer's expected utilty:  -0.3276156461733347
# Seller's expected utilty:  -0.7566341701071027
#
#
# 0.951530900779189 1.1001770717772792
# Buyer's expected utilty:  -0.25950594093182633
# Seller's expected utilty:  -0.5884271773183457
#
#
# 0.9535215156857231 1.1441289361794404
# Buyer's expected utilty:  -0.2876863064020963
# Seller's expected utilty:  -0.6058690758407569
#
#
# 0.9974906466479814 1.0164543475010035
# Buyer's expected utilty:  -0.1813700593658781
# Seller's expected utilty:  -0.5099467500996986
#
#
# 0.9399036784096098 1.0106771097042502
# Buyer's expected utilty:  -0.19788953286209132
# Seller's expected utilty:  -0.5618986830719302
#
#
# 0.8637552173908721 1.0851277290453043
# Buyer's expected utilty:  -0.2797633421056954
# Seller's expected utilty:  -0.6527672520371772
#
#
# 0.9603488186500337 1.0697676423525153
# Buyer's expected utilty:  -0.23323131849140366
# Seller's expected utilty:  -0.5672517058799247
#
#
# 0.9493764151022481 1.0444533657598225
# Buyer's expected utilty:  -0.21653201856407062
# Seller's expected utilty:  -0.5669194751313515
#
#
# 0.967254669987187 1.0665938976014768
# Buyer's expected utilty:  -0.2298434053135437
# Seller's expected utilty:  -0.5602891147638946
#
#
# 0.9215006123446323 1.1210115378359085
# Buyer's expected utilty:  -0.2792419188110401
# Seller's expected utilty:  -0.6196975682897515
#
#
# 0.9827117503910076 1.1879101016892752
# Buyer's expected utilty:  -0.30280993745336965
# Seller's expected utilty:  -0.5912848017310601
#
#
# 0.8661563671118773 1.0202698085625295
# Buyer's expected utilty:  -0.23304354644702274
# Seller's expected utilty:  -0.6292723513376813
#
#
# 0.9295322040129743 1.0348606228302097
# Buyer's expected utilty:  -0.21656050524760057
# Seller's expected utilty:  -0.5798660175039633
#
#
# 0.8300118484907355 1.053163538535598
# Buyer's expected utilty:  -0.2774920764894928
# Seller's expected utilty:  -0.6741687530180925
#
#
# 0.9988086712437686 1.2203095728126425
# Buyer's expected utilty:  -0.31701747087668547
# Seller's expected utilty:  -0.5924442926971977
#
#
# 0.8318819931054999 1.1318517419796683
# Buyer's expected utilty:  -0.324554330776487
# Seller's expected utilty:  -0.6938928652310324
#
#
# 0.9902458159942792 1.0520187930484821
# Buyer's expected utilty:  -0.20793733601868297
# Seller's expected utilty:  -0.5286256855876603
#
#
# 0.8867507745157819 1.0824236927795083
# Buyer's expected utilty:  -0.2673291555449296
# Seller's expected utilty:  -0.631771669973673
#
#
# 0.852673520056263 1.0624695556911166
# Buyer's expected utilty:  -0.270542494737308
# Seller's expected utilty:  -0.6566984467980944
#
#
# 0.976754949278117 1.1547405567645352
# Buyer's expected utilty:  -0.2855163160959349
# Seller's expected utilty:  -0.5859901201700454
#
#
# 0.890956199797948 1.0198775571187275
# Buyer's expected utilty:  -0.22717272310943903
# Seller's expected utilty:  -0.6135616105679857
#
#
# 0.8718244506892684 1.1251037781739084
# Buyer's expected utilty:  -0.30535475387743755
# Seller's expected utilty:  -0.6612245291706114
#
#
# 0.9176752085943085 1.012315229549629
# Buyer's expected utilty:  -0.20736795625675167
# Seller's expected utilty:  -0.5858200273176419
#
#
# 0.7815703407714909 1.0163138885249712
# Buyer's expected utilty:  -0.2732436089914754
# Seller's expected utilty:  -0.6998041160930472
#
#
# 0.9698029860299098 1.046747311488421
# Buyer's expected utilty:  -0.21216836377016077
# Seller's expected utilty:  -0.549453056407849
#
#
# 0.9291802675030791 1.0946221352286265
# Buyer's expected utilty:  -0.2583464901491159
# Seller's expected utilty:  -0.6023682650914339
#
#
# 0.9654069383827173 1.0211748693401281
# Buyer's expected utilty:  -0.1975641327330652
# Seller's expected utilty:  -0.5456405059160132
#
#
# 0.8643025202595016 1.0764079278249834
# Buyer's expected utilty:  -0.2748212291769058
# Seller's expected utilty:  -0.6515857942233791
#
#
# 0.9933087467662887 1.1379489684432085
# Buyer's expected utilty:  -0.26935689146297054
# Seller's expected utilty:  -0.5651139925759363
#
#
# 0.9597911615899415 1.065747127288271
# Buyer's expected utilty:  -0.2322378447640693
# Seller's expected utilty:  -0.5673085508878568
#
#
# 0.9134614500282879 1.138862314775549
# Buyer's expected utilty:  -0.2992023874172169
# Seller's expected utilty:  -0.6366729312294508
#
#
# 0.9930176893471567 1.1887401209040485
# Buyer's expected utilty:  -0.30297608824299904
# Seller's expected utilty:  -0.5867968111655848
#
#
# 0.702836706152282 1.013244666745294
# Buyer's expected utilty:  -0.31686585060939376
# Seller's expected utilty:  -0.7525177857297813
#
#
# 0.9751432296235187 1.1810241200895117
# Buyer's expected utilty:  -0.30527720772379185
# Seller's expected utilty:  -0.6031379186094669
#
#
# 0.9308315834148807 1.134053361206417
# Buyer's expected utilty:  -0.28779817991973233
# Seller's expected utilty:  -0.6182431171938579
#
#
# 0.9480962574699792 1.03151245070163
# Buyer's expected utilty:  -0.208344786301861
# Seller's expected utilty:  -0.5632361967715847
#
#
# 0.9379102365094746 1.0040169283081202
# Buyer's expected utilty:  -0.19472550534573488
# Seller's expected utilty:  -0.5655447462667273
#
#
# 0.9482532161645087 1.0738279431475553
# Buyer's expected utilty:  -0.2411904925568508
# Seller's expected utilty:  -0.5813000190277986
#
#
# 0.9134970001230914 1.1110630911943833
# Buyer's expected utilty:  -0.27978341233740667
# Seller's expected utilty:  -0.6266231079505887
#
#
# 0.8892863252031797 1.0261042513858585
# Buyer's expected utilty:  -0.23181463792786997
# Seller's expected utilty:  -0.6175703680816449
#
#
# 0.8678930514401002 1.055698811969342
# Buyer's expected utilty:  -0.2608863412365854
# Seller's expected utilty:  -0.6431126212670839
#
#
# 0.861425988242775 1.09469152983141
# Buyer's expected utilty:  -0.2949355709932793
# Seller's expected utilty:  -0.6638100012175826
#
#
# 0.9886579495998239 1.1471895599297757
# Buyer's expected utilty:  -0.27599974939116395
# Seller's expected utilty:  -0.5746039869187275
#
#
# 0.8385788179462628 1.0743707894471437
# Buyer's expected utilty:  -0.2883650820721135
# Seller's expected utilty:  -0.6750911214785422
#
#
# 0.9633955290403724 1.0658572272450668
# Buyer's expected utilty:  -0.22716437727722158
# Seller's expected utilty:  -0.5616517109347241
#
#
# 0.6994848493971025 1.0083343516078942
# Buyer's expected utilty:  -0.3193473086582427
# Seller's expected utilty:  -0.7595657180018662
#
#
# 0.98227343866846 1.0228967556588304
# Buyer's expected utilty:  -0.18989442255895123
# Seller's expected utilty:  -0.5249349331089095
#
#
# 0.9391531453164976 1.0147143237251541
# Buyer's expected utilty:  -0.1991794635682505
# Seller's expected utilty:  -0.563600837786424
#
#
# 0.9789339108159196 1.083496251153477
# Buyer's expected utilty:  -0.23920029407034668
# Seller's expected utilty:  -0.5602627270014224
#
#
# 0.9782815071998983 1.1817974904923394
# Buyer's expected utilty:  -0.2978693395100635
# Seller's expected utilty:  -0.5902297120671048
#
#
# 0.9695950943730617 1.0076367417004248
# Buyer's expected utilty:  -0.18641198679954468
# Seller's expected utilty:  -0.5379661470632043
#
#
# 0.9370910605841588 1.0575760819182232
# Buyer's expected utilty:  -0.23414920009659818
# Seller's expected utilty:  -0.5864965279865274
#
#
# 0.9385509820229134 1.0305506852180226
# Buyer's expected utilty:  -0.21550869935300335
# Seller's expected utilty:  -0.5759168102777501
#
#
# 0.830193147915479 1.1389724671248695
# Buyer's expected utilty:  -0.33045184163479285
# Seller's expected utilty:  -0.6991269483357692
#
#
# 0.9850554777118748 1.0960867376003838
# Buyer's expected utilty:  -0.24654737630957382
# Seller's expected utilty:  -0.5589496576008253
#
#
# 0.919139617438376 1.196948799176789
# Buyer's expected utilty:  -0.3327784620894293
# Seller's expected utilty:  -0.6512086992044341
# 0.9660103311212977 1.1823507500201322
# Buyer's expected utilty:  -0.30193519903907207
# Seller's expected utilty:  -0.5985203520655756
#
#
# 0.9966805225254218 1.1430404197391102
# Buyer's expected utilty:  -0.2707120269337805
# Seller's expected utilty:  -0.5626870178247567
#
#
# 0.8093768330602588 1.1067091334402626
# Buyer's expected utilty:  -0.3226310190341033
# Seller's expected utilty:  -0.7035050515644682
#
#
# 0.8773291915511008 1.1041605660318297
# Buyer's expected utilty:  -0.285585323117191
# Seller's expected utilty:  -0.6483215068971573
#
#
# 0.8842440758174568 1.0561790500507278
# Buyer's expected utilty:  -0.25057003103855213
# Seller's expected utilty:  -0.6233086490199884
#
#
# 0.9933328143787195 1.2123220890601079
# Buyer's expected utilty:  -0.31341916881313164
# Seller's expected utilty:  -0.5900070019502316
#
#
# 0.9573287945971678 1.1128060121177055
# Buyer's expected utilty:  -0.2637348201866253
# Seller's expected utilty:  -0.5867923456508175
#
#
# 0.9235730987313335 1.1804081707462304
# Buyer's expected utilty:  -0.31758310713708376
# Seller's expected utilty:  -0.637484958681903
#
#
# 0.9320107912994361 1.1535309293192497
# Buyer's expected utilty:  -0.2998934064258663
# Seller's expected utilty:  -0.6241060655086368
#
#
# 0.9879032949003279 1.0405852310532662
# Buyer's expected utilty:  -0.20312505859569507
# Seller's expected utilty:  -0.5310095933066039
#
#
# 0.8178740289863982 1.0158396643482073
# Buyer's expected utilty:  -0.2575308750966544
# Seller's expected utilty:  -0.6705408061331483
#
#
# 0.9318583804774243 1.1703629612683342
# Buyer's expected utilty:  -0.30864948240833656
# Seller's expected utilty:  -0.6271157823908556
#
#
# 0.7471456973869257 1.02778858472759
# Buyer's expected utilty:  -0.30007761272163924
# Seller's expected utilty:  -0.7261440886052325
#
#
# 0.9640203415908007 1.226676372682161
# Buyer's expected utilty:  -0.33046511376987364
# Seller's expected utilty:  -0.6188041997218243
#
#
# 0.8916055387554256 1.177678171208159
# Buyer's expected utilty:  -0.32988974609612415
# Seller's expected utilty:  -0.6651565224658397
#
#
# 0.8311944181695878 1.0346607678589477
# Buyer's expected utilty:  -0.2631867058165691
# Seller's expected utilty:  -0.6665142827437115
#
#
# 0.9490445019492677 1.1219916548948712
# Buyer's expected utilty:  -0.27447944782009165
# Seller's expected utilty:  -0.598093971092485
#
#
# 0.9673810889738095 1.0533873050213969
# Buyer's expected utilty:  -0.2189705570026972
# Seller's expected utilty:  -0.5558008332852431
#
#
# 0.8843592571144292 1.1042986555034027
# Buyer's expected utilty:  -0.28131094167235904
# Seller's expected utilty:  -0.6412110935427464
#
#
# 0.7269191403900082 1.0383223103314363
# Buyer's expected utilty:  -0.32186051516814723
# Seller's expected utilty:  -0.7450605512604246
#
#
# 0.8296482663833018 1.0599798031612375
# Buyer's expected utilty:  -0.2814186815339485
# Seller's expected utilty:  -0.676396703675156
#
#
# 0.9339730155693587 1.1887352254606594
# Buyer's expected utilty:  -0.31888533872540886
# Seller's expected utilty:  -0.6311850464602399
#
#
# 0.8434446218550375 1.0014694826785768
# Buyer's expected utilty:  -0.22978333992742803
# Seller's expected utilty:  -0.6411767346226084
#
#
# 0.963732019370654 1.2094029258588024
# Buyer's expected utilty:  -0.31756236124034
# Seller's expected utilty:  -0.6144124433918424
#
#
# 0.8160736893252576 1.0681541970641395
# Buyer's expected utilty:  -0.290325774852272
# Seller's expected utilty:  -0.6866775981924922
#
#
# 0.9691433250987294 1.021151424579338
# Buyer's expected utilty:  -0.19356174991383163
# Seller's expected utilty:  -0.5380795989420032
#
#
# 0.9193693284632762 1.0325392821901187
# Buyer's expected utilty:  -0.22486552664593729
# Seller's expected utilty:  -0.5936099464897626
#
#
# 0.9507759631625389 1.172335796479278
# Buyer's expected utilty:  -0.3050569207250312
# Seller's expected utilty:  -0.6145779937834206
#
#
# 0.9016680650186693 1.156418564831176
# Buyer's expected utilty:  -0.3122824201696383
# Seller's expected utilty:  -0.6464293894188804
#
#
# 0.7416485872885488 1.0453860025606014
# Buyer's expected utilty:  -0.31632326074936923
# Seller's expected utilty:  -0.7351680588167306
#
#
# 0.778025431935336 1.063923538216301
# Buyer's expected utilty:  -0.30857125691455967
# Seller's expected utilty:  -0.7119590141465959
#
#
# 0.8260079727080681 1.0168410162161474
# Buyer's expected utilty:  -0.25346762212473767
# Seller's expected utilty:  -0.6647858221185107
#
#
# 0.9747382619424173 1.230722087258259
# Buyer's expected utilty:  -0.32986805561107874
# Seller's expected utilty:  -0.6138814950201551
#
#
# 0.9443558254649832 1.1610687545226681
# Buyer's expected utilty:  -0.2997748638937697
# Seller's expected utilty:  -0.617565467267991
#
#
# 0.8668112459990382 1.156467821203932
# Buyer's expected utilty:  -0.3266923080461954
# Seller's expected utilty:  -0.6748274193694834
#
#
# 0.9947424284751751 1.1501439506296995
# Buyer's expected utilty:  -0.27832053875686624
# Seller's expected utilty:  -0.572602282717515
#
#
# 0.9709171679692823 1.1583062564800846
# Buyer's expected utilty:  -0.28802458840017536
# Seller's expected utilty:  -0.5952071804682255
#
#
# 0.8085897432237689 1.0613796320257534
# Buyer's expected utilty:  -0.29092657561922425
# Seller's expected utilty:  -0.6902839060402121
#
#
# 0.90903181166698 1.1954924970799212
# Buyer's expected utilty:  -0.3315284014417883
# Seller's expected utilty:  -0.6536202473868896
#
#
# 0.9919738472539337 1.1809432937023585
# Buyer's expected utilty:  -0.29913730562938495
# Seller's expected utilty:  -0.5845290162223561
#
#
# 0.9109831631338099 1.0841602133470063
# Buyer's expected utilty:  -0.258627609695884
# Seller's expected utilty:  -0.6156457203032206
#
#
# 0.8547375094709031 1.1271124491406257
# Buyer's expected utilty:  -0.31381665208988757
# Seller's expected utilty:  -0.6779711591748299
#
#
# 0.8526004881082003 1.0877401069563823
# Buyer's expected utilty:  -0.28723229975533165
# Seller's expected utilty:  -0.665003517293051
#
#
# 0.7420806915483169 1.0112945657600236
# Buyer's expected utilty:  -0.29481764317440196
# Seller's expected utilty:  -0.730162816919281
#
#
# 0.9887433990860294 1.1438858658556614
# Buyer's expected utilty:  -0.2773731501424081
# Seller's expected utilty:  -0.5745764151286554
#
#
# 0.8194118259007944 1.0858726013841122
# Buyer's expected utilty:  -0.3057599021087259
# Seller's expected utilty:  -0.6948168747999806
#
#
# 0.8864963573877415 1.1232451315551544
# Buyer's expected utilty:  -0.2960974038475838
# Seller's expected utilty:  -0.6469051278727879
#
#
# 0.9774726766398493 1.1250371236285721
# Buyer's expected utilty:  -0.26726440002728863
# Seller's expected utilty:  -0.5765600111496141
#
#
# 0.7904981430754718 1.0761152358296395
# Buyer's expected utilty:  -0.31395203302401825
# Seller's expected utilty:  -0.7142047687012384
#
#
# 0.919617654129854 1.1056464777607706
# Buyer's expected utilty:  -0.2781691507744761
# Seller's expected utilty:  -0.6213483403042582
#
#
# 0.9942803022817199 1.1244424245034725
# Buyer's expected utilty:  -0.260674261046884
# Seller's expected utilty:  -0.5590024079216132
#
#
# 0.9854787966378635 1.1651087752671585
# Buyer's expected utilty:  -0.2888172618516868
# Seller's expected utilty:  -0.5836691941552973
#
#
# 0.8037618401208456 1.1121445607779756
# Buyer's expected utilty:  -0.32740418523698556
# Seller's expected utilty:  -0.7087629145550307
#
#
# 0.9166905423737146 1.1855503798660287
# Buyer's expected utilty:  -0.321219878601038
# Seller's expected utilty:  -0.6434234400485108
#
#
# 0.8102574960529267 1.030257206714548
# Buyer's expected utilty:  -0.2713111259353391
# Seller's expected utilty:  -0.6835299688380531
#
#
# 0.9659531676112676 1.1187690499900986
# Buyer's expected utilty:  -0.26657855657526364
# Seller's expected utilty:  -0.5836865973741332
#
#
# 0.7519127592553425 1.0528168886392444
# Buyer's expected utilty:  -0.3158769394951558
# Seller's expected utilty:  -0.7296070089326046
#
#
# 0.9781841695078815 1.1829474073094532
# Buyer's expected utilty:  -0.3033157436568321
# Seller's expected utilty:  -0.5994745526931189
#
#
# 0.941343287394085 1.0787350309940404
# Buyer's expected utilty:  -0.24573102506734634
# Seller's expected utilty:  -0.5875903917005779
#
#
# 0.9568186334291642 1.1244689700769934
# Buyer's expected utilty:  -0.27334422802195585
# Seller's expected utilty:  -0.5949161648796604
#
#
# 0.9572417324104276 1.035222782713943
# Buyer's expected utilty:  -0.20938386943552337
# Seller's expected utilty:  -0.5579983636612287
#
#
# 0.9520598343339244 1.1243425076514557
# Buyer's expected utilty:  -0.27514427056559415
# Seller's expected utilty:  -0.6006186069291265
# 0.9506373851053371 1.187502476932782
# Buyer's expected utilty:  -0.3141295242878027
# Seller's expected utilty:  -0.6214303208791525
#
#
# 0.7695103496746463 1.0724141196066173
# Buyer's expected utilty:  -0.31808811566323003
# Seller's expected utilty:  -0.7205704364596401
#
#
# 0.9030128612615458 1.1842196896638817
# Buyer's expected utilty:  -0.3304279663826838
# Seller's expected utilty:  -0.657146038790797
#
#
# 0.9244169643453852 1.163827209569065
# Buyer's expected utilty:  -0.31159256887785747
# Seller's expected utilty:  -0.6344970261975657
#
#
# 0.8118703613430442 1.0678314206242407
# Buyer's expected utilty:  -0.29357401157088925
# Seller's expected utilty:  -0.6906293284796223
#
#
# 0.9909848141079909 1.073832276014924
# Buyer's expected utilty:  -0.22819959802309958
# Seller's expected utilty:  -0.54275812737167
#
#
# 0.8087958961107922 1.0139347115093003
# Buyer's expected utilty:  -0.2565725302519819
# Seller's expected utilty:  -0.6734206809972105
#
#
# 0.9816206757500421 1.1685228808700798
# Buyer's expected utilty:  -0.2929578392813407
# Seller's expected utilty:  -0.588399676102933
#
#
# 0.924911334255746 1.1946894824211318
# Buyer's expected utilty:  -0.32554938786890436
# Seller's expected utilty:  -0.6402076007395042
#
#
# 0.9207349354397623 1.1227610294708834
# Buyer's expected utilty:  -0.284774030461374
# Seller's expected utilty:  -0.6232723397950456
#
#
# 0.8796855290193394 1.1529082406944715
# Buyer's expected utilty:  -0.314938019391598
# Seller's expected utilty:  -0.6613141996822398
#
#
# 0.9653813242437311 1.2332353265821863
# Buyer's expected utilty:  -0.3319414583204622
# Seller's expected utilty:  -0.6192914475423299
#
#
# 0.8835446074122285 1.0685773633665905
# Buyer's expected utilty:  -0.2621841083346522
# Seller's expected utilty:  -0.6332553576761762
#
#
# 0.9982026439305196 1.2230296706621213
# Buyer's expected utilty:  -0.3246086976314839
# Seller's expected utilty:  -0.5999238462115432
#
#
# 0.727973287431843 1.0164940705804757
# Buyer's expected utilty:  -0.30705646984355167
# Seller's expected utilty:  -0.7397913663797916
#
#
# 0.9326058461140789 1.0097785645350768
# Buyer's expected utilty:  -0.20109243513014083
# Seller's expected utilty:  -0.5705212041328556
#
#
# 0.7244282762479289 1.0128588315409894
# Buyer's expected utilty:  -0.31037020902126516
# Seller's expected utilty:  -0.7444411098040868
#
#
# 0.869840108842591 1.154086722050198
# Buyer's expected utilty:  -0.3256341523268048
# Seller's expected utilty:  -0.6704297462160338
#
#
# 0.9580764812731066 1.1880823136136704
# Buyer's expected utilty:  -0.3102254551176709
# Seller's expected utilty:  -0.611670670423522
#
#
# 0.9655091465516549 1.040292135505269
# Buyer's expected utilty:  -0.2106116201963828
# Seller's expected utilty:  -0.552358574162772
#
#
# 0.9330684707904611 1.0188479347528998
# Buyer's expected utilty:  -0.20336211378843985
# Seller's expected utilty:  -0.5691602810180663
#
#
# 0.8579515537435438 1.067403978699237
# Buyer's expected utilty:  -0.2713043732271403
# Seller's expected utilty:  -0.6524941065246087
#
#
# 0.8176696500103434 1.0221329729833473
# Buyer's expected utilty:  -0.26329917657361857
# Seller's expected utilty:  -0.6763791200084919
#
#
# 0.9054725220040913 1.0806225499699136
# Buyer's expected utilty:  -0.26467020671625757
# Seller's expected utilty:  -0.6228232036053553
#
#
# 0.9862396359376178 1.1023749022802052
# Buyer's expected utilty:  -0.2479856401365836
# Seller's expected utilty:  -0.5586581025751131
#
#
# 0.9289784819447418 1.2100386855710634
# Buyer's expected utilty:  -0.33385290685391833
# Seller's expected utilty:  -0.643341380460396
#
#
# 0.8593590874547206 1.1704050420565466
# Buyer's expected utilty:  -0.3329900752110145
# Seller's expected utilty:  -0.6785936251690683
#
#
# 0.8189608077766815 1.011949468031506
# Buyer's expected utilty:  -0.252596642991984
# Seller's expected utilty:  -0.6693650832935287
#
#
# 0.8057524373136551 1.1119994362564505
# Buyer's expected utilty:  -0.32504722879815184
# Seller's expected utilty:  -0.7065796559199804
#
#
# 0.7558351377924059 1.0033498775381562
# Buyer's expected utilty:  -0.2787457961031488
# Seller's expected utilty:  -0.713765732994196
#
#
# 0.8064333775041923 1.0551555537866992
# Buyer's expected utilty:  -0.2889369358024098
# Seller's expected utilty:  -0.6898750508441938
#
#
# 0.9765401942717469 1.162661404649274
# Buyer's expected utilty:  -0.2915576810557892
# Seller's expected utilty:  -0.5909441476372956
#
#
# 0.9846926950707295 1.1312955783188705
# Buyer's expected utilty:  -0.26823847824051966
# Seller's expected utilty:  -0.5733268384824772
#
#
# 0.8598197511007095 1.0663337883132202
# Buyer's expected utilty:  -0.26867041986168805
# Seller's expected utilty:  -0.6484378621522339

# %% [markdown]
# ### Theoretical equilibrium when seller places same asks and buyer places different bids both the items

# %%
alpha_b1 = 0.85714285714;
alpha_b2 = 0.57142857142;

alpha_s1 = 1.12169312;
alpha_s2 = 1.12169312;

theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
theta_s, S = seller_strategy(alpha_s1, alpha_s2)

cp_list, cq_list = auction_clearing(B, S)

U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
U_s = seller_expected_utility(theta_s, cp_list, cq_list)

print("Buyer's expected utilty: ", U_b)
print("Seller's expected utilty: ", U_s)

best_Ub2 = U_b
best_Us2 = U_s
# Out:
# Buyer's expected utilty:  -0.36164565342459687
# Seller's expected utilty:  -0.7869981927842143

# %%
# Checking if some randomly selected scaler values can yeild better utility

for i in range(1000):
    
    alpha_b1 = np.random.uniform(0.5, 1, 1)[0];
    alpha_b2 = np.random.uniform(0.5, 1, 1)[0];

    alpha_s1 = np.random.uniform(1, 1.5, 1)[0];
    alpha_s2 = alpha_s1;

    theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
    theta_s, S = seller_strategy(alpha_s1, alpha_s2)

    cp_list, cq_list = auction_clearing(B, S)

    U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
    U_s = seller_expected_utility(theta_s, cp_list, cq_list)

    if((U_b >= best_Ub2) and (U_s >= best_Us2)):
        print(alpha_b1, alpha_b2, alpha_s1)
        print("Buyer's expected utilty: ", U_b)
        print("Seller's expected utilty: ", U_s)
        print("\n")
# Out:
# 0.6925103069014357 0.9456737439470868 1.0132777276264613
# Buyer's expected utilty:  -0.23270616182816264
# Seller's expected utilty:  -0.6914667081773878
#
#
# 0.8809113773285229 0.5260829971743963 1.0636129154016096
# Buyer's expected utilty:  -0.3339501485068866
# Seller's expected utilty:  -0.7806492195348729
#
#
# 0.8455220193826738 0.6143670769012701 1.0223655434054852
# Buyer's expected utilty:  -0.29261508998002844
# Seller's expected utilty:  -0.757322059464796
#
#
# 0.9273021562078541 0.9019651444831835 1.21414216010636
# Buyer's expected utilty:  -0.3369222475650527
# Seller's expected utilty:  -0.6606730829385782
#
#
# 0.7131317968383958 0.8036209815707187 1.071361664740278
# Buyer's expected utilty:  -0.3174279377351187
# Seller's expected utilty:  -0.744664050959252
#
#
# 0.7924578619331616 0.7853963715585502 1.0268048256821958
# Buyer's expected utilty:  -0.2773849313359787
# Seller's expected utilty:  -0.697903720077245
#
#
# 0.9230025130074482 0.5016817021374476 1.1058549079250568
# Buyer's expected utilty:  -0.355626718261866
# Seller's expected utilty:  -0.7805026369376317
#
#
# 0.9338280216331629 0.7560714270639859 1.1007090965344557
# Buyer's expected utilty:  -0.2841614770090789
# Seller's expected utilty:  -0.6931242752315153
#
#
# 0.5136827367661736 0.9051121941373557 1.1033342697883617
# Buyer's expected utilty:  -0.36091008538340336
# Seller's expected utilty:  -0.7848965171396752
#
#
# 0.615417132616993 0.9300677175947449 1.1559942139869928
# Buyer's expected utilty:  -0.351417695909675
# Seller's expected utilty:  -0.7594776788722245
#
#
# 0.7032114685741713 0.9156311082985706 1.148148176473743
# Buyer's expected utilty:  -0.3270604756405576
# Seller's expected utilty:  -0.7288412124678934
#
#
# 0.7300815567158356 0.962975457209892 1.075456683976084
# Buyer's expected utilty:  -0.2656795191613236
# Seller's expected utilty:  -0.6874803233716912
#
#
# 0.9954511853912764 0.690831737478889 1.221640260075384
# Buyer's expected utilty:  -0.35306400410887373
# Seller's expected utilty:  -0.7306951575537425
#
#
# 0.8324028747655063 0.9356176219870416 1.2096965931941772
# Buyer's expected utilty:  -0.34116293695549305
# Seller's expected utilty:  -0.6887370642125508
#
#
# 0.799692648454382 0.8833213541251879 1.17936740401638
# Buyer's expected utilty:  -0.3378108670013059
# Seller's expected utilty:  -0.7055518487388284
#
#
# 0.5416620297876344 0.9380785301894099 1.050513256474495
# Buyer's expected utilty:  -0.3067286200558486
# Seller's expected utilty:  -0.7587475694916391
#
#
# 0.7251111815399787 0.8069180305745252 1.10724937294712
# Buyer's expected utilty:  -0.3358913198944616
# Seller's expected utilty:  -0.7442604453524172
#
#
# 0.7771474441326897 0.9067910080173782 1.1456937682292077
# Buyer's expected utilty:  -0.3158366180373411
# Seller's expected utilty:  -0.6998655334209616
#
#
# 0.6674410628071321 0.8620751392040251 1.117561454215564
# Buyer's expected utilty:  -0.33417019405511494
# Seller's expected utilty:  -0.7544938383573468
#
#
# 0.7063438752652604 0.9267675230014398 1.119680029130957
# Buyer's expected utilty:  -0.3057435632011164
# Seller's expected utilty:  -0.7160843796122963
#
#
# 0.9110966039853536 0.6559457554302152 1.1532833559872837
# Buyer's expected utilty:  -0.34083036086242363
# Seller's expected utilty:  -0.7506152746248811
#
#
# 0.991333458351392 0.54750531309379 1.0487038262527655
# Buyer's expected utilty:  -0.29068039489101216
# Seller's expected utilty:  -0.7349864773780251
#
#
# 0.761634521631372 0.9222207453808817 1.1386112669389132
# Buyer's expected utilty:  -0.3104302914125595
# Seller's expected utilty:  -0.7053620278574417
#
#
# 0.8085051752323775 0.9778803749710712 1.1445548388678182
# Buyer's expected utilty:  -0.2941047650932778
# Seller's expected utilty:  -0.6698757318944405
#
#
# 0.8801638902472875 0.5685735612946541 1.0737785483533948
# Buyer's expected utilty:  -0.3220232411286239
# Seller's expected utilty:  -0.7628175292829695
#
#
# 0.7533154027171887 0.6750607282651951 1.009506115633245
# Buyer's expected utilty:  -0.29623095576358255
# Seller's expected utilty:  -0.7506859141085312
#
#
# 0.6924118556701342 0.9772221609837621 1.030882560274007
# Buyer's expected utilty:  -0.2365935255360956
# Seller's expected utilty:  -0.6832226438987126
#
#
# 0.5757253463366917 0.9462072241082922 1.0549391992602875
# Buyer's expected utilty:  -0.2959640855756016
# Seller's expected utilty:  -0.7432557013777814
#
#
# 0.8634043331312001 0.5926747154259606 1.1185309082021382
# Buyer's expected utilty:  -0.3529862236377183
# Seller's expected utilty:  -0.7769232045264028
#
#
# 0.9221081572730039 0.8810486819085246 1.0462969854349735
# Buyer's expected utilty:  -0.23314153102014498
# Seller's expected utilty:  -0.6139956690849966
#
#
# 0.7674686275407766 0.8296644217232516 1.1539423729778209
# Buyer's expected utilty:  -0.3432850590561335
# Seller's expected utilty:  -0.7246867124228188
#
#
# 0.7200229549698269 0.9350887497892029 1.1838386146987503
# Buyer's expected utilty:  -0.339193157411017
# Seller's expected utilty:  -0.7253453524670451
#
#
# 0.7072657275147365 0.8453996403888308 1.0830607296147838
# Buyer's expected utilty:  -0.3089323591500876
# Seller's expected utilty:  -0.7331811228202201
#
#
# 0.7997478805317557 0.6469478734020995 1.032673371682641
# Buyer's expected utilty:  -0.3043163883659779
# Seller's expected utilty:  -0.7581496675428279
#
#
# 0.8727053684522266 0.8211563647059956 1.1490550343244195
# Buyer's expected utilty:  -0.3226035641086622
# Seller's expected utilty:  -0.6931092850200861
#
#
# 0.75648366124323 0.8422178528058744 1.1868954964530916
# Buyer's expected utilty:  -0.3609455637724039
# Seller's expected utilty:  -0.7402151835104499
#
#
# 0.8819277275187988 0.7627985479530871 1.0681599222961857
# Buyer's expected utilty:  -0.2821822188572367
# Seller's expected utilty:  -0.7004373429223003
#
#
# 0.7598878842667226 0.8902821842030911 1.1385074211155455
# Buyer's expected utilty:  -0.3206850064719784
# Seller's expected utilty:  -0.7177016246150786
#
#
# 0.8543958009369312 0.6631297186442155 1.144558769593082
# Buyer's expected utilty:  -0.35498683300108397
# Seller's expected utilty:  -0.7640224734861681
#
#
# 0.9927501766145499 0.8147917366321338 1.019916335816187
# Buyer's expected utilty:  -0.20267054064871506
# Seller's expected utilty:  -0.6226245795830425
#
#
# 0.8549329919116513 0.621079950075139 1.0097481186747752
# Buyer's expected utilty:  -0.27412677276853314
# Seller's expected utilty:  -0.745977191112073
#
#
# 0.7570364136234549 0.6455680633141953 1.028076846483736
# Buyer's expected utilty:  -0.3195499693652541
# Seller's expected utilty:  -0.7674211522162392
#
#
# 0.9372357361711904 0.7684746331052599 1.1131470746513379
# Buyer's expected utilty:  -0.28847534445794937
# Seller's expected utilty:  -0.6884852752673162
#
#
# 0.7812619469520836 0.599175736929122 1.0132107137331046
# Buyer's expected utilty:  -0.3156251518147759
# Seller's expected utilty:  -0.782086692134141
#
#
# 0.8806048214729998 0.6317419155724351 1.1106878527336794
# Buyer's expected utilty:  -0.336274920500974
# Seller's expected utilty:  -0.763961202819125
#
#
# 0.7091806308480232 0.9056828883782356 1.1159029667907137
# Buyer's expected utilty:  -0.31318932369369334
# Seller's expected utilty:  -0.7250417258158207
#
#
# 0.9740663953450035 0.9512954654938304 1.0919010397846893
# Buyer's expected utilty:  -0.2442798696005696
# Seller's expected utilty:  -0.577017625046124
#
#
# 0.6081085905259048 0.8725084932935406 1.037454383018852
# Buyer's expected utilty:  -0.29141132668234293
# Seller's expected utilty:  -0.7483220108089303
#
#
# 0.9183223566502543 0.6624699666355329 1.0456346532098226
# Buyer's expected utilty:  -0.2698127856652279
# Seller's expected utilty:  -0.7169596031400596
#
#
# 0.9939650271164207 0.6662303721321554 1.049609660574647
# Buyer's expected utilty:  -0.25227116006200623
# Seller's expected utilty:  -0.6922021463574457
#
#
# 0.9697550282829888 0.8969307146531188 1.111041859940316
# Buyer's expected utilty:  -0.2637730067757848
# Seller's expected utilty:  -0.6172804880734307
#
#
# 0.8674216815555795 0.8845605556671787 1.059457733634766
# Buyer's expected utilty:  -0.25904095333721533
# Seller's expected utilty:  -0.642731599758696
#
#
# 0.8020979489559716 0.7765124150471583 1.0690798415818026
# Buyer's expected utilty:  -0.3051481629038539
# Seller's expected utilty:  -0.7097777785666906
#
#
# 0.9556124135789885 0.6220175877646015 1.124962597211627
# Buyer's expected utilty:  -0.32256453627586984
# Seller's expected utilty:  -0.741458447554762
#
#
# 0.8854534515807486 0.7967175090112874 1.2022657039801383
# Buyer's expected utilty:  -0.35353211821339603
# Seller's expected utilty:  -0.7153181011010452
# 0.9563489428565431 0.971828573711434 1.0670657989284436
# Buyer's expected utilty:  -0.22392559755971636
# Seller's expected utilty:  -0.5614930712845249
#
#
# 0.7804417985455196 0.999183652413715 1.2251023958335507
# Buyer's expected utilty:  -0.3360249076038657
# Seller's expected utilty:  -0.6953793414581162
#
#
# 0.9911725983383675 0.9164162227049526 1.0527707378146067
# Buyer's expected utilty:  -0.2134231706855575
# Seller's expected utilty:  -0.5762890423636925
#
#
# 0.8511797523019963 0.7504947559863797 1.0420225400992111
# Buyer's expected utilty:  -0.2711597257408569
# Seller's expected utilty:  -0.7026033378525275
#
#
# 0.8690174384623635 0.7546460187632612 1.1622087859638508
# Buyer's expected utilty:  -0.3425317424043304
# Seller's expected utilty:  -0.729463138291327
#
#
# 0.990449667062574 0.6385295156512278 1.1645439583320456
# Buyer's expected utilty:  -0.3345387241244957
# Seller's expected utilty:  -0.734904350242391
#
#
# 0.9665446724356965 0.6204071045138014 1.0205510378665623
# Buyer's expected utilty:  -0.2532390398640856
# Seller's expected utilty:  -0.7133585024896145
#
#
# 0.8947450502161816 0.9460648571085069 1.0472591320348892
# Buyer's expected utilty:  -0.2277207872536635
# Seller's expected utilty:  -0.6049732782983036
#
#
# 0.7406770723974538 0.9677974103804841 1.1857539403463566
# Buyer's expected utilty:  -0.3280912574492962
# Seller's expected utilty:  -0.7093805192523
#
#
# 0.8045093732232875 0.9013496169721462 1.1539398015944808
# Buyer's expected utilty:  -0.321645965812356
# Seller's expected utilty:  -0.6980497624477016
#
#
# 0.9512335893510762 0.8750180221847103 1.2365965031065695
# Buyer's expected utilty:  -0.34471709833064085
# Seller's expected utilty:  -0.672739253075757
#
#
# 0.9296363564755049 0.8661982134797938 1.2477556708480724
# Buyer's expected utilty:  -0.35831898626981223
# Seller's expected utilty:  -0.6866432780280469
#
#
# 0.806400638430915 0.564138009828216 1.0259541227830853
# Buyer's expected utilty:  -0.3215966982994723
# Seller's expected utilty:  -0.7838968381530064
#
#
# 0.6610792863103311 0.6943317658465558 1.0329618760270758
# Buyer's expected utilty:  -0.34503254819713197
# Seller's expected utilty:  -0.782240060650282
#
#
# 0.9329511755560774 0.8152361699960672 1.1474810749416076
# Buyer's expected utilty:  -0.3065820737326972
# Seller's expected utilty:  -0.6812837800489399
#
#
# 0.5950075927504265 0.9595261187156647 1.1118341343830342
# Buyer's expected utilty:  -0.32406562131533634
# Seller's expected utilty:  -0.7472672855252168
#
#
# 0.8300731560519901 0.8794431680051492 1.2280925254882764
# Buyer's expected utilty:  -0.3611408516513675
# Seller's expected utilty:  -0.7051529513419359
#
#
# 0.8792978588306601 0.9039303547839388 1.1541920202360967
# Buyer's expected utilty:  -0.31355375893622633
# Seller's expected utilty:  -0.6597595607769413
#
#
# 0.8250358483486857 0.7350703924147369 1.136397850164535
# Buyer's expected utilty:  -0.34043007102339334
# Seller's expected utilty:  -0.734361061111832
#
#
# 0.7282368695193082 0.9188567127829145 1.2009397306900595
# Buyer's expected utilty:  -0.3550006737334776
# Seller's expected utilty:  -0.732894243710974
#
#
# 0.5983761974853796 0.9977660553788207 1.122590693485394
# Buyer's expected utilty:  -0.31457755479188343
# Seller's expected utilty:  -0.7348693012032671
#
#
# 0.7687361738509537 0.8835640969585983 1.143086272379413
# Buyer's expected utilty:  -0.328075664900889
# Seller's expected utilty:  -0.7179699508381678
#
#
# 0.5942930922234142 0.8981755045636393 1.048562061155529
# Buyer's expected utilty:  -0.2987798825305303
# Seller's expected utilty:  -0.7538451218306202
#
#
# 0.915710630318576 0.8772537451667753 1.2190720923811218
# Buyer's expected utilty:  -0.33984319388451745
# Seller's expected utilty:  -0.6732549652924498
#
#
# 0.9251019131455165 0.5754719685534531 1.1283289703227448
# Buyer's expected utilty:  -0.34426996405924204
# Seller's expected utilty:  -0.7647193051894865
#
#
# 0.9918996208231486 0.7171428237063897 1.1742253760217616
# Buyer's expected utilty:  -0.3211953201138802
# Seller's expected utilty:  -0.7099505826949075
#
#
# 0.9875981572179864 0.8783687076913205 1.1530134359358133
# Buyer's expected utilty:  -0.2894885140917078
# Seller's expected utilty:  -0.6393354879219755
#
#
# 0.9540163923115046 0.6007286666401681 1.1036933591432074
# Buyer's expected utilty:  -0.31492974938062707
# Seller's expected utilty:  -0.7422661729894383
#
#
# 0.6637063595267448 0.9994463899203571 1.0656657030620231
# Buyer's expected utilty:  -0.2642969212625845
# Seller's expected utilty:  -0.6994300373421364
#
#
# 0.6570303543182361 0.9826611643249598 1.1478719270946147
# Buyer's expected utilty:  -0.32103021397759146
# Seller's expected utilty:  -0.725196796070118
#
#
# 0.9915120902370276 0.7628867995789976 1.0859932043831642
# Buyer's expected utilty:  -0.25991004878156565
# Seller's expected utilty:  -0.6692692280399488
#
#
# 0.8171989356338372 0.7377497349185649 1.1591460539180767
# Buyer's expected utilty:  -0.3594300914285524
# Seller's expected utilty:  -0.7470775361977241
#
#
# 0.764101744282788 0.7895679803837092 1.0283886699220433
# Buyer's expected utilty:  -0.285299762175992
# Seller's expected utilty:  -0.7117724626293553
#
#
# 0.6763219634954595 0.9756843905947101 1.1810807278779403
# Buyer's expected utilty:  -0.3385207466085959
# Seller's expected utilty:  -0.7327562696470779
#
#
# 0.7162118138815593 0.7492319988796867 1.1136256863932754
# Buyer's expected utilty:  -0.3601036478063032
# Seller's expected utilty:  -0.7636453009571523
#
#
# 0.5584240015631909 0.967970868155791 1.0854134915820408
# Buyer's expected utilty:  -0.3118246189599762
# Seller's expected utilty:  -0.7442129400926011
#
#
# 0.890953009795644 0.858135141403245 1.1892511535715111
# Buyer's expected utilty:  -0.3361872990400021
# Seller's expected utilty:  -0.6826534965132114
#
#
# 0.5955692119672558 0.9902470779628834 1.028958432383506
# Buyer's expected utilty:  -0.2573270849010155
# Seller's expected utilty:  -0.7132286050399855
#
#
# 0.7367985711843723 0.9079788311432544 1.057433669946852
# Buyer's expected utilty:  -0.26747921440426997
# Seller's expected utilty:  -0.6974595451829083
#
#
# 0.6567521726435621 0.7353155590268738 1.0422241794452463
# Buyer's expected utilty:  -0.33275337635555335
# Seller's expected utilty:  -0.7747446708868639
#
#
# 0.7672386844904011 0.8114070098357501 1.0952637041250264
# Buyer's expected utilty:  -0.3164004146032038
# Seller's expected utilty:  -0.71961263054394
#
#
# 0.6026560630936189 0.9414900954609158 1.0171864750168347
# Buyer's expected utilty:  -0.26088132314467233
# Seller's expected utilty:  -0.7274275966230227
#
#
# 0.5518472086387597 0.8330683361499176 1.0007586634029135
# Buyer's expected utilty:  -0.3031797380780898
# Seller's expected utilty:  -0.7792687078665369
#
#
# 0.8039886889248007 0.6615660839765979 1.114243616664706
# Buyer's expected utilty:  -0.34793051945891124
# Seller's expected utilty:  -0.7689869418915696
#
#
# 0.9620138218367704 0.5759554498568601 1.0694640678676277
# Buyer's expected utilty:  -0.29941796610712945
# Seller's expected utilty:  -0.7392576950705761
#
#
# 0.8956320725330198 0.5357153969157684 1.0369721870845736
# Buyer's expected utilty:  -0.3113930573549185
# Seller's expected utilty:  -0.7673332984383733
#
#
# 0.9700395311213607 0.980046097657822 1.0544620418074762
# Buyer's expected utilty:  -0.21579968056574478
# Seller's expected utilty:  -0.5520590030664821
#
#
# 0.8835457969629932 0.6779797719319269 1.1804470234846296
# Buyer's expected utilty:  -0.3606448352564167
# Seller's expected utilty:  -0.7564183841599761
#
#
# 0.8758563923426566 0.720414096367032 1.1087686020007848
# Buyer's expected utilty:  -0.31399338754301515
# Seller's expected utilty:  -0.7263145950395568
#
#
# 0.950498791954238 0.5480942516359177 1.1440488038523193
# Buyer's expected utilty:  -0.3574699871222114
# Seller's expected utilty:  -0.7698085837767162
#
#
# 0.8400625678194531 0.965481342161159 1.0535013075835762
# Buyer's expected utilty:  -0.2282163736966557
# Seller's expected utilty:  -0.625534782993724
#
#
# 0.8799243279786135 0.781274819595317 1.013737727169684
# Buyer's expected utilty:  -0.24040229125163934
# Seller's expected utilty:  -0.6772643061196445
#
#
# 0.7790623116712441 0.7193218402580901 1.0319764862514043
# Buyer's expected utilty:  -0.29697769356735815
# Seller's expected utilty:  -0.7312908998684702
#
#
# 0.9059606209259928 0.795084627597805 1.220088228807021
# Buyer's expected utilty:  -0.3577068285709518
# Seller's expected utilty:  -0.7172170082837332
#
#
# 0.8611732806042036 0.5733218299769505 1.0781267487081063
# Buyer's expected utilty:  -0.338311574034247
# Seller's expected utilty:  -0.7777430298324295
# 0.833933097110809 0.8985513163474625 1.0418246763964905
# Buyer's expected utilty:  -0.2437332131089423
# Seller's expected utilty:  -0.6502428849062722
#
#
# 0.5200435771386773 0.916513136928083 1.0864731831470729
# Buyer's expected utilty:  -0.34362905955314765
# Seller's expected utilty:  -0.7780972053257318
#
#
# 0.8835534790466564 0.9683619200569498 1.0154766161757658
# Buyer's expected utilty:  -0.1961571531541447
# Seller's expected utilty:  -0.5907083185647218
#
#
# 0.9955860698278873 0.9194941808655304 1.0600495401569
# Buyer's expected utilty:  -0.2204290857975712
# Seller's expected utilty:  -0.5833683610550985
#
#
# 0.9816904959912129 0.6748451892641494 1.14004625015834
# Buyer's expected utilty:  -0.3128451371804273
# Seller's expected utilty:  -0.718158891513626
#
#
# 0.950433821160318 0.7447210413694274 1.2049039837018891
# Buyer's expected utilty:  -0.3422800404272636
# Seller's expected utilty:  -0.7213831184396423
#
#
# 0.8836425436452828 0.5982007548477505 1.018420647818262
# Buyer's expected utilty:  -0.27993317776865145
# Seller's expected utilty:  -0.7465439930456482
#
#
# 0.8225756578133624 0.8812989749124095 1.0723575749271206
# Buyer's expected utilty:  -0.2738648390272733
# Seller's expected utilty:  -0.6722518621040589
#
#
# 0.7893703886835254 0.9683747459994536 1.2468464268491222
# Buyer's expected utilty:  -0.35616609790360254
# Seller's expected utilty:  -0.7083599435550392
#
#
# 0.9556927761925588 0.6422548547677674 1.035643346460996
# Buyer's expected utilty:  -0.26001410095417077
# Seller's expected utilty:  -0.713670368983568
#
#
# 0.6197511377460192 0.8354712485958791 1.0523032580043894
# Buyer's expected utilty:  -0.3110419440879936
# Seller's expected utilty:  -0.7620933830572099
#
#
# 0.9813223600501481 0.7594788244515587 1.0258954366381015
# Buyer's expected utilty:  -0.2139027632734753
# Seller's expected utilty:  -0.6488464247515645
#
#
# 0.8410327910537065 0.7009411795269874 1.1489123714054181
# Buyer's expected utilty:  -0.3537287062694078
# Seller's expected utilty:  -0.7552182276304072
#
#
# 0.9585311001858312 0.9371573237131061 1.014463675345517
# Buyer's expected utilty:  -0.19717771594373196
# Seller's expected utilty:  -0.5650922322789987
#
#
# 0.6353056564679362 0.9643464302705019 1.153259969377706
# Buyer's expected utilty:  -0.3356152681981655
# Seller's expected utilty:  -0.7441041130151869
#
#
# 0.726735539153509 0.6788732111423426 1.035819515201614
# Buyer's expected utilty:  -0.3270597189923047
# Seller's expected utilty:  -0.7669903792157938
#
#
# 0.6287868911210162 0.9618398961860068 1.1039290729605915
# Buyer's expected utilty:  -0.3064540998877248
# Seller's expected utilty:  -0.7325726859764433
#
#
# 0.9863628991709138 0.6558536914064929 1.2005311114529797
# Buyer's expected utilty:  -0.3497078263709846
# Seller's expected utilty:  -0.7379900711827007
#
#
# 0.7501533505174669 0.7899692102115764 1.1443935322318282
# Buyer's expected utilty:  -0.36036465052967176
# Seller's expected utilty:  -0.74850405700908
#
#
# 0.5886728539050475 0.7674322794556123 1.0108337319490723
# Buyer's expected utilty:  -0.3168040339163072
# Seller's expected utilty:  -0.7860230156938688
#
#
# 0.8289305797720892 0.9801039323519002 1.1081753465872044
# Buyer's expected utilty:  -0.26124347813074117
# Seller's expected utilty:  -0.6401147932575382
#
#
# 0.8822129142101987 0.9833096864078847 1.0685324106290608
# Buyer's expected utilty:  -0.23204888173881888
# Seller's expected utilty:  -0.6063795429890171
#
#
# 0.7709585174148361 0.6488377360155168 1.0220075816174556
# Buyer's expected utilty:  -0.312429409046323
# Seller's expected utilty:  -0.7653519740835915
#
#
# 0.8599755555288199 0.8343490277865172 1.177966054775915
# Buyer's expected utilty:  -0.344072997891593
# Seller's expected utilty:  -0.7004641648817175
#
#
# 0.8385498944583852 0.8228060244831745 1.130916393398182
# Buyer's expected utilty:  -0.3230237497297965
# Seller's expected utilty:  -0.6957129647366462
#
#
# 0.8880411987903998 0.7532173751742546 1.00972111326399
# Buyer's expected utilty:  -0.23028445230695194
# Seller's expected utilty:  -0.6766166316786468
#
#
# 0.8793803807422416 0.8282392954999218 1.0355759990813593
# Buyer's expected utilty:  -0.24624550105335719
# Seller's expected utilty:  -0.6514731927967049
#
#
# 0.6684712930689638 0.8848314462920995 1.0876933013385073
# Buyer's expected utilty:  -0.3046086971897734
# Seller's expected utilty:  -0.733715321522843
#
#
# 0.6614548130066418 0.8649637198193391 1.109687917290628
# Buyer's expected utilty:  -0.32912950988413237
# Seller's expected utilty:  -0.7512951143464135
#
#
# 0.6985119181509272 0.8162435847108047 1.1452969866630702
# Buyer's expected utilty:  -0.3559276708081038
# Seller's expected utilty:  -0.7568175828663665
#
#
# 0.8951539019721934 0.7156724043573419 1.111948201170676
# Buyer's expected utilty:  -0.3105797029690801
# Seller's expected utilty:  -0.7237836083436693
#
#
# 0.8146537173044214 0.9218955612326518 1.02023329205565
# Buyer's expected utilty:  -0.22392493432461477
# Seller's expected utilty:  -0.6440142407767009
#
#
# 0.9798301760871968 0.639722520814294 1.2142295724918177
# Buyer's expected utilty:  -0.3611993938800766
# Seller's expected utilty:  -0.7449071225767203
#
#
# 0.9472502809486685 0.7922475568781702 1.16345344638488
# Buyer's expected utilty:  -0.3182198917667389
# Seller's expected utilty:  -0.6944485728693531
#
#
# 0.8170656883932987 0.9917676307006986 1.0514629063265817
# Buyer's expected utilty:  -0.22454681437779894
# Seller's expected utilty:  -0.6296399846360202
#
#
# 0.8663706742929533 0.9618074782389547 1.165035595439562
# Buyer's expected utilty:  -0.29683304771255536
# Seller's expected utilty:  -0.6463977188451084
#
#
# 0.947004573863059 0.5333398933547038 1.0641573674255982
# Buyer's expected utilty:  -0.3171390405073584
# Seller's expected utilty:  -0.7572270095067847
#
#
# 0.8245973471825447 0.7775818568270119 1.006683978860069
# Buyer's expected utilty:  -0.25245325148755304
# Seller's expected utilty:  -0.6859498786316396
#
#
# 0.9237624607272799 0.5007563620142292 1.0888436308952438
# Buyer's expected utilty:  -0.34645522400409157
# Seller's expected utilty:  -0.7766193743830513
#
#
# 0.7269038121684284 0.7325121952524686 1.0401871770653082
# Buyer's expected utilty:  -0.32061099951233685
# Seller's expected utilty:  -0.7459451240921557
#
#
# 0.8960357007875753 0.5849900488573112 1.0633450957030455
# Buyer's expected utilty:  -0.30947548039279404
# Seller's expected utilty:  -0.7584938361052609
#
#
# 0.731598595371852 0.9743214288721995 1.1402643879858474
# Buyer's expected utilty:  -0.3029438740503712
# Seller's expected utilty:  -0.6987520727130231
#
#
# 0.761682439292152 0.819079498165123 1.09112201163441
# Buyer's expected utilty:  -0.31467027676605575
# Seller's expected utilty:  -0.7222034623480132
#
#
# 0.8594194647992871 0.7793316047988748 1.2009558795605975
# Buyer's expected utilty:  -0.36107642538688844
# Seller's expected utilty:  -0.7275176889922705
#
#
# 0.9531288628666499 0.8611900053630153 1.0155271225419908
# Buyer's expected utilty:  -0.2011705458209056
# Seller's expected utilty:  -0.6066941984441758
#
#
# 0.8917428861427135 0.9001937347925412 1.1752541972855883
# Buyer's expected utilty:  -0.3248461344732389
# Seller's expected utilty:  -0.6612709167916953
#
#
# 0.7305468802487161 0.9221706445151554 1.2135940161634493
# Buyer's expected utilty:  -0.3594150721110768
# Seller's expected utilty:  -0.7346583777565258
#
#
# 0.8419967692564743 0.9791809961669953 1.259229169301734
# Buyer's expected utilty:  -0.3500904761411916
# Seller's expected utilty:  -0.6821213711308761
#
#
# 0.5143292856922765 0.9570762812338005 1.0300419719221965
# Buyer's expected utilty:  -0.2994095837195238
# Seller's expected utilty:  -0.7543977111617567
#
#
# 0.9537049113798497 0.8854576380844676 1.0806379926157175
# Buyer's expected utilty:  -0.2457313288338175
# Seller's expected utilty:  -0.6160632744757878
#
#
# 0.7343012965365812 0.6348076132011325 1.0665240607664093
# Buyer's expected utilty:  -0.3485758507110418
# Seller's expected utilty:  -0.7841429116294591
#
#
# 0.7343047125438816 0.781910529114024 1.137762646345387
# Buyer's expected utilty:  -0.3566361373174608
# Seller's expected utilty:  -0.7498369572031593
#
#
# 0.9716459568371618 0.561792406171806 1.0709979800352956
# Buyer's expected utilty:  -0.30330839256857955
# Seller's expected utilty:  -0.7408764579685795
#
#
# 0.8622678647144644 0.8997967664489925 1.0082967892681662
# Buyer's expected utilty:  -0.21237450245264328
# Seller's expected utilty:  -0.617396919243183
#
#
# 0.9919427867635235 0.7154290589135965 1.1042305540250679
# Buyer's expected utilty:  -0.27630087220783356
# Seller's expected utilty:  -0.6896908762886154
# 0.9730691087773393 0.9075649725196675 1.1272725893111721
# Buyer's expected utilty:  -0.2699649415315267
# Seller's expected utilty:  -0.6155786199573792
#
#
# 0.9548358769243545 0.5863168692126199 1.053078588011331
# Buyer's expected utilty:  -0.29121249991626696
# Seller's expected utilty:  -0.7379639050727135
#
#
# 0.784620805661947 0.6715803309299198 1.0197917351002188
# Buyer's expected utilty:  -0.2979773246410791
# Seller's expected utilty:  -0.7530711602002972
#
#
# 0.8304881322908089 0.9980802723442554 1.0188489662799112
# Buyer's expected utilty:  -0.19525243102437545
# Seller's expected utilty:  -0.6101305479977999
#
#
# 0.8066875837223163 0.8593190227944665 1.0809051105978054
# Buyer's expected utilty:  -0.28745214674119485
# Seller's expected utilty:  -0.6846116040367749
#
#
# 0.8461925234980348 0.7335458575432976 1.108683203092443
# Buyer's expected utilty:  -0.320073087733724
# Seller's expected utilty:  -0.7291623234566452
#
#
# 0.6514084828692502 0.829349665065846 1.0640009197509694
# Buyer's expected utilty:  -0.3109470754242351
# Seller's expected utilty:  -0.7545109531212436
#
#
# 0.9879438970853018 0.6461481387038599 1.029484905620136
# Buyer's expected utilty:  -0.24227969203605276
# Seller's expected utilty:  -0.6940959823565735
#
#
# 0.8673439812321554 0.821418554158081 1.150680777184017
# Buyer's expected utilty:  -0.3259859308815931
# Seller's expected utilty:  -0.6945369325569387
#
#
# 0.8697287901785373 0.9948768478379793 1.2180430472159647
# Buyer's expected utilty:  -0.32246552543375334
# Seller's expected utilty:  -0.6554808432416435
#
#
# 0.8497933590178659 0.5885388567736638 1.0955312391315475
# Buyer's expected utilty:  -0.34332579907676447
# Seller's expected utilty:  -0.778845082494386
#
#
# 0.8720731008956935 0.8737707931660941 1.154336470085744
# Buyer's expected utilty:  -0.3242667117107723
# Seller's expected utilty:  -0.6729941609437436
#
#
# 0.7649763083452661 0.958326261039163 1.1755227245737605
# Buyer's expected utilty:  -0.31696214233810416
# Seller's expected utilty:  -0.6986568243613195
#
#
# 0.9336025080549303 0.8567480533070686 1.1062077428694865
# Buyer's expected utilty:  -0.2720707370566696
# Seller's expected utilty:  -0.6456071773801064
#
#
# 0.8557741784026605 0.9865119301262195 1.0920344802637105
# Buyer's expected utilty:  -0.24797799240442225
# Seller's expected utilty:  -0.6259853037276706
#
#
# 0.7939403667734495 0.8618807287623507 1.0411539573424342
# Buyer's expected utilty:  -0.26338446785110403
# Seller's expected utilty:  -0.6827441242553516
#
#
# 0.9671625211950892 0.731707904162628 1.0066756885428818
# Buyer's expected utilty:  -0.21416214160499406
# Seller's expected utilty:  -0.6665152919061005
#
#
# 0.781680906113655 0.737398266388998 1.0673701013806367
# Buyer's expected utilty:  -0.31801437794437615
# Seller's expected utilty:  -0.7362309723672718
#
#
# 0.6992219030648046 0.8241170058191705 1.0381019086287266
# Buyer's expected utilty:  -0.29078212711116264
# Seller's expected utilty:  -0.7335189760607682
#
#
# 0.8704949989585014 0.9315078148255498 1.006613537755567
# Buyer's expected utilty:  -0.20535163410281723
# Seller's expected utilty:  -0.6121238144430313
#
#
# 0.7189547535950191 0.9502317663171553 1.2283857359853558
# Buyer's expected utilty:  -0.36032505488008015
# Seller's expected utilty:  -0.7330606643645586
#
#
# 0.7347659278862303 0.8143486614015383 1.0708028296636916
# Buyer's expected utilty:  -0.308384207101959
# Seller's expected utilty:  -0.7302314717516725
#
#
# 0.5973464892718481 0.9825762135521989 1.1042413740104107
# Buyer's expected utilty:  -0.3152993401327033
# Seller's expected utilty:  -0.7394852112423246
#
#
# 0.8336260751784437 0.5273686035993679 1.0006261972754695
# Buyer's expected utilty:  -0.30854745755968704
# Seller's expected utilty:  -0.7813878007938206
#
#
# 0.7324629749083353 0.7842845359214421 1.1384149450690664
# Buyer's expected utilty:  -0.35891014264097526
# Seller's expected utilty:  -0.749890103578197
#
#
# 0.6382138027908358 0.9076298422001243 1.0473712164640432
# Buyer's expected utilty:  -0.277913334283292
# Seller's expected utilty:  -0.7304056822520795
#
#
# 0.8121046046763857 0.8438133506409359 1.0519195974841091
# Buyer's expected utilty:  -0.27336944903215293
# Seller's expected utilty:  -0.6769650069430847
#
#
# 0.9388484623247695 0.6534577353396439 1.0099617557202039
# Buyer's expected utilty:  -0.2426402749253384
# Seller's expected utilty:  -0.7058810038248559
#
#
# 0.7562236233808663 0.8516883847475663 1.0877022333617479
# Buyer's expected utilty:  -0.30074976204121384
# Seller's expected utilty:  -0.7113871301154531
#
#
# 0.8720084413625873 0.7867195156975724 1.029537739648342
# Buyer's expected utilty:  -0.2493238335819262
# Seller's expected utilty:  -0.677821936037153
#
#
# 0.9961507679807966 0.7050599717501458 1.1774030804560147
# Buyer's expected utilty:  -0.3210654019188304
# Seller's expected utilty:  -0.7113803184961229
#
#
# 0.9900386988990192 0.632142431903977 1.1405011003887342
# Buyer's expected utilty:  -0.3186441021820744
# Seller's expected utilty:  -0.7332752034292371
#
#
# 0.9313526756772862 0.835678920623987 1.1188984276438214
# Buyer's expected utilty:  -0.28132644761042797
# Seller's expected utilty:  -0.6592253912758368
#
#
# 0.8681025668704063 0.7539397284865165 1.1754795672572433
# Buyer's expected utilty:  -0.3520553832224555
# Seller's expected utilty:  -0.7335157565682289
#
#
# 0.9070773949542302 0.527020710422951 1.05051490669424
# Buyer's expected utilty:  -0.3200673579770412
# Seller's expected utilty:  -0.7683032443854342
#
#
# 0.7709739928450539 0.9623166211817586 1.036346797466474
# Buyer's expected utilty:  -0.23096895017105243
# Seller's expected utilty:  -0.6619851608652954
#
#
# 0.8057323885652604 0.5681195959898155 1.0388021447562497
# Buyer's expected utilty:  -0.32905309811483324
# Seller's expected utilty:  -0.7868925150978935
#
#
# 0.8268858378852111 0.8650609070318689 1.0045360155311465
# Buyer's expected utilty:  -0.22850560239548307
# Seller's expected utilty:  -0.6496833736345371
#
#
# 0.8401206178011902 0.9411790385145795 1.1412421688427452
# Buyer's expected utilty:  -0.29084903849198196
# Seller's expected utilty:  -0.6576271768204465
#
#
# 0.6885969678906516 0.8442601781271705 1.0203009112032784
# Buyer's expected utilty:  -0.2728249307913675
# Seller's expected utilty:  -0.7252018798614537
#
#
# 0.9183708123698976 0.7376177048477075 1.0168718835328896
# Buyer's expected utilty:  -0.23167224115106774
# Seller's expected utilty:  -0.6807038925920603
#
#
# 0.8377029618474857 0.9386796203619496 1.233519758979464
# Buyer's expected utilty:  -0.3485425510686667
# Seller's expected utilty:  -0.6924202665109394
#
#
# 0.8566540912245995 0.7748233411152525 1.0193466499022896
# Buyer's expected utilty:  -0.24836067697763378
# Seller's expected utilty:  -0.6803092098800919
#
#
# 0.732349577467613 0.9528863567738957 1.1865046069991174
# Buyer's expected utilty:  -0.3374931316773498
# Seller's expected utilty:  -0.7204242602971039
#
#
# 0.8540947088854145 0.8171879357549106 1.0431207263668998
# Buyer's expected utilty:  -0.264430703580552
# Seller's expected utilty:  -0.6721754646163831
#
#
# 0.72957185280244 0.9553464814344019 1.151817807297497
# Buyer's expected utilty:  -0.3153623931599811
# Seller's expected utilty:  -0.7093993840616065
#
#
# 0.989072789895521 0.65105492775719 1.0682647844379969
# Buyer's expected utilty:  -0.27107610053084646
# Seller's expected utilty:  -0.7067775637163267
#
#
# 0.9767493076493876 0.7472127719275645 1.1336698873209117
# Buyer's expected utilty:  -0.29350368890503853
# Seller's expected utilty:  -0.6921098574249686
#
#
# 0.9263335156668997 0.9733247413166222 1.190636449550132
# Buyer's expected utilty:  -0.30950396657697443
# Seller's expected utilty:  -0.6260181627105128
#
#
# 0.9183368456235617 0.6243547495323238 1.0262300732954852
# Buyer's expected utilty:  -0.26755363495096385
# Seller's expected utilty:  -0.7289305529991019
#
#
# 0.9315031198875395 0.8712318407663737 1.1566519123823165
# Buyer's expected utilty:  -0.30176213243011074
# Seller's expected utilty:  -0.6516951497641271
#
#
# 0.6696929266794915 0.952146735906023 1.1631050970562187
# Buyer's expected utilty:  -0.3341860186468002
# Seller's expected utilty:  -0.7358785970601364
#
#
# 0.8210417692234676 0.9716598594837138 1.1755126438318826
# Buyer's expected utilty:  -0.30742315116130575
# Seller's expected utilty:  -0.6676645809577236
#
#
# 0.9167458743473207 0.8926461151041936 1.1573676594591
# Buyer's expected utilty:  -0.30961355566770093
# Seller's expected utilty:  -0.6500642384615929
# 0.8553542671280898 0.9173669295466076 1.0758013321698783
# Buyer's expected utilty:  -0.26044849673512654
# Seller's expected utilty:  -0.6444362007258122
#
#
# 0.7699654114632672 0.8568361704464804 1.1417856089855687
# Buyer's expected utilty:  -0.3332232560235148
# Seller's expected utilty:  -0.7256175618828534
#
#
# 0.8469876145734803 0.6058079167245058 1.0179242073124406
# Buyer's expected utilty:  -0.28869914257188234
# Seller's expected utilty:  -0.7531020924987989
#
#
# 0.7843946488274203 0.9339199834468604 1.1522520518732375
# Buyer's expected utilty:  -0.31256682965827326
# Seller's expected utilty:  -0.6935903598881562
#
#
# 0.591299751540358 0.810120371706028 1.0618057211597087
# Buyer's expected utilty:  -0.33704639558156524
# Seller's expected utilty:  -0.7858000288069192
#
#
# 0.7768530733183425 0.7633634423027014 1.0961003769567141
# Buyer's expected utilty:  -0.33068729499219124
# Seller's expected utilty:  -0.7301096608012924
#
#
# 0.5352759326194139 0.9610770180034586 1.13267139781351
# Buyer's expected utilty:  -0.3515031365907538
# Seller's expected utilty:  -0.7648174429458812
#
#
# 0.602005504355292 0.7795901240077663 1.0171486386795234
# Buyer's expected utilty:  -0.31491108750656793
# Seller's expected utilty:  -0.780937727150621
#
#
# 0.851716290649694 0.5758000729456987 1.0284730065318286
# Buyer's expected utilty:  -0.30540345824009835
# Seller's expected utilty:  -0.7682804166353299
#
#
# 0.9821788776746263 0.9442392871303132 1.0888583522444908
# Buyer's expected utilty:  -0.24481400040560333
# Seller's expected utilty:  -0.5812533166017739
#
#
# 0.8392648770803295 0.9140872188154581 1.1815924190246188
# Buyer's expected utilty:  -0.3256319364596089
# Seller's expected utilty:  -0.6818815975912764
#
#
# 0.8994906196082029 0.8213414769395145 1.144556895150614
# Buyer's expected utilty:  -0.3148057856017939
# Seller's expected utilty:  -0.6875464360616501
#
#
# 0.785467531385761 0.8861763915700633 1.1578050163280045
# Buyer's expected utilty:  -0.3285395411722353
# Seller's expected utilty:  -0.7103789692025447
#
#
# 0.6739765413556738 0.9135893953166472 1.050854940981884
# Buyer's expected utilty:  -0.27797809136782026
# Seller's expected utilty:  -0.7225160972300345
#
#
# 0.5747574748786246 0.9773416810500498 1.1034865244893246
# Buyer's expected utilty:  -0.3228209362312981
# Seller's expected utilty:  -0.7456169543526042
#
#
# 0.8030735092305423 0.8837448920591995 1.1276283503159705
# Buyer's expected utilty:  -0.31026240285484885
# Seller's expected utilty:  -0.6946767272168839
#
#
# 0.666932653720157 0.7693234806621059 1.1071369861423421
# Buyer's expected utilty:  -0.36000508908414486
# Seller's expected utilty:  -0.7781090265909397
#
#
# 0.8491080124123683 0.6721651772907717 1.0643553376026986
# Buyer's expected utilty:  -0.3047743872601437
# Seller's expected utilty:  -0.7437163720827067
#
#
# 0.9749647220228415 0.8440113327068377 1.1122696388633626
# Buyer's expected utilty:  -0.2677962072158467
# Seller's expected utilty:  -0.6463964896594709
#
#
# 0.7121851572713065 0.8585868872989304 1.1772006203922558
# Buyer's expected utilty:  -0.35813921298387186
# Seller's expected utilty:  -0.747103819772391
#
#
# 0.8341447040662913 0.9596035667011154 1.1527516328502911
# Buyer's expected utilty:  -0.2945213178911407
# Seller's expected utilty:  -0.6611247982794166
#
#
# 0.8767410234643458 0.9304998156769231 1.2033823229696794
# Buyer's expected utilty:  -0.3319003805810394
# Seller's expected utilty:  -0.6683510602487238
#
#
# 0.9374460953886301 0.7483846463938861 1.0841173810233735
# Buyer's expected utilty:  -0.27746775601676615
# Seller's expected utilty:  -0.6912536725500337
#
#
# 0.9987387010114053 0.7802212318877055 1.1264357405591081
# Buyer's expected utilty:  -0.2772373348857144
# Seller's expected utilty:  -0.6683055267629955
#
#
# 0.906455848353561 0.6483233157867232 1.059970648858112
# Buyer's expected utilty:  -0.2887212921476126
# Seller's expected utilty:  -0.7350420511719551
#
#
# 0.9220095748820223 0.9461608269908113 1.1221485700695426
# Buyer's expected utilty:  -0.2727459015749314
# Seller's expected utilty:  -0.6114574867825019
#
#
# 0.6998540224508148 0.9808034014654887 1.170862509872424
# Buyer's expected utilty:  -0.3239711986909185
# Seller's expected utilty:  -0.7163346569061846
#
#
# 0.9816096514077846 0.9087183028331727 1.1438172887037297
# Buyer's expected utilty:  -0.274588817306569
# Seller's expected utilty:  -0.6150809472921377
#
#
# 0.9609069772322961 0.8639714538444127 1.1234117807087087
# Buyer's expected utilty:  -0.2768943360598276
# Seller's expected utilty:  -0.6413798191126167
#
#
# 0.5261825848300934 0.9485039452783415 1.138646427321682
# Buyer's expected utilty:  -0.36123023617377453
# Seller's expected utilty:  -0.7749544522136818
#
#
# 0.963217357945594 0.8026937384690446 1.2076422948298275
# Buyer's expected utilty:  -0.3294716117632103
# Seller's expected utilty:  -0.6873631773230725
#
#
# 0.9486001202193285 0.7910624466478497 1.1502827018233481
# Buyer's expected utilty:  -0.3016617186183356
# Seller's expected utilty:  -0.6819808275576793
#
#
# 0.8971669157020536 0.6725234961558293 1.0023239232090257
# Buyer's expected utilty:  -0.24507646807458827
# Seller's expected utilty:  -0.7126528931699414
#
#
# 0.7496726131550588 0.9122719351082911 1.1430970656360815
# Buyer's expected utilty:  -0.31712394465878974
# Seller's expected utilty:  -0.7147872197691485
#
#
# 0.924595696772469 0.9947522285512135 1.0246749335927052
# Buyer's expected utilty:  -0.1938595738886303
# Seller's expected utilty:  -0.5657824823228057
#
#
# 0.9642152008546805 0.8270190010587251 1.0375361480100285
# Buyer's expected utilty:  -0.22047863620398195
# Seller's expected utilty:  -0.6298624353900856
#
#
# 0.7382265429297903 0.8441399298474708 1.0163110384775293
# Buyer's expected utilty:  -0.26042548628053774
# Seller's expected utilty:  -0.7069913242253724
#
#
# 0.9957579565447683 0.5422102014950819 1.0672773519885137
# Buyer's expected utilty:  -0.29847312623612676
# Seller's expected utilty:  -0.735161607068019
#
#
# 0.8781640799989461 0.9846361787652965 1.0098478067399008
# Buyer's expected utilty:  -0.1847439409375222
# Seller's expected utilty:  -0.5819695973297073
#
#
# 0.813583974579056 0.6910836095952038 1.0482469995404626
# Buyer's expected utilty:  -0.29841771763311736
# Seller's expected utilty:  -0.7410149389250833
#
#
# 0.9128400641519752 0.7268889931860891 1.0267395250315732
# Buyer's expected utilty:  -0.24752917644904465
# Seller's expected utilty:  -0.6937175004566057
#
#
# 0.9490018765820887 0.6033744727246633 1.0578144330738404
# Buyer's expected utilty:  -0.2902335019957001
# Seller's expected utilty:  -0.7367454148884084
#
#
# 0.8691547375802001 0.8901282499738954 1.110990723154571
# Buyer's expected utilty:  -0.29243073539688386
# Seller's expected utilty:  -0.6581256672740776
#
#
# 0.8950027689450708 0.7316406730526865 1.0120804905087564
# Buyer's expected utilty:  -0.23989704728189457
# Seller's expected utilty:  -0.6911565042438508
#
#
# 0.9828754050443285 0.6967217854440066 1.0335937281366605
# Buyer's expected utilty:  -0.23708570797641518
# Seller's expected utilty:  -0.6790525697395821
#
#
# 0.913041997888006 0.9400393271630454 1.2646133764232164
# Buyer's expected utilty:  -0.35819460689245186
# Seller's expected utilty:  -0.6613394629866892
#
#
# 0.7237766766959066 0.7798980240213567 1.0355431364177676
# Buyer's expected utilty:  -0.30237084139404946
# Seller's expected utilty:  -0.7354792321385063
#
#
# 0.956438299456399 0.6357016288930819 1.1034712800655353
# Buyer's expected utilty:  -0.30271360566578315
# Seller's expected utilty:  -0.7277953285366885

# %% [markdown]
# ### Theoretical equilibrium when buyer places same bids and seller palces different asks both the items

# %%
alpha_b1 = 0.666667;
alpha_b2 = 0.666667;

alpha_s1 = 1.0;
alpha_s2 = 1.0;

theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
theta_s, S = seller_strategy(alpha_s1, alpha_s2)

cp_list, cq_list = auction_clearing(B, S)

U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
U_s = seller_expected_utility(theta_s, cp_list, cq_list)

print("Buyer's expected utilty: ", U_b)
print("Seller's expected utilty: ", U_s)

best_Ub3 = U_b
best_Us3 = U_s
# Out:
# Buyer's expected utilty:  -0.3307639376969103
# Seller's expected utilty:  -0.7769245063941405

# %%
# Checking if some randomly selected scaler values can yeild better utility

for i in range(100):
    
    alpha_b1 = np.random.uniform(0.5, 1, 1)[0];
    alpha_b2 = alpha_b1;

    alpha_s1 = np.random.uniform(1, 1.5, 1)[0];
    alpha_s2 = np.random.uniform(1, 1.5, 1)[0];

    theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
    theta_s, S = seller_strategy(alpha_s1, alpha_s2)

    cp_list, cq_list = auction_clearing(B, S)

    U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
    U_s = seller_expected_utility(theta_s, cp_list, cq_list)

    if((U_b >= best_Ub3) and (U_s >= best_Us3)):
        print(alpha_b1, alpha_s1)
        print("Buyer's expected utilty: ", U_b)
        print("Seller's expected utilty: ", U_s)
        print("\n")
# Out:
# 0.8216292981790505 1.124383980494511
# Buyer's expected utilty:  -0.32005034148245537
# Seller's expected utilty:  -0.693731164237486
#
#
# 0.9582081327562237 1.3808255495275592
# Buyer's expected utilty:  -0.32047992944658277
# Seller's expected utilty:  -0.5944743931216954
#
#
# 0.9403681856133981 1.1694390004181021
# Buyer's expected utilty:  -0.3154541108019348
# Seller's expected utilty:  -0.6253184202519583
#
#
# 0.8844071168510028 1.0493155152801568
# Buyer's expected utilty:  -0.27024709244086825
# Seller's expected utilty:  -0.6342626489524943
#
#
# 0.8978332647463415 1.2384567707031893
# Buyer's expected utilty:  -0.297492994375341
# Seller's expected utilty:  -0.6286631390545393
#
#
# 0.9745724020235115 1.136530895283189
# Buyer's expected utilty:  -0.25632993221033945
# Seller's expected utilty:  -0.5664785234323229
#
#
# 0.8862966724734156 1.0164012834532272
# Buyer's expected utilty:  -0.3218702728281591
# Seller's expected utilty:  -0.6447161157611486
#
#
# 0.9943281242324176 1.0143044670545267
# Buyer's expected utilty:  -0.21240486216909882
# Seller's expected utilty:  -0.5236307624989062
#
#
# 0.9301171531964783 1.2056972170985016
# Buyer's expected utilty:  -0.3280328578950969
# Seller's expected utilty:  -0.6392710137780846
#
#
# 0.9920687810541986 1.103418453880807
# Buyer's expected utilty:  -0.28044913963046814
# Seller's expected utilty:  -0.5659063623189664
#
#
# 0.896892214003997 1.0328565401808345
# Buyer's expected utilty:  -0.3275332054072517
# Seller's expected utilty:  -0.642793472811007
#
#
# 0.9348011865288629 1.0120588009648928
# Buyer's expected utilty:  -0.21524975421679066
# Seller's expected utilty:  -0.5736131331780793
#
#
# 0.8609158902914046 1.1843279334644092
# Buyer's expected utilty:  -0.31453994723474044
# Seller's expected utilty:  -0.6640210524485843
#
#
# 0.8667057121411091 1.2030902047791119
# Buyer's expected utilty:  -0.2937971646358966
# Seller's expected utilty:  -0.6463774455993279

# %% [markdown]
# ### Theoretical equilibrium when buyer/seller places two different bids/asks both the items

# %%
alpha_b1 = 0.882782;
alpha_b2 = 0.588521;

alpha_s1 = 1.2207;
alpha_s2 = 1.10806;

theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
theta_s, S = seller_strategy(alpha_s1, alpha_s2)

cp_list, cq_list = auction_clearing(B, S)

U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
U_s = seller_expected_utility(theta_s, cp_list, cq_list)

print("Buyer's expected utilty: ", U_b)
print("Seller's expected utilty: ", U_s)

best_Ub4 = U_b
best_Us4 = U_s
# Out:
# Buyer's expected utilty:  -0.3703891595392058
# Seller's expected utilty:  -0.7751464348196148

# %%
# Checking if some randomly selected scaler values can yeild better utility

for i in range(100):
    
    alpha_b1 = np.random.uniform(0.5, 1, 1)[0];
    alpha_b2 = np.random.uniform(0.5, 1, 1)[0];

    alpha_s1 = np.random.uniform(1, 1.5, 1)[0];
    alpha_s2 = np.random.uniform(1, 1.5, 1)[0];

    theta_b, B = buyer_strategy(alpha_b1, alpha_b2)
    theta_s, S = seller_strategy(alpha_s1, alpha_s2)

    cp_list, cq_list = auction_clearing(B, S)

    U_b = buyer_expected_utility(theta_b, cp_list, cq_list)
    U_s = seller_expected_utility(theta_s, cp_list, cq_list)

    if((U_b >= best_Ub4) and (U_s >= best_Us4)):
        print(alpha_b1, alpha_b2, alpha_s1, alpha_s2)
        print("Buyer's expected utilty: ", U_b)
        print("Seller's expected utilty: ", U_s)
        print("\n")
# Out:
# 0.8966550066912263 0.8128540310272295 1.060557141431318 1.154790878049487
# Buyer's expected utilty:  -0.2950439886928466
# Seller's expected utilty:  -0.6742676157799635
#
#
# 0.7726953024842498 0.9835699348145565 1.3418064740050668 1.1102749603321524
# Buyer's expected utilty:  -0.3411123724401007
# Seller's expected utilty:  -0.6852378652107332
#
#
# 0.6600852349240813 0.9619039312840894 1.027514337071051 1.189498412839027
# Buyer's expected utilty:  -0.3008553977159123
# Seller's expected utilty:  -0.7081806177202306
#
#
# 0.9569135697511751 0.6022187888356076 1.1152399618238917 1.3144826729712618
# Buyer's expected utilty:  -0.37000053523763504
# Seller's expected utilty:  -0.7468894090668338
#
#
# 0.5397134265359232 0.8806532537420041 1.022922397215561 1.0127122051421844
# Buyer's expected utilty:  -0.3039130098811508
# Seller's expected utilty:  -0.7703635800286772
#
#
# 0.9521272943382353 0.6492769202462123 1.2111470661005468 1.0156841879031684
# Buyer's expected utilty:  -0.30507778877349745
# Seller's expected utilty:  -0.7121644807957538
#
#
# 0.6374825775713049 0.9868295201671582 1.0794392017912962 1.204174494260804
# Buyer's expected utilty:  -0.3173307211227734
# Seller's expected utilty:  -0.7179963088063875
#
#
# 0.6541444029799914 0.952451053980925 1.0987891259127565 1.3445644864850785
# Buyer's expected utilty:  -0.3627036964898148
# Seller's expected utilty:  -0.73043428986387
#
#
# 0.8315972432189536 0.6069293588063687 1.014551148286041 1.075326520756295
# Buyer's expected utilty:  -0.31496672613197835
# Seller's expected utilty:  -0.7632556962597061
#
#
# 0.7924456503862203 0.9399776685278634 1.098013778671375 1.3992192216262915
# Buyer's expected utilty:  -0.35785432855917143
# Seller's expected utilty:  -0.6902583641724843
#
#
# 0.507100056625207 0.9820762034196541 1.0754370365686383 1.082420048496759
# Buyer's expected utilty:  -0.3217092955591874
# Seller's expected utilty:  -0.7503247592264373
#
#
# 0.9690747351713742 0.5566731211052696 1.147168496244118 1.160133937956799
# Buyer's expected utilty:  -0.3551243928443588
# Seller's expected utilty:  -0.7632237125982722
#
#
# 0.6193382046390012 0.9171610015845448 1.4090456799259798 1.001937027737141
# Buyer's expected utilty:  -0.3629095286721608
# Seller's expected utilty:  -0.740878405954192
#
#
# 0.8349514804324829 0.986392452668029 1.1816262119224827 1.3737275060909608
# Buyer's expected utilty:  -0.36287693928907555
# Seller's expected utilty:  -0.6778443518312937
#
#
# 0.9561318214943257 0.5948477723181445 1.1387037372024484 1.1221735402319848
# Buyer's expected utilty:  -0.332962758195535
# Seller's expected utilty:  -0.7477125746270343
#
#
# 0.8113334386711036 0.7192537244381556 1.1995104122384546 1.0310068982229683
# Buyer's expected utilty:  -0.3427230658548935
# Seller's expected utilty:  -0.7401747205421783
#
#
# 0.9238219203933586 0.5229495111864444 1.32437951454034 1.0047955295298914
# Buyer's expected utilty:  -0.3679569507154237
# Seller's expected utilty:  -0.7603565386056099
#
#
# 0.9208333460498808 0.9476645199094909 1.3293121141454924 1.1268972386379899
# Buyer's expected utilty:  -0.33929612614123106
# Seller's expected utilty:  -0.6345494819841863
#
#
# 0.9641064046255243 0.5700962592192635 1.2211983183372104 1.0700220912748293
# Buyer's expected utilty:  -0.3420471940806963
# Seller's expected utilty:  -0.7456779591321698
#
#
# 0.8315881116991635 0.8439331904534748 1.004108302040911 1.3814139814761346
# Buyer's expected utilty:  -0.3518411728238832
# Seller's expected utilty:  -0.6859377266136868
#
#
# 0.7305373587410289 0.9819017903239713 1.3560911584641255 1.0658597515758585
# Buyer's expected utilty:  -0.33914531908738993
# Seller's expected utilty:  -0.6951995553055886
