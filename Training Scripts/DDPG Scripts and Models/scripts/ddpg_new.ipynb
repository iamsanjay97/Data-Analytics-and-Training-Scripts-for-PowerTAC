# %%
import sys

from powertac_wm import PowerTAC_WM
import gym
import datetime
import json
import numpy as np
import pandas as pd

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

from ReplayBuffer import ReplayBuffer
from ActorNetwork import ActorNetwork
from CriticNetwork import CriticNetwork
from OU import OU
# Out:
# WARNING:tensorflow:From /home/sanjay/anaconda3/envs/powertac_ddpg/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
model_storage_path = "ddpg_v1.0"

# %%
BUFFER_SIZE = 100000
BATCH_SIZE = 64
EPOCHS = 1000
GAMMA = 0.99
TAU = 0.001     #Target Network HyperParameters
LRA = 0.0001    #Learning rate for Actor
LRC = 0.001     #Lerning rate for Critic

'''
Action : [
           limitprice1 belongs to R
           limitprice2 belongs to R
         ] (TWO output nuerons)
'''
action_dim = 2

'''
State : [
          Proximity (24)
          Required_Quantity (1)
        ] (total 25 input nuerons)
'''
state_dim = 25

np.random.seed(1337)
EXPLORE = 100000.0

step = 0
epsilon = 1

ou = OU()       #Ornstein-Uhlenbeck Process

# %%
config = tf.ConfigProto(
    device_count={'GPU': 1},
    intra_op_parallelism_threads=1,
    allow_soft_placement=True
)

config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.6

session = tf.Session(config=config)

# %%
actor = ActorNetwork(session, state_dim, action_dim, BATCH_SIZE, TAU, LRA)
critic = CriticNetwork(session, state_dim, action_dim, BATCH_SIZE, TAU, LRC)

data_storage_path = "/mnt/d/PowerTAC/PowerTAC2021/training_scripts/ddpg_data_scripts_and_models/data/new_with_two_limit_prices_2609/similar_to_ddpg_v1"
replay_buffer = pd.read_csv(data_storage_path + '/replay_buffer_2.csv', header=None)
# Out:
# WARNING:tensorflow:From /mnt/d/PowerTAC/PowerTAC2021/training_scripts/ddpg_data_scripts_and_models/scripts/ActorNetwork.py:21: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# dense (Dense)                (None, 400)               10400
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               120300
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 602
# _________________________________________________________________
# concatenate (Concatenate)    (None, 2)                 0
# =================================================================
# Total params: 131,302
# Trainable params: 131,302
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 25)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 400)               10400
# _________________________________________________________________
# dense_4 (Dense)              (None, 300)               120300
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 602
# _________________________________________________________________
# concatenate_1 (Concatenate)  (None, 2)                 0
# =================================================================
# Total params: 131,302
# Trainable params: 131,302
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/sanjay/anaconda3/envs/powertac_ddpg/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py:247: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 400)          10400       input_3[0][0]
# __________________________________________________________________________________________________
# action2 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 300)          120300      dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 300)          900         action2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 300)          0           dense_8[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 300)          90300       add[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            301         dense_9[0][0]
# ==================================================================================================
# Total params: 222,201
# Trainable params: 222,201
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 400)          10400       input_4[0][0]
# __________________________________________________________________________________________________
# action2 (InputLayer)            [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 300)          120300      dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 300)          900         action2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 300)          0           dense_13[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 300)          90300       add_1[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            301         dense_14[0][0]
# ==================================================================================================
# Total params: 222,201
# Trainable params: 222,201
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
replay_buffer.shape
# Out:
# (9705, 54)

# %%
def train_ddpg_network():

    for epoch in range(EPOCHS):

        print("Epoch ", (epoch+1))
        print("-"*12)
        loss = 0

        #Do the batch update
        batch = replay_buffer.sample(n=BATCH_SIZE)
        states = np.asarray(batch[batch.columns[0:25]])
        actions = np.asarray(batch[batch.columns[25:27]])
        rewards = np.asarray(batch[batch.columns[27:28]])
        new_states = np.asarray(batch[batch.columns[28:53]])
        terminals = np.asarray(batch[batch.columns[53:54]])

        y_t = np.zeros([BATCH_SIZE,1])

        print("States", states.shape)
        print("Actions", actions.shape)
        print("Rewards", rewards.shape)
        print("New_States", new_states.shape)

        with session.as_default():
            with session.graph.as_default():

                target_q_values = critic.target_model.predict([new_states, actor.target_model.predict(new_states)])
                # print("Target_Q_Values", target_q_values.shape)

                for k in range(BATCH_SIZE):
                    if terminals[k] == 1:
                        y_t[k] = rewards[k]
                    else:
                        y_t[k] = rewards[k] + GAMMA*target_q_values[k]

                # print("Bellman Rewards", y_t)
                loss += critic.model.train_on_batch([states,actions], y_t)
                print("Loss", loss)
                a_for_grad = actor.model.predict(states)      # This may not be required, a_for_grad should be replaced by actions ##### Check PENDING #####
                # print("a_for_grad", a_for_grad)
                grads = critic.gradients(states, a_for_grad)       # a_for_grad is replaced by actions ##### Check PENDING #####   shape ERROR 
                # print("grads", grads)
                actor.train(states, grads)
                actor.target_train()
                critic.target_train()

    print("Training Completed !!!")

# %%
train_ddpg_network()
# Out:
# Epoch  1
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# /home/sanjay/anaconda3/envs/powertac_ddpg/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Loss 1.8216791152954102
# Epoch  2
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4444083571434021
# Epoch  3
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.44011390209198
# Epoch  4
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.641099214553833
# Epoch  5
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.36705130338668823
# Epoch  6
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6175764203071594
# Epoch  7
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5000836253166199
# Epoch  8
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.9979690313339233
# Epoch  9
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.26035207509994507
# Epoch  10
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4648985266685486
# Epoch  11
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.9470093250274658
# Epoch  12
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.1168004497885704
# Epoch  13
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 3.9236464500427246
# Epoch  14
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.3721065521240234
# Epoch  15
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.22854021191596985
# Epoch  16
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2102782428264618
# Epoch  17
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4004786014556885
# Epoch  18
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.9323647022247314
# Epoch  19
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.9238283634185791
# Epoch  20
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2252759337425232
# Epoch  21
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.11765413731336594
# Epoch  22
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.41464436054229736
# Epoch  23
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 2.0171797275543213
# Epoch  24
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.34994739294052124
# Epoch  25
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.29222220182418823
# Epoch  26
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5527408123016357
# Epoch  27
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.9937400221824646
# Epoch  28
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5007038712501526
# Epoch  29
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.17812854051589966
# Epoch  30
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.22384993731975555
# Epoch  31
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.1107454299926758
# Epoch  32
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.590077817440033
# Epoch  33
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5707745552062988
# Epoch  34
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.3732579946517944
# Epoch  35
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.19124025106430054
# Epoch  36
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5278928875923157
# Epoch  37
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.660936176776886
# Epoch  38
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.23696266114711761
# Epoch  39
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.19479532539844513
# Epoch  40
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.24472428858280182
# Epoch  41
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.512255072593689
# Epoch  42
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.1536189466714859
# Epoch  43
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6325359344482422
# Epoch  44
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3151991665363312
# Epoch  45
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.15627144277095795
# Epoch  46
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6297798156738281
# Epoch  47
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.229032501578331
# Epoch  48
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 2.5184695720672607
# Epoch  141
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3944550156593323
# Epoch  142
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.1109280586242676
# Epoch  143
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5383555889129639
# Epoch  144
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.7254025936126709
# Epoch  145
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.3001199960708618
# Epoch  146
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5345908999443054
# Epoch  147
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.33783090114593506
# Epoch  148
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.7446564435958862
# Epoch  149
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.49813058972358704
# Epoch  150
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6053548455238342
# Epoch  151
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2322680950164795
# Epoch  152
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3709155321121216
# Epoch  153
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3647991418838501
# Epoch  154
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.34493058919906616
# Epoch  155
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.311935693025589
# Epoch  156
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.0986981987953186
# Epoch  157
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3355003595352173
# Epoch  158
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.574737548828125
# Epoch  159
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.7353774905204773
# Epoch  160
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.37947893142700195
# Epoch  161
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.12733601033687592
# Epoch  162
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.18323561549186707
# Epoch  163
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6264951825141907
# Epoch  164
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.22143356502056122
# Epoch  165
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.23120486736297607
# Epoch  166
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.1638208031654358
# Epoch  167
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.20328889787197113
# Epoch  168
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.25008171796798706
# Epoch  169
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.29731523990631104
# Epoch  170
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5678235292434692
# Epoch  171
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.09545592963695526
# Epoch  172
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.10609721392393112
# Epoch  173
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.22463011741638184
# Epoch  174
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.1223897933959961
# Epoch  175
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.15723876655101776
# Epoch  176
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.8165309429168701
# Epoch  177
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.11246629059314728
# Epoch  178
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5094119310379028
# Epoch  179
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6365203857421875
# Epoch  180
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2720382511615753
# Epoch  181
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.31089356541633606
# Epoch  182
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.34110188484191895
# Epoch  183
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4336298406124115
# Epoch  184
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3835572600364685
# Epoch  185
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.32479220628738403
# Epoch  186
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.7114181518554688
# Epoch  187
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.16496387124061584
# Epoch  188
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3134225606918335
# Epoch  189
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3233094811439514
# Epoch  190
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.577162504196167
# Epoch  191
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.24903278052806854
# Epoch  192
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3241398334503174
# Epoch  193
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.16160976886749268
# Epoch  194
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2085973620414734
# Epoch  195
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.0829128623008728
# Epoch  196
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4555087089538574
# Epoch  197
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.328685998916626
# Epoch  198
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.24594272673130035
# Epoch  199
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4797552227973938
# Epoch  200
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.11701302230358124
# Epoch  201
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.21901476383209229
# Epoch  202
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.47954460978507996
# Epoch  203
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.1804264634847641
# Epoch  204
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.10084035992622375
# Epoch  205
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.29230254888534546
# Epoch  206
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2351318895816803
# Epoch  207
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5020852088928223
# Epoch  208
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6436700224876404
# Epoch  209
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6789409518241882
# Epoch  210
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3968692719936371
# Epoch  211
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3563624322414398
# Epoch  212
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.12819990515708923
# Epoch  213
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.14545390009880066
# Epoch  214
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.17603057622909546
# Epoch  215
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.39609065651893616
# Epoch  216
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.1935076266527176
# Epoch  217
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6882268190383911
# Epoch  218
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6234947443008423
# Epoch  219
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.1339341700077057
# Epoch  220
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.17468073964118958
# Epoch  221
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.15507666766643524
# Epoch  222
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4698750078678131
# Epoch  223
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.31503307819366455
# Epoch  224
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.24615411460399628
# Epoch  225
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6243263483047485
# Epoch  226
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.16763935983181
# Epoch  227
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.29727861285209656
# Epoch  228
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 2.9439163208007812
# Epoch  229
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5626824498176575
# Epoch  230
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.40637993812561035
# Epoch  231
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.673980712890625
# Epoch  232
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.890667200088501
# Epoch  233
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.46079570055007935
# Epoch  960
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.37497571110725403
# Epoch  961
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.26559895277023315
# Epoch  962
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.20058012008666992
# Epoch  963
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.397629976272583
# Epoch  964
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.21491794288158417
# Epoch  965
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.0961957648396492
# Epoch  966
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.23345130681991577
# Epoch  967
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.09484689682722092
# Epoch  968
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2714739441871643
# Epoch  969
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3722689747810364
# Epoch  970
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.4475061297416687
# Epoch  971
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.16187119483947754
# Epoch  972
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.21046194434165955
# Epoch  973
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.12706764042377472
# Epoch  974
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.37416234612464905
# Epoch  975
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 2.93717885017395
# Epoch  976
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.26660192012786865
# Epoch  977
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6164307594299316
# Epoch  978
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5791819095611572
# Epoch  979
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.7496169209480286
# Epoch  980
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6812511682510376
# Epoch  981
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 1.2592682838439941
# Epoch  982
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.18131406605243683
# Epoch  983
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6804922223091125
# Epoch  984
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.176779106259346
# Epoch  985
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.5796493887901306
# Epoch  986
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.6526761651039124
# Epoch  987
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2840861678123474
# Epoch  988
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.3429412245750427
# Epoch  989
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.13729959726333618
# Epoch  990
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.40052780508995056
# Epoch  991
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.7892831563949585
# Epoch  992
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.10810455679893494
# Epoch  993
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.22031819820404053
# Epoch  994
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.7905285358428955
# Epoch  995
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2366894781589508
# Epoch  996
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.10051640123128891
# Epoch  997
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.16030815243721008
# Epoch  998
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.23728100955486298
# Epoch  999
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.2420903742313385
# Epoch  1000
# ------------
# States (64, 25)
# Actions (64, 2)
# Rewards (64, 1)
# New_States (64, 25)
# Loss 0.30510467290878296
# Training Completed !!!

# %%
def choose_Action(states):

        actions = list()

        for state in states:

            try:

                # self.epsilon -= 1.0 / self.EXPLORE
                # a_t = np.zeros([self.action_dim])
                # noise_t = np.zeros([self.action_dim])

                with session.as_default():
                    with session.graph.as_default():

                        a_t_original = actor.model.predict(state.reshape(1, state.shape[0]))[0].tolist()
                        # noise_t[0] = max(self.epsilon, 0) * self.ou.function(a_t_original[0],  0.0 , 0.60, 0.30)  # decide theta, sigma and mu for limitprice

                        # a_t[0] = a_t_original[0] + noise_t[0]
                        # a_t[1] = a_t_original[1] + noise_t[1]

                        # print(a_t_original)
                        actions.append(list(a_t_original))

            except Exception as e:
                print(e)

        return actions

# %%
batch = replay_buffer.sample(n=BATCH_SIZE)
states = np.asarray(batch[batch.columns[0:25]])

lps = choose_Action(states)

# %%
for lp in lps:
    print(lp)
# Out:
# [-1.9986138343811035, -1.998808741569519]
# [-1.9995125532150269, -1.9998949766159058]
# [-1.999644160270691, -1.9999266862869263]
# [-1.999294400215149, -1.9998599290847778]
# [-1.9997283220291138, -1.9999641180038452]
# [-1.9985324144363403, -1.9987252950668335]
# [-1.9987373352050781, -1.9989328384399414]
# [-1.998441219329834, -1.9995189905166626]
# [-1.997105360031128, -1.998976469039917]
# [-1.9982918500900269, -1.998471975326538]
# [-1.998637080192566, -1.9995906352996826]
# [-1.9989433288574219, -1.9997400045394897]
# [-1.997590184211731, -1.9991861581802368]
# [-1.997422695159912, -1.9991159439086914]
# [-1.9976328611373901, -1.9993222951889038]
# [-1.9955360889434814, -1.9982162714004517]
# [-1.9997235536575317, -1.9999449253082275]
# [-1.9991308450698853, -1.9993141889572144]
# [-1.993714451789856, -1.9971733093261719]
# [-1.9988806247711182, -1.9996758699417114]
# [-1.999822974205017, -1.9999780654907227]
# [-1.999625325202942, -1.9999216794967651]
# [-1.9996508359909058, -1.9999260902404785]
# [-1.9990684986114502, -1.9992552995681763]
# [-1.9985452890396118, -1.9995570182800293]
# [-1.9989502429962158, -1.9991422891616821]
# [-1.999571442604065, -1.9998959302902222]
# [-1.9983323812484741, -1.999707818031311]
# [-1.9885272979736328, -1.9946287870407104]
# [-1.9982223510742188, -1.9996850490570068]
# [-1.9971240758895874, -1.9989850521087646]
# [-1.9998685121536255, -1.9999771118164062]
# [-1.9989391565322876, -1.999131441116333]
# [-1.993640422821045, -1.9971280097961426]
# [-1.9954603910446167, -1.9981768131256104]
# [-1.9992406368255615, -1.9994150400161743]
# [-1.999355673789978, -1.9995182752609253]
# [-1.9988455772399902, -1.9990402460098267]
# [-1.999655842781067, -1.9999388456344604]
# [-1.998348355293274, -1.999484658241272]
# [-1.9784313440322876, -1.97492253780365]
# [-1.999041199684143, -1.9992293119430542]
# [-1.9991295337677002, -1.9993128776550293]
# [-1.9988127946853638, -1.9997020959854126]
# [-1.9998157024383545, -1.9999698400497437]
# [-1.999646544456482, -1.999927043914795]
# [-1.9995315074920654, -1.999932885169983]
# [-1.9996289014816284, -1.9999372959136963]
# [-1.989856481552124, -1.9943623542785645]
# [-1.9902387857437134, -1.9946727752685547]
# [-1.9996116161346436, -1.9999192953109741]
# [-1.9965945482254028, -1.9987419843673706]
# [-1.9998338222503662, -1.9999754428863525]
# [-1.9988305568695068, -1.999025583267212]
# [-1.9923022985458374, -1.9973301887512207]
# [-1.9938713312149048, -1.9972689151763916]
# [-1.9997799396514893, -1.999971866607666]
# [-1.9939980506896973, -1.9973454475402832]
# [-1.9995931386947632, -1.999932050704956]
# [-1.999388337135315, -1.999546766281128]
# [-1.9987045526504517, -1.9997828006744385]
# [-1.9953607320785522, -1.9949276447296143]
# [-1.9985367059707642, -1.999618649482727]
# [-1.9957114458084106, -1.9953882694244385]

# %%
def save_models():

        with session.as_default():
                with session.graph.as_default():        

                    timestamp = int(datetime.datetime.now().timestamp())

                    actor.model.save_weights(model_storage_path + "/actormodel.h5", overwrite=True)
                    with open(model_storage_path + "/actormodel.json", "w") as outfile:
                        json.dump(actor.model.to_json(), outfile)

                    critic.model.save_weights(model_storage_path + "/criticmodel.h5", overwrite=True)
                    with open(model_storage_path + "/criticmodel.json", "w") as outfile:
                        json.dump(critic.model.to_json(), outfile)

                    actor.target_model.save_weights(model_storage_path + "/actortargetmodel.h5", overwrite=True)
                    with open(model_storage_path + "/actormodeltarget.json", "w") as outfile:
                        json.dump(actor.target_model.to_json(), outfile)

                    critic.target_model.save_weights(model_storage_path + "/critictargetmodel.h5", overwrite=True)
                    with open(model_storage_path + "/criticmodeltarget.json", "w") as outfile:
                        json.dump(critic.target_model.to_json(), outfile)

                    print("Models Saved Successfully !!!")

# %%
# save_models()
