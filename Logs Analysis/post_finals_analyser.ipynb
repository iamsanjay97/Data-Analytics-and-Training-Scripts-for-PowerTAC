# %%
# All the games
folders_all_games = ["finals_2021_1", "finals_2021_2", "finals_2021_3", "finals_2021_4", "finals_2021_5", "finals_2021_6", \
                     "finals_2021_7", "finals_2021_8", "finals_2021_9", "finals_2021_10",  "finals_2021_11", "finals_2021_12", \
                     "finals_2021_13", "finals_2021_14", "finals_2021_15", "finals_2021_16", "finals_2021_17", "finals_2021_18", \
                     "finals_2021_19", "finals_2021_20", "finals_2021_21", "finals_2021_22", "finals_2021_23", "finals_2021_24", \
                     "finals_2021_25", "finals_2021_26", "finals_2021_27", "finals_2021_28", "finals_2021_29", "finals_2021_30", \
                     "finals_2021_31", "finals_2021_32", "finals_2021_33", "finals_2021_34", "finals_2021_35", "finals_2021_36", \
                     "finals_2021_37", "finals_2021_38", "finals_2021_39", "finals_2021_40", "finals_2021_41", "finals_2021_42", \
                     "finals_2021_43", "finals_2021_44", "finals_2021_45", "finals_2021_46", "finals_2021_47", "finals_2021_48", \
                     "finals_2021_49", "finals_2021_50", "finals_2021_51", "finals_2021_52", "finals_2021_53", "finals_2021_54", \
                     "finals_2021_55", "finals_2021_56", "finals_2021_57", "finals_2021_58", "finals_2021_59", "finals_2021_60", \
                     "finals_2021_61", "finals_2021_62", "finals_2021_63", "finals_2021_64", "finals_2021_65", "finals_2021_66", \
                     "finals_2021_67", "finals_2021_68", "finals_2021_69", "finals_2021_70", "finals_2021_71", "finals_2021_72", \
                     "finals_2021_73", "finals_2021_74", "finals_2021_76", "finals_2021_77", "finals_2021_78", \
                     "finals_2021_79", "finals_2021_80", "finals_2021_81", "finals_2021_82", "finals_2021_83", "finals_2021_84", \
                     "finals_2021_85", "finals_2021_86", "finals_2021_87", "finals_2021_88", "finals_2021_89", "finals_2021_90", \
                     "finals_2021_91", "finals_2021_92", "finals_2021_93", "finals_2021_94", "finals_2021_95", "finals_2021_96", \
                     "finals_2021_97", "finals_2021_98", "finals_2021_99", "finals_2021_100", "finals_2021_101", "finals_2021_102", \
                     "finals_2021_103", "finals_2021_104", "finals_2021_105", "finals_2021_106", "finals_2021_107", "finals_2021_108", \
                     "finals_2021_109", "finals_2021_110", "finals_2021_111", "finals_2021_112", "finals_2021_113", "finals_2021_114", \
                     "finals_2021_115", "finals_2021_116", "finals_2021_117", "finals_2021_118", "finals_2021_119", "finals_2021_120", \
                     "finals_2021_121", "finals_2021_122", "finals_2021_123", "finals_2021_124", "finals_2021_125", "finals_2021_126", \
                     "finals_2021_127", "finals_2021_128", "finals_2021_129", "finals_2021_130", "finals_2021_131", "finals_2021_132", \
                     "finals_2021_133", "finals_2021_134", "finals_2021_135", "finals_2021_136", "finals_2021_137", "finals_2021_138", \
                     "finals_2021_139", "finals_2021_140", "finals_2021_141", "finals_2021_142", "finals_2021_143", "finals_2021_144", \
                     "finals_2021_145", "finals_2021_146", "finals_2021_147", "finals_2021_148", "finals_2021_149", "finals_2021_150", \
                     "finals_2021_151", "finals_2021_152", "finals_2021_153", "finals_2021_154", "finals_2021_155", "finals_2021_156", \
                     "finals_2021_157", "finals_2021_158", "finals_2021_159", "finals_2021_160", "finals_2021_161", "finals_2021_162", \
                     "finals_2021_163", "finals_2021_164", "finals_2021_165", "finals_2021_166", "finals_2021_167", "finals_2021_168", \
                     "finals_2021_169", "finals_2021_170", "finals_2021_171", "finals_2021_172", "finals_2021_173", "finals_2021_174", \
                     "finals_2021_175", "finals_2021_176", "finals_2021_177", "finals_2021_178", "finals_2021_179", "finals_2021_180", \
                     "finals_2021_181", "finals_2021_182", "finals_2021_183", "finals_2021_184", "finals_2021_185", "finals_2021_186", \
                     "finals_2021_187", "finals_2021_188", "finals_2021_189", "finals_2021_190", "finals_2021_191", "finals_2021_192", \
                     "finals_2021_193", "finals_2021_194", "finals_2021_195", "finals_2021_196", "finals_2021_197", "finals_2021_198", \
                     "finals_2021_199", "finals_2021_200", "finals_2021_201", "finals_2021_202", "finals_2021_203", "finals_2021_204", \
                     "finals_2021_205", "finals_2021_206", "finals_2021_207", "finals_2021_208", "finals_2021_209", "finals_2021_210", \
                     "finals_2021_211", "finals_2021_212", "finals_2021_213", "finals_2021_214", "finals_2021_215", "finals_2021_216", \
                     "finals_2021_217", "finals_2021_218", "finals_2021_219", "finals_2021_220", "finals_2021_221", "finals_2021_222", \
                     "finals_2021_223", "finals_2021_224", "finals_2021_225", "finals_2021_226", "finals_2021_227", "finals_2021_228", \
                     "finals_2021_229", "finals_2021_230", "finals_2021_231", "finals_2021_232", "finals_2021_233", "finals_2021_234", \
                     "finals_2021_235", "finals_2021_236", "finals_2021_237", "finals_2021_238", "finals_2021_239", "finals_2021_240", \
                     "finals_2021_241", "finals_2021_242", "finals_2021_243", "finals_2021_244", "finals_2021_245", "finals_2021_246", \
                     "finals_2021_247", "finals_2021_248", "finals_2021_249", "finals_2021_250", "finals_2021_251", "finals_2021_252", \
                     "finals_2021_253", "finals_2021_254", "finals_2021_255", "finals_2021_256", "finals_2021_257", "finals_2021_258", \
                     "finals_2021_259", "finals_2021_260", "finals_2021_261", "finals_2021_262", "finals_2021_263", "finals_2021_264", \
                     "finals_2021_265", "finals_2021_266", "finals_2021_267", "finals_2021_268", "finals_2021_269", "finals_2021_270", \
                     "finals_2021_271", "finals_2021_272", "finals_2021_273", "finals_2021_274", "finals_2021_275", "finals_2021_276", \
                     "finals_2021_277", "finals_2021_278", "finals_2021_279", "finals_2021_280", "finals_2021_281", "finals_2021_282", \
                     "finals_2021_283", "finals_2021_284", "finals_2021_285", "finals_2021_286", "finals_2021_287", "finals_2021_288", \
                     "finals_2021_289", "finals_2021_290", "finals_2021_291", "finals_2021_292", "finals_2021_293", "finals_2021_294", \
                     "finals_2021_295", "finals_2021_296", "finals_2021_297", "finals_2021_298", "finals_2021_299", "finals_2021_300", \
                     "finals_2021_301", "finals_2021_302", "finals_2021_303", "finals_2021_304", "finals_2021_305", "finals_2021_306", \
                     "finals_2021_307", "finals_2021_308", "finals_2021_309", "finals_2021_310", "finals_2021_311", "finals_2021_312", \
                     "finals_2021_313", "finals_2021_314", "finals_2021_315", "finals_2021_316", "finals_2021_317", "finals_2021_318", \
                     "finals_2021_319", "finals_2021_320", "finals_2021_321", "finals_2021_322", "finals_2021_323", "finals_2021_324", \
                     "finals_2021_325", "finals_2021_326", "finals_2021_327", "finals_2021_328", "finals_2021_329", "finals_2021_330", \
                     "finals_2021_331", "finals_2021_332", "finals_2021_333", "finals_2021_334", "finals_2021_335", "finals_2021_336", \
                     "finals_2021_337", "finals_2021_338", "finals_2021_339", "finals_2021_340", "finals_2021_341", "finals_2021_342", \
                     "finals_2021_343", "finals_2021_344", "finals_2021_345", "finals_2021_346", "finals_2021_347", "finals_2021_348", \
                     "finals_2021_349", "finals_2021_350", "finals_2021_351", "finals_2021_352", "finals_2021_353", "finals_2021_354", \
                     "finals_2021_355", "finals_2021_356", "finals_2021_357", "finals_2021_358", "finals_2021_359", "finals_2021_360", \
                     "finals_2021_361", "finals_2021_362", "finals_2021_363", "finals_2021_364", "finals_2021_365", "finals_2021_366", \
                     "finals_2021_367", "finals_2021_368", "finals_2021_369", "finals_2021_370", "finals_2021_371", "finals_2021_372", \
                     "finals_2021_373", "finals_2021_374", "finals_2021_375", "finals_2021_376", "finals_2021_377", "finals_2021_378", \
                     "finals_2021_379", "finals_2021_380", "finals_2021_381", "finals_2021_382", "finals_2021_383", "finals_2021_384", \
                     "finals_2021_385", "finals_2021_386"]

folders_7_games = ["finals_2021_1", "finals_2021_2", "finals_2021_3", "finals_2021_4", "finals_2021_5", "finals_2021_6", \
                   "finals_2021_7", "finals_2021_8", "finals_2021_9", "finals_2021_10", "finals_2021_11", "finals_2021_12", \
                   "finals_2021_13", "finals_2021_14", "finals_2021_15", "finals_2021_16", "finals_2021_17", "finals_2021_18", \
                   "finals_2021_19", "finals_2021_20", "finals_2021_21", "finals_2021_22", "finals_2021_23", "finals_2021_24", \
                   "finals_2021_25", "finals_2021_26", "finals_2021_27", "finals_2021_28", "finals_2021_29", "finals_2021_30", \
                   "finals_2021_31", "finals_2021_32", "finals_2021_33", "finals_2021_34", "finals_2021_35", "finals_2021_36", \
                   "finals_2021_37", "finals_2021_38", "finals_2021_39", "finals_2021_40", "finals_2021_41", "finals_2021_42", \
                   "finals_2021_43", "finals_2021_44", "finals_2021_45", "finals_2021_46", "finals_2021_47", "finals_2021_48", \
                   "finals_2021_49", "finals_2021_50"]

folders_5_games = ["finals_2021_51", "finals_2021_52", "finals_2021_53", "finals_2021_54", "finals_2021_55", "finals_2021_56", \
                   "finals_2021_57", "finals_2021_58", "finals_2021_59", "finals_2021_60", "finals_2021_61", "finals_2021_62", \
                   "finals_2021_63", "finals_2021_64", "finals_2021_65", "finals_2021_66", "finals_2021_67", "finals_2021_68", \
                   "finals_2021_69", "finals_2021_70", "finals_2021_71", "finals_2021_72", "finals_2021_73", "finals_2021_74", \
                   "finals_2021_76", "finals_2021_77", "finals_2021_78", "finals_2021_79", "finals_2021_80", \
                   "finals_2021_81", "finals_2021_82", "finals_2021_83", "finals_2021_84", "finals_2021_85", "finals_2021_86", \
                   "finals_2021_87", "finals_2021_88", "finals_2021_89", "finals_2021_90", "finals_2021_91", "finals_2021_92", \
                   "finals_2021_93", "finals_2021_94", "finals_2021_95", "finals_2021_96", "finals_2021_97", "finals_2021_98", \
                   "finals_2021_99", "finals_2021_100", "finals_2021_101", "finals_2021_102", "finals_2021_103", "finals_2021_104", \
                   "finals_2021_105", "finals_2021_106", "finals_2021_107", "finals_2021_108", "finals_2021_109", "finals_2021_110", \
                   "finals_2021_111", "finals_2021_112", "finals_2021_113", "finals_2021_114", "finals_2021_115", "finals_2021_116", \
                   "finals_2021_117", "finals_2021_118", "finals_2021_119", "finals_2021_120", "finals_2021_121", "finals_2021_122", \
                   "finals_2021_123", "finals_2021_124", "finals_2021_125", "finals_2021_126", "finals_2021_127", "finals_2021_128", \
                   "finals_2021_129", "finals_2021_130", "finals_2021_131", "finals_2021_132", "finals_2021_133", "finals_2021_134", \
                   "finals_2021_135", "finals_2021_136", "finals_2021_137", "finals_2021_138", "finals_2021_139", "finals_2021_140", \
                   "finals_2021_141", "finals_2021_142", "finals_2021_143", "finals_2021_144", "finals_2021_145", "finals_2021_146", \
                   "finals_2021_147", "finals_2021_148", "finals_2021_149", "finals_2021_150", "finals_2021_151", "finals_2021_152", \
                   "finals_2021_153", "finals_2021_154", "finals_2021_155", "finals_2021_156", "finals_2021_157", "finals_2021_158", \
                   "finals_2021_159", "finals_2021_160", "finals_2021_161", "finals_2021_162", "finals_2021_163", "finals_2021_164", \
                   "finals_2021_165", "finals_2021_166", "finals_2021_167", "finals_2021_168", "finals_2021_169", "finals_2021_170", \
                   "finals_2021_171", "finals_2021_172", "finals_2021_173", "finals_2021_174", "finals_2021_175", "finals_2021_176"] 

folders_3_games = ["finals_2021_114", "finals_2021_115", "finals_2021_116", "finals_2021_117", "finals_2021_118", "finals_2021_119", \
                   "finals_2021_135", "finals_2021_136", "finals_2021_137", "finals_2021_138", "finals_2021_139", "finals_2021_140", \
                   "finals_2021_156", "finals_2021_157", "finals_2021_158", "finals_2021_159", "finals_2021_160", "finals_2021_161", \
                   "finals_2021_177", "finals_2021_178", "finals_2021_179", "finals_2021_180", "finals_2021_181", "finals_2021_182", \
                   "finals_2021_183", "finals_2021_184", "finals_2021_185", "finals_2021_186", "finals_2021_187", "finals_2021_188", \
                   "finals_2021_189", "finals_2021_230", "finals_2021_231", "finals_2021_247", "finals_2021_248", "finals_2021_190", \
                   "finals_2021_191", "finals_2021_192", "finals_2021_193", "finals_2021_194", "finals_2021_195", "finals_2021_196", \
                   "finals_2021_212", "finals_2021_213", "finals_2021_214", "finals_2021_215", "finals_2021_216", "finals_2021_217", \
                   "finals_2021_218", "finals_2021_219", "finals_2021_220", "finals_2021_221", "finals_2021_222", "finals_2021_223", \
                   "finals_2021_224", "finals_2021_225", "finals_2021_226", "finals_2021_227", "finals_2021_228", "finals_2021_229", \
                   "finals_2021_249", "finals_2021_250", "finals_2021_251", "finals_2021_252", "finals_2021_253", "finals_2021_254", \
                   "finals_2021_255", "finals_2021_256", "finals_2021_257", "finals_2021_258", "finals_2021_259", "finals_2021_260", \
                   "finals_2021_261", "finals_2021_262", "finals_2021_263", "finals_2021_264", "finals_2021_265", "finals_2021_266", \
                   "finals_2021_282", "finals_2021_283", "finals_2021_284", "finals_2021_285", "finals_2021_286", "finals_2021_287", \
                   "finals_2021_288", "finals_2021_289", "finals_2021_290", "finals_2021_291", "finals_2021_292", "finals_2021_293", \
                   "finals_2021_294", "finals_2021_295", "finals_2021_296", "finals_2021_297", "finals_2021_298", "finals_2021_299", \
                   "finals_2021_300", "finals_2021_301", "finals_2021_317", "finals_2021_318", "finals_2021_319", "finals_2021_320", \
                   "finals_2021_321", "finals_2021_322", "finals_2021_323", "finals_2021_324", "finals_2021_325", "finals_2021_326", \
                   "finals_2021_327", "finals_2021_328", "finals_2021_329", "finals_2021_330", "finals_2021_331", "finals_2021_332", \
                   "finals_2021_333", "finals_2021_334", "finals_2021_335", "finals_2021_336", "finals_2021_352", "finals_2021_353", \
                   "finals_2021_354", "finals_2021_355", "finals_2021_356", "finals_2021_357", "finals_2021_358", "finals_2021_359", \
                   "finals_2021_360", "finals_2021_361", "finals_2021_362", "finals_2021_363", "finals_2021_364", "finals_2021_365", \
                   "finals_2021_366", "finals_2021_367", "finals_2021_368", "finals_2021_369", "finals_2021_370", "finals_2021_371", \
                   "finals_2021_51", "finals_2021_52", "finals_2021_53", "finals_2021_54", "finals_2021_55", "finals_2021_56", \
                   "finals_2021_72", "finals_2021_73", "finals_2021_74", "finals_2021_75", "finals_2021_76", "finals_2021_77", \
                   "finals_2021_93", "finals_2021_94", "finals_2021_95", "finals_2021_96", "finals_2021_97", "finals_2021_98"]

# %%
import os
import sys
import csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

from matplotlib import pyplot as plt
from plotly.subplots import make_subplots

sns.set_theme(style="darkgrid")

# See complete data
# pd.set_option('max_columns', None)
# pd.set_option("max_rows", None)
# np.set_printoptions(threshold=np.inf)

# %%
color_book = {'ttx_sc': 'gray', 'ttx_sd': 'lightgray', 'ttx_uc': 'limegreen', 'ttx_ud': 'seagreen', 'mtx_c': 'slateblue', 
              'mtx_d': 'mediumslateblue', 'btx_c': 'salmon', 'btx_d': 'tomato', 'dtx_c': 'khaki', 'dtx_d': 'gold', 
              'ctx_c': 'palegreen', 'ctx_d': 'darkseagreen', 'bce_c': 'skyblue', 'bce_d': 'deepskyblue', 
              'bank_c': 'deeppink', 'bank_d': 'hotpink', 'final_cash': 'darkorchid', 'net_demand': 'lightsalmon', 
              'mkt_qty': 'yellowgreen', 'mkt_cost': 'yellowgreen', 'imb_qty': 'mediumorchid', 'imb_cost': 'mediumorchid', 
              'VidyutVanika': 'royalblue','EWIIS3_2021': 'deepskyblue', 'Mertacor': 'navy', 'SPOT': 'tomato', 'UTA_PTA': 'olivedrab', 'default broker': 'deeppink', 'COLDPOWER': 'cornflowerblue',
              'VidyutVanika21': 'darkorchid', 'TUC_TAC': 'yellowgreen','EWIIS3_2021': 'deepskyblue', 'IS3': 'deepskyblue', 'Mertacor2021': 'mediumorchid',
              'CrocodileAgent2020': 'skyblue', 'SPOT': 'tomato', 'UTA_PTA2021': 'tomato', 'default broker': 'deeppink', 'COLDPOWER2021': 'deeppink',
              'overall': 'cornflowerblue', '9player': 'mediumorchid', '7player': 'lightsalmon', '5player': 'lightgreen', '3player': 'plum'}

# color_book = {'ttx_sc': 'gray', 'ttx_sd': 'lightgray', 'ttx_uc': 'limegreen', 'ttx_ud': 'seagreen', 'mtx_c': 'slateblue', 
#               'mtx_d': 'mediumslateblue', 'btx_c': 'salmon', 'btx_d': 'tomato', 'dtx_c': 'khaki', 'dtx_d': 'gold', 
#               'ctx_c': 'palegreen', 'ctx_d': 'darkseagreen', 'bce_c': 'skyblue', 'bce_d': 'deepskyblue', 
#               'bank_c': 'deeppink', 'bank_d': 'hotpink', 'final_cash': 'darkorchid', 'net_demand': 'lightsalmon', 
#               'mkt_qty': 'yellowgreen', 'mkt_cost': 'yellowgreen', 'imb_qty': 'mediumorchid', 'imb_cost': 'mediumorchid', 
#               'VidyutVanika': 'darkorchid', 'TUC_TAC': 'yellowgreen','EWIIS3_2021': 'deepskyblue', 'IS3': 'deepskyblue', 'Mertacor': 'mediumorchid',
#               'CrocodileAgent2020': 'skyblue', 'SPOT': 'tomato', 'UTA_PTA': 'tomato', 'default broker': 'deeppink', 'COLDPOWER': 'deeppink',
#               'AIB': 'darkorchid', 'TB1': 'yellowgreen','EWIIS3_2021': 'deepskyblue', 'TB3': 'deepskyblue', 'TB6': 'mediumorchid',
#               'TB2': 'skyblue', 'SPOT': 'tomato', 'TB5': 'tomato', 'default broker': 'deeppink', 'TB4': 'deeppink',
#               'overall': 'cornflowerblue', '9player': 'mediumorchid', '7player': 'lightsalmon', '5player': 'lightgreen', '3player': 'plum'}

def get_colors(list_of_brokers):
    return [color_book.get(broker) for broker in list_of_brokers]

# %%
def Broker_Accounting():
    
    with open(path + '/BrokerCosts.csv', 'r') as fin:
        data = fin.read().splitlines(True)
    with open(path + '/BrokerCostsU.csv', 'w') as fout:
        fout.writelines(data[1:])

    broker_accounting = pd.read_csv(path + "/BrokerAccounting.csv")
    broker_costs = pd.read_csv(path + "/BrokerCostsU.csv")

    number_of_brokers = len(broker_costs['broker-name'])

    list_of_brokers = list()
    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting[col_broker].unique()[0]
        list_of_brokers.append(broker_name)

    columns = broker_accounting.iloc[:, 4:21].columns.tolist()
    
    start_index = 4

    total_ttx_sc = list()
    total_ttx_sd = list()
    total_ttx_uc = list()
    total_ttx_ud = list()
    total_mtx_c = list()
    total_mtx_d = list()
    total_btx_c = list()
    total_btx_d = list()
    total_dtx_c = list()
    total_dtx_d = list()
    total_ctx_c = list()
    total_ctx_d = list()
    total_bce_c = list()
    total_bce_d = list()
    total_bank_c = list()
    total_bank_d = list()
    final_cash = list()

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting[col_broker].unique()[0]

        dataframe = broker_accounting.iloc[:, start_index:(start_index+17)]
        dataframe.columns = columns

        total_ttx_sc.append(dataframe['ttx-sc'].sum())
        total_ttx_sd.append(dataframe['ttx-sd'].sum())
        total_ttx_uc.append(dataframe['ttx-uc'].sum())
        total_ttx_ud.append(dataframe['ttx-ud'].sum())
        total_mtx_c.append(dataframe['mtx-c'].sum())
        total_mtx_d.append(dataframe['mtx-d'].sum())
        total_btx_c.append(dataframe['btx-c'].sum())
        total_btx_d.append(dataframe['btx-d'].sum())
        total_dtx_c.append(dataframe['dtx-c'].sum())
        total_dtx_d.append(dataframe['dtx-d'].sum())
        total_ctx_c.append(dataframe['ctx-c'].sum())
        total_ctx_d.append(dataframe['ctx-d'].sum())
        total_bce_c.append(dataframe['bce-c'].sum())
        total_bce_d.append(dataframe['bce-d'].sum())
        total_bank_c.append(dataframe['bank-c'].sum())
        total_bank_d.append(dataframe['bank-d'].sum())
        final_cash.append(dataframe['cash'].iloc[-1])

        start_index = start_index + 18


    fig = go.Figure(data = [
            (go.Bar(name='ttx_sc', x=list_of_brokers, y=total_ttx_sc, marker_color=color_book.get('ttx_sc'))),
            (go.Bar(name='ttx_sd', x=list_of_brokers, y=total_ttx_sd, marker_color=color_book.get('ttx_sd'))),
            (go.Bar(name='ttx_uc', x=list_of_brokers, y=total_ttx_uc, marker_color=color_book.get('ttx_uc'))),
            (go.Bar(name='ttx_ud', x=list_of_brokers, y=total_ttx_ud, marker_color=color_book.get('ttx_ud'))),
            (go.Bar(name='mtx_c', x=list_of_brokers, y=total_mtx_c, marker_color=color_book.get('mtx_c'))),
            (go.Bar(name='mtx_d', x=list_of_brokers, y=total_mtx_d, marker_color=color_book.get('mtx_d'))),
            (go.Bar(name='btx_c', x=list_of_brokers, y=total_btx_c, marker_color=color_book.get('btx_c'))),
            (go.Bar(name='btx_d', x=list_of_brokers, y=total_btx_d, marker_color=color_book.get('btx_d'))),
            (go.Bar(name='dtx_c', x=list_of_brokers, y=total_dtx_c, marker_color=color_book.get('dtx_c'))),
            (go.Bar(name='dtx_d', x=list_of_brokers, y=total_dtx_d, marker_color=color_book.get('dtx_d'))),
            (go.Bar(name='ctx_c', x=list_of_brokers, y=total_ctx_c, marker_color=color_book.get('ctx_c'))),
            (go.Bar(name='ctx_d', x=list_of_brokers, y=total_ctx_d, marker_color=color_book.get('ctx_d'))),
            (go.Bar(name='bce_c', x=list_of_brokers, y=total_bce_c, marker_color=color_book.get('bce_c'))),
            (go.Bar(name='bce_d', x=list_of_brokers, y=total_bce_d, marker_color=color_book.get('bce_d'))),
            (go.Bar(name='bank_c', x=list_of_brokers, y=total_bank_c, marker_color=color_book.get('bank_c'))),
            (go.Bar(name='bank_d', x=list_of_brokers, y=total_bank_d, marker_color=color_book.get('bank_d'))),
            (go.Bar(name='final_cash', x=list_of_brokers, y=final_cash, marker_color=color_book.get('final_cash')))
        ])    

    fig.update_yaxes(title_text="Price ($)")
    fig.update_traces(marker_line_color='black', marker_line_width=0.5)
    fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
            title_text='Accounting Information',
            template='ggplot2')

    fig.write_html(path + "/Results/BrokerAccounting.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
def Broker_Imbalance():
    
    broker_imbalance_cost = pd.read_csv(path + "/BrokerImbalanceCost.csv")

    group_dataframe = broker_imbalance_cost.groupby(' broker')
    group_dataframe_mean = group_dataframe.mean()
    group_dataframe_sum = group_dataframe.sum()

    list_of_brokers = list(group_dataframe.groups.keys())

    mean_net_demand = group_dataframe_mean[' netDemand']
    mean_mkt_qty = group_dataframe_mean[' mktQty']*(-1)
    mean_mkt_cost = group_dataframe_mean[' mktCost']
    unit_mkt_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(mean_mkt_cost, mean_mkt_qty)]
    mean_imb_qty = group_dataframe_mean[' imbalance']
    mean_imb_cost = group_dataframe_mean[' imbalanceCost']
    unit_imb_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(mean_imb_cost, mean_imb_qty)]

    num_rows = 1
    num_cols = 3

    fig = make_subplots(rows=num_rows, 
                        cols=num_cols,
                        subplot_titles=('Quantity Comparison', 'Price Comparison', 'Unit Price Comparison'))

    trace1 = go.Bar(name='net_demand', x=list_of_brokers, y=mean_net_demand,marker_color=color_book.get('net_demand'), legendgroup = 1)
    trace2 = go.Bar(name='mkt_qty', x=list_of_brokers, y=mean_mkt_qty, marker_color=color_book.get('mkt_qty'), legendgroup = 1)
    trace3 = go.Bar(name='mkt_cost', x=list_of_brokers, y=mean_mkt_cost, marker_color=color_book.get('mkt_cost'), legendgroup = 2)
    trace4 = go.Bar(name='imb_qty', x=list_of_brokers, y=mean_imb_qty, marker_color=color_book.get('imb_qty'), legendgroup = 1)
    trace5 = go.Bar(name='imb_cost', x=list_of_brokers, y=mean_imb_cost, marker_color=color_book.get('imb_cost'), legendgroup = 2)
    trace6 = go.Bar(name='unit_mkt_cost', x=list_of_brokers, y=unit_mkt_price, marker_color=color_book.get('mkt_cost'), legendgroup = 3)
    trace7 = go.Bar(name='unit_imb_cost', x=list_of_brokers, y=unit_imb_price, marker_color=color_book.get('imb_cost'), legendgroup = 3)

    fig.append_trace(trace1, row = 1, col = 1)
    fig.append_trace(trace2, row = 1, col = 1)
    fig.append_trace(trace4, row = 1, col = 1)
    fig.append_trace(trace3, row = 1, col = 2)
    fig.append_trace(trace5, row = 1, col = 2)
    fig.append_trace(trace6, row = 1, col = 3)
    fig.append_trace(trace7, row = 1, col = 3)

    fig.update_yaxes(title_text="Quantity (KWh)", row=1, col=1)
    fig.update_yaxes(title_text="Price ($)", row=1, col=2)
    fig.update_yaxes(title_text="Price ($/MWh)", row=1, col=3)
    fig.update_traces(marker_line_color='black', marker_line_width=0.5)

    for i in fig['layout']['annotations']:
            i['font'] = dict(size=14)

    fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
            title_text='Balancing Information (Mean Value per Timeslot)',
            template='ggplot2')

    fig.write_html(path + "/Results/BrokerImbalance.html")
    
    list_of_brokers = list(group_dataframe.groups.keys())

    mean_net_demand = group_dataframe_sum[' netDemand']
    mean_mkt_qty = group_dataframe_sum[' mktQty']*(-1)
    mean_mkt_cost = group_dataframe_sum[' mktCost']
    unit_mkt_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(mean_mkt_cost, mean_mkt_qty)]
    mean_imb_qty = group_dataframe_sum[' imbalance']
    mean_imb_cost = group_dataframe_sum[' imbalanceCost']
    unit_imb_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(mean_imb_cost, mean_imb_qty)]

    num_rows = 1
    num_cols = 3

    fig = make_subplots(rows=num_rows, 
                        cols=num_cols,
                        subplot_titles=('Quantity Comparison', 'Price Comparison', 'Unit Price Comparison'))

    trace1 = go.Bar(name='net_demand', x=list_of_brokers, y=mean_net_demand,marker_color=color_book.get('net_demand'), legendgroup = 1)
    trace2 = go.Bar(name='mkt_qty', x=list_of_brokers, y=mean_mkt_qty, marker_color=color_book.get('mkt_qty'), legendgroup = 1)
    trace3 = go.Bar(name='mkt_cost', x=list_of_brokers, y=mean_mkt_cost, marker_color=color_book.get('mkt_cost'), legendgroup = 2)
    trace4 = go.Bar(name='imb_qty', x=list_of_brokers, y=mean_imb_qty, marker_color=color_book.get('imb_qty'), legendgroup = 1)
    trace5 = go.Bar(name='imb_cost', x=list_of_brokers, y=mean_imb_cost, marker_color=color_book.get('imb_cost'), legendgroup = 2)
    trace6 = go.Bar(name='unit_mkt_cost', x=list_of_brokers, y=unit_mkt_price, marker_color=color_book.get('mkt_cost'), legendgroup = 3)
    trace7 = go.Bar(name='unit_imb_cost', x=list_of_brokers, y=unit_imb_price, marker_color=color_book.get('imb_cost'), legendgroup = 3)

    fig.append_trace(trace1, row = 1, col = 1)
    fig.append_trace(trace2, row = 1, col = 1)
    fig.append_trace(trace4, row = 1, col = 1)
    fig.append_trace(trace3, row = 1, col = 2)
    fig.append_trace(trace5, row = 1, col = 2)
    fig.append_trace(trace6, row = 1, col = 3)
    fig.append_trace(trace7, row = 1, col = 3)

    fig.update_yaxes(title_text="Quantity (KWh)", row=1, col=1)
    fig.update_yaxes(title_text="Price ($)", row=1, col=2)
    fig.update_yaxes(title_text="Price ($/MWh)", row=1, col=3)
    fig.update_traces(marker_line_color='black', marker_line_width=0.5)

    for i in fig['layout']['annotations']:
            i['font'] = dict(size=14)

    fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
            title_text='Balancing Information',
            template='ggplot2')

    fig.write_html(path + "/Results/BrokerImbalanceTotal.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
 def Tariff_Mkt_Share():
    
    tariff_mkt_share = pd.read_csv(path + "/TariffMktShare.csv", index_col=False)
    list_of_brokers = tariff_mkt_share.iloc[:,1:].columns.tolist()
    tariff_mkt_share['Total'] = tariff_mkt_share.iloc[:,1:].sum(axis=1)

    for broker in list_of_brokers:

        tariff_mkt_share[broker] = (tariff_mkt_share[broker] / tariff_mkt_share['Total'])*100

    fig = px.line(tariff_mkt_share, x='ts', y=list_of_brokers, color_discrete_sequence=get_colors(list_of_brokers))

    fig.update_yaxes(title_text="Overall Market Share (%)")
    fig.update_xaxes(title_text="Timeslot")

    fig.update_layout(
        height=750, 
        width=1500, 
        title_text='Tariff Market Share Information',
        template='ggplot2',
    )

    for i in fig['layout']['annotations']:
        i['font'] = dict(size=14)

    fig.write_html(path + "/Results/TariffMktShare.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
def Total_Demand():

    total_demand = pd.read_csv(path + "/TotalDemand.csv", index_col=False)

    num_rows = 2
    num_cols = 1

    fig = make_subplots(rows=num_rows, 
                        cols=num_cols,
                        subplot_titles=('Internal PowerTAC Demand', 'External MISO Buyer Demand'),
                        vertical_spacing=0.10)


    fig.append_trace(go.Scatter(x = total_demand['slot'], y = total_demand[' int_demand'], name = 'int_demand', legendgroup = 1), row = 1, col = 1)
    fig.append_trace(go.Scatter(x = total_demand['slot'], y = total_demand[' ext_demand'], name = 'ext_demand', legendgroup = 2), row = 2, col = 1)

    fig.update_yaxes(title_text="Demand (MWh)")
    fig.update_xaxes(title_text="Timeslot", row=2)

    fig.update_layout(height=750, width=1500, title_text='Market Net Demand Information', template='ggplot2')

    for i in fig['layout']['annotations']:
        i['font'] = dict(size=14)

    fig.write_html(path + "/Results/TotalDemand.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
def Production_Consumption():
    
    production_consumption = pd.read_csv(path + "/ProductionConsumptionWeather.csv", index_col=False)
    production_consumption[' net demand'] = -1*(production_consumption[' consumption'] + production_consumption[' production'])
    production_consumption[' consumption'] = -1*production_consumption[' consumption']

    fig = px.line(production_consumption, x='slot', y=[' production', ' consumption', ' net demand'])

    fig.update_yaxes(title_text="Quantity (MWh)")
    fig.update_xaxes(title_text="Timeslot")

    fig.update_layout(
        height=750, 
        width=1500, 
        title_text='Production, Consumption and Net Demand Information',
        template='ggplot2',
    )

    for i in fig['layout']['annotations']:
        i['font'] = dict(size=14)

    fig.write_html(path + "/Results/ProductionConsumption.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
def Retail_Information():
    
    imbalance_summary = pd.read_csv(path + "/ImbalanceSummary.csv", header=None)
    imbalance_summary = imbalance_summary.iloc[2:,:-3]
    new_header = imbalance_summary.iloc[0]
    imbalance_summary = imbalance_summary[1:]
    imbalance_summary.columns = new_header

    imbalance_summary.iloc[:,1:] = imbalance_summary.iloc[:,1:].apply(pd.to_numeric)

    list_of_brokers = imbalance_summary['broker'].tolist()

    unit_con_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(imbalance_summary['c_revenue'], imbalance_summary['c'])]
    unit_pro_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(imbalance_summary['p_revenue'], imbalance_summary['p'])]

    num_rows = 1
    num_cols = 3

    fig = make_subplots(rows=num_rows, 
                        cols=num_cols,
                        subplot_titles=('Quantity Comparison', 'Price Comparison', 'Unit Price Comparison'))

    trace1 = go.Bar(name='c', x=list_of_brokers, y=imbalance_summary['c'], marker_color=color_book.get('mkt_qty'), legendgroup = 1)
    trace2 = go.Bar(name='p', x=list_of_brokers, y=imbalance_summary['p'], marker_color=color_book.get('imb_qty'), legendgroup = 1)
    trace3 = go.Bar(name='c_revenue', x=list_of_brokers, y=imbalance_summary['c_revenue'], marker_color=color_book.get('mkt_qty'), legendgroup = 2)
    trace4 = go.Bar(name='p_revenue', x=list_of_brokers, y=imbalance_summary['p_revenue'], marker_color=color_book.get('imb_qty'), legendgroup = 2)
    trace5 = go.Bar(name='unit_con_cost', x=list_of_brokers, y=unit_con_price, marker_color=color_book.get('mkt_qty'), legendgroup = 3)
    trace6 = go.Bar(name='unit_pro_cost', x=list_of_brokers, y=unit_pro_price, marker_color=color_book.get('imb_qty'), legendgroup = 3)

    fig.append_trace(trace1, row = 1, col = 1)
    fig.append_trace(trace2, row = 1, col = 1)
    fig.append_trace(trace3, row = 1, col = 2)
    fig.append_trace(trace4, row = 1, col = 2)
    fig.append_trace(trace5, row = 1, col = 3)
    fig.append_trace(trace6, row = 1, col = 3)

    fig.update_yaxes(title_text="Quantity (KWh)", row=1, col=1)
    fig.update_yaxes(title_text="Price ($)", row=1, col=2)
    fig.update_yaxes(title_text="Price ($/MWh)", row=1, col=3)
    fig.update_traces(marker_line_color='black', marker_line_width=0.5)

    for i in fig['layout']['annotations']:
            i['font'] = dict(size=14)

    fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
            title_text='Retail Information',
            template='ggplot2')

    fig.write_html(path + "/Results/RetailInformation.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
def Tariff_Wholesale_Price_Comparison():

    broker_imbalance_cost = pd.read_csv(path + "/BrokerImbalanceCost.csv")

    group_dataframe = broker_imbalance_cost.groupby(' broker')
    group_dataframe_mean = group_dataframe.mean()

    imbalance_summary = pd.read_csv(path + "/ImbalanceSummary.csv", header=None)
    imbalance_summary = imbalance_summary.iloc[2:,:-3]
    new_header = imbalance_summary.iloc[0]
    imbalance_summary = imbalance_summary[1:]
    imbalance_summary.columns = new_header

    imbalance_summary.iloc[:,1:] = imbalance_summary.iloc[:,1:].apply(pd.to_numeric)

    list_of_brokers = imbalance_summary['broker'].tolist()

    num_rows = 1
    num_cols = 2

    fig = make_subplots(rows=num_rows, 
                        cols=num_cols,
                        subplot_titles=('Consumption Price Comparison', 'Production Price Comparison'))

    mean_mkt_qty = group_dataframe_mean[' mktQty']*(-1)
    mean_mkt_cost = group_dataframe_mean[' mktCost']
    unit_mkt_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(mean_mkt_cost, mean_mkt_qty)]

    unit_con_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(imbalance_summary['c_revenue'], imbalance_summary['c'])]
    unit_pro_price = [abs((c/q)*1000) if q != 0 else -1 for c,q in zip(imbalance_summary['p_revenue'], imbalance_summary['p'])]

    trace1 = go.Bar(name='unit_wholesale_cost', x=list(group_dataframe.groups.keys()), y=unit_mkt_price, marker_color=color_book.get('mkt_cost'))
    trace2 = go.Bar(name='unit_retail_con_cost', x=list_of_brokers, y=unit_con_price, marker_color=color_book.get('imb_qty'))
    trace3 = go.Bar(name='unit_retail_prod_cost', x=list_of_brokers, y=unit_pro_price, marker_color=color_book.get('imb_qty'))

    fig.append_trace(trace1, row = 1, col = 1)
    fig.append_trace(trace2, row = 1, col = 1)
    fig.append_trace(trace1, row = 1, col = 2)
    fig.append_trace(trace3, row = 1, col = 2)

    fig.update_yaxes(title_text="Price ($/MWh)")
    fig.update_traces(marker_line_color='black', marker_line_width=0.5)

    for i in fig['layout']['annotations']:
            i['font'] = dict(size=14)

    fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
            title_text='Per Unit Retail and Wholesale Price Comparison',
            template='ggplot2')

    fig.write_html(path + "/Results/TariffWholesalePriceComparison.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
def Imbalance_Comparison():
    
    imbalance_stats = pd.read_csv(path + "/ImbalanceStats.csv")
    columns = imbalance_stats.columns.tolist()
    [columns.remove(x) for x in ['game-id', 'timeslot','consumption']]

    fig = px.line(imbalance_stats, x='timeslot', y=columns)

    fig.update_yaxes(title_text="Quantity (MWh)")
    fig.update_xaxes(title_text="Timeslot")

    fig.update_layout(
        height=750, 
        width=1500, 
        title_text='Broker and Net Imbalance Information',
        template='ggplot2',
    )

    for i in fig['layout']['annotations']:
        i['font'] = dict(size=14)

    fig.write_html(path + "/Results/ImbalanceComparison.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
def Imbalance_Cost_Analysis():    
    
    imbalace_cost_analysis = pd.read_csv(path + "/ImbalanceCostAnalysis.csv", delimiter=";")

    num_rows = 3
    num_cols = 1

    fig = make_subplots(rows=num_rows, 
                        cols=num_cols,
                        subplot_titles=('Net Imbalance', 'Imbalance Price', 'Ratio of Balacing and Mean Boot Price'),
                        vertical_spacing=0.10)


    fig.append_trace(go.Scatter(x = imbalace_cost_analysis['ts'], y = imbalace_cost_analysis[' imb'], name = 'imbalance'), row = 1, col = 1)
    fig.append_trace(go.Scatter(x = imbalace_cost_analysis['ts'], y = imbalace_cost_analysis[' imb-price']*1000, name = 'price'), row = 2, col = 1)
    fig.append_trace(go.Scatter(x = imbalace_cost_analysis['ts'], y = imbalace_cost_analysis[' ratio'], name = 'ratio'), row = 3, col = 1)

    fig.update_yaxes(title_text="Demand (MWh)", row = 1)
    fig.update_yaxes(title_text="Price ($/MWh)", row = 2)
    fig.update_xaxes(title_text="Timeslot", row = 3)

    fig.update_layout(height=750, width=1500, title_text='Imbalance Cost Analysis', template='ggplot2')

    for i in fig['layout']['annotations']:
        i['font'] = dict(size=14)

    fig.write_html(path + "/Results/ImbalanceCostAnalysis.html")

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------

# %%
for folder in folders_all_games:
    
    path = '/mnt/d/PowerTAC/PowerTAC2021/experiments/logtool_results/finals_2021/' + folder
    os.makedirs(path + "/Results", exist_ok=True)
    
    print('Analyzing ', folder, '...')
    
    try:
        Broker_Accounting()
    except Exception as e:
        print(e)
        
    try:
        Broker_Imbalance()
    except Exception as e:
        print(e)
        
    try:
        Tariff_Mkt_Share()
    except Exception as e:
        print(e)
        
    try:
        Total_Demand()
    except Exception as e:
        print(e)
        
    try:
        Production_Consumption()
    except Exception as e:
        print(e)
        
    try:
        Retail_Information()
    except Exception as e:
        print(e)
        
    try:
        Tariff_Wholesale_Price_Comparison()
    except Exception as e:
        print(e)
    
    try:
        Imbalance_Comparison()
    except Exception as e:
        print(e)
        
    try:
        Imbalance_Cost_Analysis()
    except Exception as e:
        print(e)

# %% [markdown]
# ## -------------------------------------- Extra Analysis after Finals2021 ---------------------------------------

# %%
 def vv_overall_analysis(folders, game_size):
        
    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/finals2021_overall_analysis.csv'
    fields = ['File_Name', 'Game_Size', 'VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', \
              'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']
    brokers = ['VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', 'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']
    
    with open(filename, 'w') as csvfile: 
        csvwriter = csv.writer(csvfile) 
        csvwriter.writerow(fields) 
        
    for folder in folders:
    
        path = '/mnt/d/PowerTAC/PowerTAC2021/experiments/logtool_results/finals_2021/' + folder
        os.makedirs(path + "/Results", exist_ok=True)
        print('Writing data for', folder, '...')
        
        """Average Market Share Information"""
        tariff_mkt_share = pd.read_csv(path + "/TariffMktShare.csv", index_col=False)
        list_of_brokers = tariff_mkt_share.iloc[:,1:].columns.tolist()
        tariff_mkt_share['Total'] = tariff_mkt_share.iloc[:,1:].sum(axis=1)

        for broker in list_of_brokers:
            tariff_mkt_share[broker] = (tariff_mkt_share[broker] / tariff_mkt_share['Total'])*100 
            
        final_list = [folder, game_size, tariff_mkt_share['VidyutVanika'].mean()]
        
        """VidyutVanika's Unit Price Information"""
        broker_imbalance_cost = pd.read_csv(path + "/BrokerImbalanceCost.csv")

        group_dataframe = broker_imbalance_cost.groupby(' broker').get_group('VidyutVanika')
        group_dataframe_mean = group_dataframe.mean()

        mean_mkt_qty = group_dataframe_mean[' mktQty']*(-1)
        mean_mkt_cost = group_dataframe_mean[' mktCost']
        try:
            unit_mkt_price = abs(mean_mkt_cost/mean_mkt_qty)*1000
        except:
            unit_mkt_price = 0.0
        mean_imb_qty = group_dataframe_mean[' imbalance']
        
        mean_imb_cost = group_dataframe_mean[' imbalanceCost']
        try:
            unit_imb_price = abs(mean_imb_cost/mean_imb_qty)*1000
        except:
            unit_imb_price = 0.0
        
        imbalance_summary = pd.read_csv(path + "/ImbalanceSummary.csv", header=None)
        imbalance_summary = imbalance_summary.iloc[2:,:-3]
        new_header = imbalance_summary.iloc[0]
        imbalance_summary = imbalance_summary[1:]
        imbalance_summary.columns = new_header

        imbalance_summary.iloc[:,1:] = imbalance_summary.iloc[:,1:].apply(pd.to_numeric)
        imbalance_summary_vv = imbalance_summary.loc[imbalance_summary['broker'] == 'VidyutVanika']

        try:
            unit_con_price = (abs(imbalance_summary_vv['c_revenue']/imbalance_summary_vv['c'])*1000).values[0]
        except:
            unit_con_price = 0.0
            
        try:
            unit_pro_price = (abs(imbalance_summary_vv['p_revenue']/imbalance_summary_vv['p'])*1000).values[0]
        except:
            unit_pro_price = 0.0
        
        unit_price_list = [unit_con_price, unit_pro_price, unit_mkt_price, unit_imb_price]

        final_list.extend(unit_price_list)
            
        """VidyutVanika's Accounting Information"""    
        broker_accounting = pd.read_csv(path + "/BrokerAccounting.csv")
        broker_costs = pd.read_csv(path + "/BrokerCostsU.csv")

        number_of_brokers = len(broker_costs['broker-name'])

        list_of_brokers = list()
        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting[col_broker].unique()[0]
            list_of_brokers.append(broker_name)

        columns = broker_accounting.iloc[:, 4:21].columns.tolist()

        start_index = 4

        accounting_list = list()

        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting[col_broker].unique()[0]

            dataframe = broker_accounting.iloc[:, start_index:(start_index+17)]
            dataframe.columns = columns
            
            if broker_name == 'VidyutVanika':
                
                tariff_exchange = dataframe['ttx-sc'].sum() + dataframe['ttx-sd'].sum() + \
                                  dataframe['ttx-uc'].sum() + dataframe['ttx-ud'].sum()
                wholesale_exchange = dataframe['mtx-c'].sum() + dataframe['mtx-d'].sum() + dataframe['dtx-c'].sum() + \
                                     dataframe['dtx-d'].sum() + dataframe['bank-c'].sum() + dataframe['bank-d'].sum()
                balancing_exchange = dataframe['btx-c'].sum() + dataframe['btx-d'].sum() + \
                                     dataframe['bce-c'].sum() + dataframe['bce-d'].sum()
                cap_trans_exchange = dataframe['ctx-c'].sum() + dataframe['ctx-d'].sum()
                final_cash = dataframe['cash'].iloc[-1]
                
                accounting_list.extend([tariff_exchange, wholesale_exchange, balancing_exchange, cap_trans_exchange, final_cash])

            start_index = start_index + 18
            
        final_list.extend(accounting_list)

        with open(filename, 'a') as csvfile: 
            csvwriter = csv.writer(csvfile) 
            csvwriter.writerows([final_list])

# vv_overall_analysis(folders, None)

# %%
 def mkt_share_analysis(folders, name):
        
    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/' + name + '.csv'
    fields = ['File_Name', 'Game_Size', 'VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', \
              'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']
    brokers = ['VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', 'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']
    
    with open(filename, 'w') as csvfile: 
        csvwriter = csv.writer(csvfile) 
        csvwriter.writerow(fields) 
        
    for folder in folders:
        
        try:
    
            path = '/mnt/d/PowerTAC/PowerTAC2021/experiments/logtool_results/finals_2021/' + folder

            """Average Market Share Information"""
            tariff_mkt_share = pd.read_csv(path + "/TariffMktShare.csv", index_col=False)
            list_of_brokers = tariff_mkt_share.iloc[:,1:].columns.tolist()
            tariff_mkt_share['Total'] = tariff_mkt_share.iloc[:,1:].sum(axis=1)
                        
            if folder in folders_7_games:
                game_size = 7
            elif folder in folders_5_games:
                game_size = 5;
            elif folder in folders_3_games:
                game_size = 3
            
            final_list = [folder, game_size]

            for broker in list_of_brokers:
                tariff_mkt_share[broker] = (tariff_mkt_share[broker] / tariff_mkt_share['Total'])*100 

            mkt_share_list = list()
            for broker in brokers:       
                if broker in tariff_mkt_share.columns.tolist():
                    mkt_share = tariff_mkt_share[broker].mean()
                else:
                    mkt_share = None
                mkt_share_list.append(mkt_share)

            final_list.extend(mkt_share_list)

            with open(filename, 'a') as csvfile: 
                csvwriter = csv.writer(csvfile) 
                csvwriter.writerows([final_list])
        
        except Exception as e:
            print(e)


# mkt_share_analysis(folders_all_games, 'OverallMarketShareAnalysis')

# %%
brokers_A = ['VidyutVanika21', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', 'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']

def mkt_share_analysis_plot():
    
    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallMarketShareAnalysis.csv'
    brokers = ['VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', 'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']
    
    mkt_share_cost_analysis = pd.read_csv(filename)
    mkt_share_cost_analysis_groupby = mkt_share_cost_analysis.groupby("Game_Size")
    
    average_mkt_share = list()
    average_7_mkt_share = list()
    average_5_mkt_share = list()
    average_3_mkt_share = list()

    for broker in brokers:

        average_mkt_share.append(mkt_share_cost_analysis[broker].mean(skipna=True))
        average_7_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(7)[broker].mean())
        average_5_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(5)[broker].mean())
        average_3_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(3)[broker].mean())

    fig = go.Figure(data = [
                (go.Bar(name='Overall', x=brokers_A, y=average_mkt_share, marker_color=color_book.get('overall'))),
                (go.Bar(name='7-Player', x=brokers_A, y=average_7_mkt_share, marker_color=color_book.get('7player'))),
                (go.Bar(name='5-Player', x=brokers_A, y=average_5_mkt_share, marker_color=color_book.get('5player'))),
                (go.Bar(name='3-Player', x=brokers_A, y=average_3_mkt_share, marker_color=color_book.get('3player')))
            ])    

    fig.update_yaxes(title_text="Market-Share (%)")
    fig.update_traces(marker_line_color='black', marker_line_width=1.0)
    for i in fig['layout']['annotations']:
            i['font'] = dict(size=28)
    fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
#             title_text='Average Market-Share Analysis',
            template='ggplot2',
            font=dict(size=28))
    fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

    fig.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallMarketShareAnalysis.html')

####################################################################################################################
    
def mkt_share_analysis_wrt_weather():
        
    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallMarketShareAnalysis.csv'
    weather_locations = ['denver', 'phoenix', 'minneapolis']
    brokers = ['VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', 'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']

    mkt_share_cost_analysis = pd.read_csv(filename)
    
    for location in weather_locations:
        
        mkt_share_cost_analysis_groupby_weather = mkt_share_cost_analysis.groupby("Weather_Location").get_group(location)
        mkt_share_cost_analysis_groupby = mkt_share_cost_analysis_groupby_weather.groupby("Game_Size")

        average_mkt_share = list()
        average_7_mkt_share = list()
        average_5_mkt_share = list()
        average_3_mkt_share = list()

        for broker in brokers:

            average_mkt_share.append(mkt_share_cost_analysis[broker].mean(skipna=True))
            average_7_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(7)[broker].mean())
            average_5_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(5)[broker].mean())
            average_3_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(3)[broker].mean())

        fig = go.Figure(data = [
                    (go.Bar(name='Overall', x=brokers_A, y=average_mkt_share, marker_color=color_book.get('overall'))),
                    (go.Bar(name='7-Player', x=brokers_A, y=average_7_mkt_share, marker_color=color_book.get('7player'))),
                    (go.Bar(name='5-Player', x=brokers_A, y=average_5_mkt_share, marker_color=color_book.get('5player'))),
                    (go.Bar(name='3-Player', x=brokers_A, y=average_3_mkt_share, marker_color=color_book.get('3player')))
                ])    

        fig.update_yaxes(title_text="Market-Share (%)")
        fig.update_traces(marker_line_color='black', marker_line_width=1.0)
        for i in fig['layout']['annotations']:
            i['font'] = dict(size=28)
        fig.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
#                 title_text='Average Market-Share Analysis for ' + location,
                template='ggplot2',
                font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

        fig.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallMarketShareAnalysis_' + location + '.html')
        
    mkt_share_cost_analysis_groupby_weather1 = mkt_share_cost_analysis.groupby("Weather_Location").get_group('denver')
    mkt_share_cost_analysis_groupby_weather2 = mkt_share_cost_analysis.groupby("Weather_Location").get_group('minneapolis')
    mkt_share_cost_analysis_groupby_weather = pd.concat([mkt_share_cost_analysis_groupby_weather1, mkt_share_cost_analysis_groupby_weather2])
    mkt_share_cost_analysis_groupby = mkt_share_cost_analysis_groupby_weather.groupby("Game_Size")

    average_mkt_share = list()
    average_7_mkt_share = list()
    average_5_mkt_share = list()
    average_3_mkt_share = list()

    for broker in brokers:

        average_mkt_share.append(mkt_share_cost_analysis[broker].mean(skipna=True))
        average_7_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(7)[broker].mean())
        average_5_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(5)[broker].mean())
        average_3_mkt_share.append(mkt_share_cost_analysis_groupby.get_group(3)[broker].mean())

        fig = go.Figure(data = [
                (go.Bar(name='Overall', x=brokers_A, y=average_mkt_share, marker_color=color_book.get('overall'))),
                (go.Bar(name='7-Player', x=brokers_A, y=average_7_mkt_share, marker_color=color_book.get('7player'))),
                (go.Bar(name='5-Player', x=brokers_A, y=average_5_mkt_share, marker_color=color_book.get('5player'))),
                (go.Bar(name='3-Player', x=brokers_A, y=average_3_mkt_share, marker_color=color_book.get('3player')))
            ])    

        fig.update_yaxes(title_text="Market-Share (%)")
        fig.update_traces(marker_line_color='black', marker_line_width=1.0)
        for i in fig['layout']['annotations']:
            i['font'] = dict(size=28)
        fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
#             title_text='Average Market-Share Analysis for Regular Games',
            template='ggplot2',
            font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

        fig.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallMarketShareAnalysis_Regular.html')

####################################################################################################################        
        
# mkt_share_analysis_plot()
# mkt_share_analysis_wrt_weather()

# %%
 def overall_analysis(folders, name):
        
    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/' + name + '.csv'
    fields = ['File_Name', 'Game_Size', 
              'broker0', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'tariff_exchange', 'wholesale_exchange', 'balancing_exchange', 'cap_trans_exchange', 'final_cash',
              'broker1', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'tariff_exchange', 'wholesale_exchange', 'balancing_exchange', 'cap_trans_exchange', 'final_cash', 
              'broker2', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'tariff_exchange', 'wholesale_exchange', 'balancing_exchange', 'cap_trans_exchange', 'final_cash', 
              'broker3', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'tariff_exchange', 'wholesale_exchange', 'balancing_exchange', 'cap_trans_exchange', 'final_cash', 
              'broker4', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'tariff_exchange', 'wholesale_exchange', 'balancing_exchange', 'cap_trans_exchange', 'final_cash', 
              'broker5', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'tariff_exchange', 'wholesale_exchange', 'balancing_exchange', 'cap_trans_exchange', 'final_cash',
              'broker6', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'tariff_exchange', 'wholesale_exchange', 'balancing_exchange', 'cap_trans_exchange', 'final_cash']
    brokers = ['VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', 'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']
    
    with open(filename, 'w') as csvfile: 
        csvwriter = csv.writer(csvfile) 
        csvwriter.writerow(fields) 
        
    for folder in folders:
    
        path = '/mnt/d/PowerTAC/PowerTAC2021/experiments/logtool_results/finals_2021/' + folder
        
        """Average Market Share Information"""
        tariff_mkt_share = pd.read_csv(path + "/TariffMktShare.csv", index_col=False)
        tariff_mkt_share['Total'] = tariff_mkt_share.iloc[:,1:].sum(axis=1)
        
        imbalance_summary = pd.read_csv(path + "/ImbalanceSummary.csv", header=None)
        imbalance_summary = imbalance_summary.iloc[2:,:-3]
        new_header = imbalance_summary.iloc[0]
        imbalance_summary = imbalance_summary[1:]
        imbalance_summary.columns = new_header
        imbalance_summary.iloc[:,1:] = imbalance_summary.iloc[:,1:].apply(pd.to_numeric)
        
        broker_imbalance_cost = pd.read_csv(path + "/BrokerImbalanceCost.csv")
        group_dataframe = broker_imbalance_cost.groupby(' broker')
        
        broker_accounting = pd.read_csv(path + "/BrokerAccounting.csv")
        broker_costs = pd.read_csv(path + "/BrokerCostsU.csv")

        number_of_brokers = len(broker_costs['broker-name'])

        list_of_brokers = list()
        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting[col_broker].unique()[0]
            list_of_brokers.append(broker_name)

        columns = broker_accounting.iloc[:, 4:21].columns.tolist()

        if folder in folders_7_games:
            game_size = 7
        elif folder in folders_5_games:
            game_size = 5;
        elif folder in folders_3_games:
            game_size = 3

        final_list = [folder, game_size]

        for broker in list_of_brokers:
            tariff_mkt_share[broker] = (tariff_mkt_share[broker] / tariff_mkt_share['Total'])*100 

        additional_list = list()
        
        for broker in brokers:   
            
            additional_list.append(broker)
            
            if broker in tariff_mkt_share.columns.tolist():
                
                mkt_share = tariff_mkt_share[broker].mean()
                
                imbalance_summary_vv = imbalance_summary.loc[imbalance_summary['broker'] == broker]

                try:
                    unit_con_price = (abs(imbalance_summary_vv['c_revenue']/imbalance_summary_vv['c'])*1000).values[0]
                except:
                    unit_con_price = 0.0

                try:
                    unit_pro_price = (abs(imbalance_summary_vv['p_revenue']/imbalance_summary_vv['p'])*1000).values[0]
                except:
                    unit_pro_price = 0.0

                group_dataframe_mean = group_dataframe.get_group(broker).mean()

                mean_mkt_qty = group_dataframe_mean[' mktQty']*(-1)
                mean_mkt_cost = group_dataframe_mean[' mktCost']
                try:
                    unit_mkt_price = abs(mean_mkt_cost/mean_mkt_qty)*1000
                except:
                    unit_mkt_price = 0.0
                mean_imb_qty = group_dataframe_mean[' imbalance']

                mean_imb_cost = group_dataframe_mean[' imbalanceCost']
                try:
                    unit_imb_price = abs(mean_imb_cost/mean_imb_qty)*1000
                except:
                    unit_imb_price = 0.0

                additional_list.extend([mkt_share, unit_con_price, unit_pro_price, unit_mkt_price, unit_imb_price])
                
            else:
                additional_list.extend([None, None, None, None, None])
                                                    
            start_index = 4
            accounting_flag = False
            
            for ind in range(number_of_brokers):

                col_broker = 'broker' + str(ind)
                broker_name = broker_accounting[col_broker].unique()[0]

                if broker_name == broker:
                    
                    dataframe = broker_accounting.iloc[:, start_index:(start_index+17)].copy()
                    dataframe.columns = columns

                    tariff_exchange = dataframe['ttx-sc'].sum() + dataframe['ttx-sd'].sum() + \
                                      dataframe['ttx-uc'].sum() + dataframe['ttx-ud'].sum()
                    wholesale_exchange = dataframe['mtx-c'].sum() + dataframe['mtx-d'].sum() + dataframe['dtx-c'].sum() + \
                                         dataframe['dtx-d'].sum() + dataframe['bank-c'].sum() + dataframe['bank-d'].sum()
                    balancing_exchange = dataframe['btx-c'].sum() + dataframe['btx-d'].sum() + \
                                         dataframe['bce-c'].sum() + dataframe['bce-d'].sum()
                    cap_trans_exchange = dataframe['ctx-c'].sum() + dataframe['ctx-d'].sum()
                    final_cash = dataframe['cash'].iloc[-1]

                    additional_list.extend([tariff_exchange, wholesale_exchange, balancing_exchange, cap_trans_exchange, final_cash])
                    accounting_flag = True
                    break

                start_index = start_index + 18
            
            if accounting_flag == False:
                additional_list.extend([None, None, None, None, None])
                            
        final_list.extend(additional_list)

        with open(filename, 'a') as csvfile: 
            csvwriter = csv.writer(csvfile) 
            csvwriter.writerows([final_list])
        

# overall_analysis(folders_all_games, 'OverallAnalysis')

# %%
def overall_analysis_plotting():
    
    number_of_brokers = 7
    list_of_brokers = list()

    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallAnalysis.csv'
    broker_accounting = pd.read_csv(filename)

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting[col_broker].unique()[0]
        list_of_brokers.append(broker_name)

    columns = broker_accounting.iloc[:, 4:15].columns.tolist()

    start_index = 4

    unit_con_price = list()
    unit_prod_price = list()
    unit_mkt_price = list()
    unit_imb_price = list()
    tariff_exc = list()
    wholesale_exc = list()
    balancing_exc = list()
    cap_tran_exc = list()
    final_cash = list()

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting[col_broker].unique()[0]

        dataframe = broker_accounting.iloc[:, start_index:(start_index+11)]
        dataframe.columns = columns

        unit_con_price.append(dataframe['unit_con_price'].mean())
        unit_prod_price.append(dataframe['unit_pro_price'].mean())
        unit_mkt_price.append(dataframe['unit_mkt_price'].mean())
        unit_imb_price.append(dataframe['unit_imb_price'].mean())
        tariff_exc.append(dataframe['tariff_exchange'].sum())
        wholesale_exc.append(dataframe['wholesale_exchange'].sum())
        balancing_exc.append(dataframe['balancing_exchange'].sum())
        cap_tran_exc.append(dataframe['cap_trans_exchange'].sum())
        final_cash.append(dataframe['final_cash'].sum())

        start_index = start_index + 11

    fig = go.Figure(data = [
            (go.Bar(name='consumption rate', x=brokers_A, y=unit_con_price, marker_color=color_book.get('overall'))),
            (go.Bar(name='production rate', x=brokers_A, y=unit_prod_price, marker_color=color_book.get('7player'))),
            (go.Bar(name='wholesale rate', x=brokers_A, y=unit_mkt_price, marker_color=color_book.get('5player'))),
            (go.Bar(name='imbalance rate', x=brokers_A, y=unit_imb_price, marker_color=color_book.get('9player')))
        ])    

    fig.update_yaxes(title_text="Unit-Price ($/MWh)")
    fig.update_traces(marker_line_color='black', marker_line_width=1.0)
    for i in fig['layout']['annotations']:
            i['font'] = dict(size=28)
    fig.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
#             title_text='Accounting Information',
            template='ggplot2',
            font=dict(size=28))
    fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

#     fig.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallUnitPriceAnalysis.html')

    fig1 = go.Figure(data = [
            (go.Bar(name='<b>Tariff</b>', x=brokers_A, y=tariff_exc, marker_color=color_book.get('overall'))),
            (go.Bar(name='<b>Wholesale</b>', x=brokers_A, y=wholesale_exc, marker_color=color_book.get('7player'))),
            (go.Bar(name='<b>Balancing</b>', x=brokers_A, y=balancing_exc, marker_color=color_book.get('5player'))),
            (go.Bar(name='<b>Cap. Trans.</b>', x=brokers_A, y=cap_tran_exc, marker_color=color_book.get('3player'))),
            (go.Bar(name='<b>Final Cash</b>', x=brokers_A, y=final_cash, marker_color=color_book.get('9player')))
        ])    

    fig1.update_xaxes(tickfont_family="Arial Black")
    fig1.update_yaxes(title_text="<b>Price ($)</b>", tickfont_family="Arial Black")
    fig1.update_traces(marker_line_color='black', marker_line_width=1.0)
    for i in fig['layout']['annotations']:
            i['font'] = dict(size=25)
    fig1.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
#             title_text='Accounting Information',
            template='ggplot2',
            font=dict(size=25))
    fig.update_layout(legend = dict(font = dict(size = 25)), legend_title = dict(font = dict(size = 25)))

    fig1.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallPriceAnalysis.html')

####################################################################################################################

def overall_analysis_plotting_game_size():
    
    number_of_brokers = 7

    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallAnalysis.csv'
    broker_accounting = pd.read_csv(filename)
    
    game_sizes = [3, 5, 7]
    
    broker_accounting_groupby = broker_accounting.groupby('Game_Size')
    
    for game_size in game_sizes:
        
        broker_accounting_groupby_game_size = broker_accounting_groupby.get_group(game_size)
        list_of_brokers = list()
        
        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_game_size[col_broker].unique()[0]
            list_of_brokers.append(broker_name)

        columns = broker_accounting_groupby_game_size.iloc[:, 4:15].columns.tolist()

        start_index = 4

        unit_con_price = list()
        unit_prod_price = list()
        unit_mkt_price = list()
        unit_imb_price = list()
        tariff_exc = list()
        wholesale_exc = list()
        balancing_exc = list()
        cap_tran_exc = list()
        final_cash = list()

        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_game_size[col_broker].unique()[0]

            dataframe = broker_accounting_groupby_game_size.iloc[:, start_index:(start_index+11)]
            dataframe.columns = columns

            unit_con_price.append(dataframe['unit_con_price'].mean())
            unit_prod_price.append(dataframe['unit_pro_price'].mean())
            unit_mkt_price.append(dataframe['unit_mkt_price'].mean())
            unit_imb_price.append(dataframe['unit_imb_price'].mean())
            tariff_exc.append(dataframe['tariff_exchange'].sum())
            wholesale_exc.append(dataframe['wholesale_exchange'].sum())
            balancing_exc.append(dataframe['balancing_exchange'].sum())
            cap_tran_exc.append(dataframe['cap_trans_exchange'].sum())
            final_cash.append(dataframe['final_cash'].sum())

            start_index = start_index + 11

        fig = go.Figure(data = [
                (go.Bar(name='consumption rate', x=brokers_A, y=unit_con_price, marker_color=color_book.get('overall'))),
                (go.Bar(name='production rate', x=brokers_A, y=unit_prod_price, marker_color=color_book.get('7player'))),
                (go.Bar(name='wholesale rate', x=brokers_A, y=unit_mkt_price, marker_color=color_book.get('5player'))),
                (go.Bar(name='imbalance rate', x=brokers_A, y=unit_imb_price, marker_color=color_book.get('9player')))
            ])    

        fig.update_yaxes(title_text="Unit-Price ($/MWh)")
        fig.update_traces(marker_line_color='black', marker_line_width=1.0)

        fig.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title_text='Accounting Information for Game-Size ' + str(game_size),
                template='ggplot2',
                font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

        fig.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallUnitPriceAnalysis_'+ str(game_size) + '.html')

        fig1 = go.Figure(data = [
                (go.Bar(name='tariff', x=brokers_A, y=tariff_exc, marker_color=color_book.get('overall'))),
                (go.Bar(name='wholesale', x=brokers_A, y=wholesale_exc, marker_color=color_book.get('7player'))),
                (go.Bar(name='balancing', x=brokers_A, y=balancing_exc, marker_color=color_book.get('5player'))),
                (go.Bar(name='cap. trans.', x=brokers_A, y=cap_tran_exc, marker_color=color_book.get('3player'))),
                (go.Bar(name='final cash', x=brokers_A, y=final_cash, marker_color=color_book.get('9player')))
            ])    

        fig1.update_yaxes(title_text="Price ($)")
        fig1.update_traces(marker_line_color='black', marker_line_width=1.0)

        fig1.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title_text='Accounting Information for Game-Size ' + str(game_size),
                template='ggplot2',
                font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

        fig1.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallPriceAnalysis_' + str(game_size) + '.html')
        
####################################################################################################################

def overall_analysis_plotting_weather():
    
    number_of_brokers = 7

    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallAnalysis.csv'
    broker_accounting = pd.read_csv(filename)
    
    weather_locations = ['denver', 'phoenix', 'minneapolis']
    
    broker_accounting_groupby = broker_accounting.groupby('Weather_Location')
    
    for location in weather_locations:
        
        broker_accounting_groupby_location = broker_accounting_groupby.get_group(location)
        list_of_brokers = list()
        
        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_location[col_broker].unique()[0]
            list_of_brokers.append(broker_name)

        columns = broker_accounting_groupby_location.iloc[:, 4:15].columns.tolist()

        start_index = 4

        unit_con_price = list()
        unit_prod_price = list()
        unit_mkt_price = list()
        unit_imb_price = list()
        tariff_exc = list()
        wholesale_exc = list()
        balancing_exc = list()
        cap_tran_exc = list()
        final_cash = list()

        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_location[col_broker].unique()[0]

            dataframe = broker_accounting_groupby_location.iloc[:, start_index:(start_index+11)]
            dataframe.columns = columns

            unit_con_price.append(dataframe['unit_con_price'].mean())
            unit_prod_price.append(dataframe['unit_pro_price'].mean())
            unit_mkt_price.append(dataframe['unit_mkt_price'].mean())
            unit_imb_price.append(dataframe['unit_imb_price'].mean())
            tariff_exc.append(dataframe['tariff_exchange'].sum())
            wholesale_exc.append(dataframe['wholesale_exchange'].sum())
            balancing_exc.append(dataframe['balancing_exchange'].sum())
            cap_tran_exc.append(dataframe['cap_trans_exchange'].sum())
            final_cash.append(dataframe['final_cash'].sum())

            start_index = start_index + 11

        fig = go.Figure(data = [
                (go.Bar(name='consumption rate', x=brokers_A, y=unit_con_price, marker_color=color_book.get('overall'))),
                (go.Bar(name='production rate', x=brokers_A, y=unit_prod_price, marker_color=color_book.get('7player'))),
                (go.Bar(name='wholesale rate', x=brokers_A, y=unit_mkt_price, marker_color=color_book.get('5player'))),
                (go.Bar(name='imbalance rate', x=brokers_A, y=unit_imb_price, marker_color=color_book.get('9player')))
            ])    

        fig.update_yaxes(title_text="Unit-Price ($/MWh)")
        fig.update_traces(marker_line_color='black', marker_line_width=1.0)

        fig.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title_text='Accounting Information for ' + location,
                template='ggplot2',
                font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

        fig.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallUnitPriceAnalysis_'+ location + '.html')

        fig1 = go.Figure(data = [
                (go.Bar(name='tariff', x=brokers_A, y=tariff_exc, marker_color=color_book.get('overall'))),
                (go.Bar(name='wholesale', x=brokers_A, y=wholesale_exc, marker_color=color_book.get('7player'))),
                (go.Bar(name='balancing', x=brokers_A, y=balancing_exc, marker_color=color_book.get('5player'))),
                (go.Bar(name='cap. trans.', x=brokers_A, y=cap_tran_exc, marker_color=color_book.get('3player'))),
                (go.Bar(name='final cash', x=brokers_A, y=final_cash, marker_color=color_book.get('9player')))
            ])    

        fig1.update_yaxes(title_text="Price ($)")
        fig1.update_traces(marker_line_color='black', marker_line_width=1.0)

        fig1.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title_text='Accounting Information for ' + location,
                template='ggplot2',
                font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))
        
        fig1.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallPriceAnalysis_' + location + '.html')
        
   
    weather_locations = ['denver', 'phoenix', 'minneapolis']
    
    broker_accounting_groupby = broker_accounting.groupby('Weather_Location')
            
    broker_accounting_groupby_location1 = broker_accounting_groupby.get_group('denver')
    broker_accounting_groupby_location2 = broker_accounting_groupby.get_group('minneapolis')
    broker_accounting_groupby_location = pd.concat([broker_accounting_groupby_location1, broker_accounting_groupby_location2])
    list_of_brokers = list()

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting_groupby_location[col_broker].unique()[0]
        list_of_brokers.append(broker_name)

    columns = broker_accounting_groupby_location.iloc[:, 4:15].columns.tolist()

    start_index = 4

    unit_con_price = list()
    unit_prod_price = list()
    unit_mkt_price = list()
    unit_imb_price = list()
    tariff_exc = list()
    wholesale_exc = list()
    balancing_exc = list()
    cap_tran_exc = list()
    final_cash = list()

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting_groupby_location[col_broker].unique()[0]

        dataframe = broker_accounting_groupby_location.iloc[:, start_index:(start_index+11)]
        dataframe.columns = columns

        unit_con_price.append(dataframe['unit_con_price'].mean())
        unit_prod_price.append(dataframe['unit_pro_price'].mean())
        unit_mkt_price.append(dataframe['unit_mkt_price'].mean())
        unit_imb_price.append(dataframe['unit_imb_price'].mean())
        tariff_exc.append(dataframe['tariff_exchange'].sum())
        wholesale_exc.append(dataframe['wholesale_exchange'].sum())
        balancing_exc.append(dataframe['balancing_exchange'].sum())
        cap_tran_exc.append(dataframe['cap_trans_exchange'].sum())
        final_cash.append(dataframe['final_cash'].sum())

        start_index = start_index + 11

        fig = go.Figure(data = [
                (go.Bar(name='consumption rate', x=brokers_A, y=unit_con_price, marker_color=color_book.get('overall'))),
                (go.Bar(name='production rate', x=brokers_A, y=unit_prod_price, marker_color=color_book.get('7player'))),
                (go.Bar(name='wholesale rate', x=brokers_A, y=unit_mkt_price, marker_color=color_book.get('5player'))),
                (go.Bar(name='imbalance rate', x=brokers_A, y=unit_imb_price, marker_color=color_book.get('9player')))
            ])    

        fig.update_yaxes(title_text="Unit-Price ($/MWh)")
        fig.update_traces(marker_line_color='black', marker_line_width=1.0)

        fig.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title_text='Accounting Information for Regular Games',
                template='ggplot2',
                font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

        fig.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallUnitPriceAnalysis_Regular.html')

        fig1 = go.Figure(data = [
                (go.Bar(name='tariff', x=brokers_A, y=tariff_exc, marker_color=color_book.get('overall'))),
                (go.Bar(name='wholesale', x=brokers_A, y=wholesale_exc, marker_color=color_book.get('7player'))),
                (go.Bar(name='balancing', x=brokers_A, y=balancing_exc, marker_color=color_book.get('5player'))),
                (go.Bar(name='cap. trans.', x=brokers_A, y=cap_tran_exc, marker_color=color_book.get('3player'))),
                (go.Bar(name='final cash', x=brokers_A, y=final_cash, marker_color=color_book.get('9player')))
            ])    

        fig1.update_yaxes(title_text="Price ($)")
        fig1.update_traces(marker_line_color='black', marker_line_width=1.0)

        fig1.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title_text='Accounting Information for Regular Games',
                template='ggplot2',
                font=dict(size=28))
        fig.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 30)))

        fig1.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallPriceAnalysis_Regular.html')

####################################################################################################################

overall_analysis_plotting()
# overall_analysis_plotting_game_size()
# overall_analysis_plotting_weather()

# %%
 def overall_analysis_extra(folders, name):
        
    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/' + name + '.csv'
    fields = ['File_Name', 'Game_Size', 
              'broker0', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'con_quan', 'pro_quan', 'mkt_quan', 'imb_quan',
              'broker1', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'con_quan', 'pro_quan', 'mkt_quan', 'imb_quan',
              'broker2', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'con_quan', 'pro_quan', 'mkt_quan', 'imb_quan',
              'broker3', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'con_quan', 'pro_quan', 'mkt_quan', 'imb_quan',
              'broker4', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'con_quan', 'pro_quan', 'mkt_quan', 'imb_quan',
              'broker5', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'con_quan', 'pro_quan', 'mkt_quan', 'imb_quan',
              'broker6', 'mkt_share', 'unit_con_price', 'unit_pro_price', 'unit_mkt_price', 'unit_imb_price', 'con_quan', 'pro_quan', 'mkt_quan', 'imb_quan']
    brokers = ['VidyutVanika', 'TUC_TAC', 'CrocodileAgent2020', 'IS3', 'COLDPOWER2021', 'UTA_PTA2021', 'Mertacor2021']
    
    with open(filename, 'w') as csvfile: 
        csvwriter = csv.writer(csvfile) 
        csvwriter.writerow(fields) 
        
    for folder in folders:
    
        path = '/mnt/d/PowerTAC/PowerTAC2021/experiments/logtool_results/finals_2021/' + folder
        
        """Average Market Share Information"""
        tariff_mkt_share = pd.read_csv(path + "/TariffMktShare.csv", index_col=False)
        tariff_mkt_share['Total'] = tariff_mkt_share.iloc[:,1:].sum(axis=1)
        
        imbalance_summary = pd.read_csv(path + "/ImbalanceSummary.csv", header=None)
        imbalance_summary = imbalance_summary.iloc[2:,:-3]
        new_header = imbalance_summary.iloc[0]
        imbalance_summary = imbalance_summary[1:]
        imbalance_summary.columns = new_header
        imbalance_summary.iloc[:,1:] = imbalance_summary.iloc[:,1:].apply(pd.to_numeric)
        
        broker_imbalance_cost = pd.read_csv(path + "/BrokerImbalanceCost.csv")
        group_dataframe = broker_imbalance_cost.groupby(' broker')
        
        broker_accounting = pd.read_csv(path + "/BrokerAccounting.csv")
        broker_costs = pd.read_csv(path + "/BrokerCostsU.csv")

        number_of_brokers = len(broker_costs['broker-name'])

        list_of_brokers = list()
        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting[col_broker].unique()[0]
            list_of_brokers.append(broker_name)

        columns = broker_accounting.iloc[:, 4:21].columns.tolist()

        if folder in folders_7_games:
            game_size = 7
        elif folder in folders_5_games:
            game_size = 5;
        elif folder in folders_3_games:
            game_size = 3

        final_list = [folder, game_size]

        for broker in list_of_brokers:
            tariff_mkt_share[broker] = (tariff_mkt_share[broker] / tariff_mkt_share['Total'])*100 

        additional_list = list()
        
        for broker in brokers:   
            
            additional_list.append(broker)
            
            if broker in tariff_mkt_share.columns.tolist():
                
                mkt_share = tariff_mkt_share[broker].mean()
                
                imbalance_summary_vv = imbalance_summary.loc[imbalance_summary['broker'] == broker]

                try:
                    unit_con_price = (abs(imbalance_summary_vv['c_revenue']/imbalance_summary_vv['c'])*1000).values[0]
                except:
                    unit_con_price = 0.0

                try:
                    unit_pro_price = (abs(imbalance_summary_vv['p_revenue']/imbalance_summary_vv['p'])*1000).values[0]
                except:
                    unit_pro_price = 0.0
                    
                con_quan = (imbalance_summary_vv['c']/1000.0).values[0]
                pro_quan = (imbalance_summary_vv['p']/1000.0).values[0]

                group_dataframe_mean = group_dataframe.get_group(broker).mean()
                game_length = group_dataframe.size()[0]

                mean_mkt_qty = group_dataframe_mean[' mktQty']
                mean_mkt_cost = group_dataframe_mean[' mktCost']
                try:
                    unit_mkt_price = abs(mean_mkt_cost/mean_mkt_qty)*1000
                except:
                    unit_mkt_price = 0.0
                mean_imb_qty = group_dataframe_mean[' imbalance']

                mean_imb_cost = group_dataframe_mean[' imbalanceCost']
                try:
                    unit_imb_price = abs(mean_imb_cost/mean_imb_qty)*1000
                except:
                    unit_imb_price = 0.0

                additional_list.extend([mkt_share, unit_con_price, unit_pro_price, unit_mkt_price, unit_imb_price, con_quan/game_length, pro_quan/game_length, mean_mkt_qty/1000.0, mean_imb_qty/1000.0])
                
            else:
                additional_list.extend([None, None, None, None, None, None, None, None, None])

        final_list.extend(additional_list)
        
        with open(filename, 'a') as csvfile: 
            csvwriter = csv.writer(csvfile) 
            csvwriter.writerows([final_list])
        

# overall_analysis_extra(folders_all_games, 'OverallAnalysisExtra')

# %%
def overall_analysis_extra_plotting():
    
    number_of_brokers = 7
    list_of_brokers = list()
    list_of_features = ['Consumption', 'Production', 'Wholesale', 'Imbalance']
    list_of_features1 = ['Consumption', 'Production', 'Wholesale', 'Imbalance']

    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallAnalysisExtra.csv'
    broker_accounting = pd.read_csv(filename)

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting[col_broker].unique()[0]
        list_of_brokers.append(broker_name)

    columns = broker_accounting.iloc[:, 4:14].columns.tolist()

    start_index = 4
    
    vv21 = list()
    tuc_tac = list()
    croc = list()
    is3 = list()
    coldpower = list()
    uta_pta = list()
    mertacor = list()
    
    vv21_1 = list()
    tuc_tac_1 = list()
    croc_1 = list()
    is3_1 = list()
    coldpower_1 = list()
    uta_pta_1 = list()
    mertacor_1 = list()
    
    broker_map = {'VidyutVanika': vv21, 'TUC_TAC': tuc_tac, 'CrocodileAgent2020': croc, 'IS3': is3,
                  'COLDPOWER2021': coldpower, 'UTA_PTA2021': uta_pta, 'Mertacor2021': mertacor}
    
    broker_map1 = {'VidyutVanika': vv21_1, 'TUC_TAC': tuc_tac_1, 'CrocodileAgent2020': croc_1, 'IS3': is3_1,
                  'COLDPOWER2021': coldpower_1, 'UTA_PTA2021': uta_pta_1, 'Mertacor2021': mertacor_1}

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting[col_broker].unique()[0]

        dataframe = broker_accounting.iloc[:, start_index:(start_index+10)]
        dataframe.columns = columns
        
        bkr = broker_map.get(broker_name)

        bkr.append(dataframe['unit_con_price'].mean())
        bkr.append(dataframe['unit_pro_price'].mean())
        bkr.append(dataframe['unit_mkt_price'].mean())
        bkr.append(dataframe['unit_imb_price'].mean())
        
        bkr1 = broker_map1.get(broker_name)
        
        bkr1.append(dataframe['con_quan'].sum()*(-1))
        bkr1.append(dataframe['pro_quan'].sum()*(-1))
        bkr1.append(dataframe['mkt_quan'].sum()*(-1))
        bkr1.append(dataframe['imb_quan'].sum())

        start_index = start_index + 10
   
    num_rows = 1
    num_cols = 2

    fig2 = make_subplots(rows=num_rows, 
                         cols=num_cols,
                         subplot_titles=('Unit Price Comparison', 'Quantity Comparison'))
    
    trace1 = go.Bar(name='AIB', x=list_of_features, y=vv21, marker_color=color_book.get('VidyutVanika'), legendgroup = 1)
    trace2 = go.Bar(name='TB1', x=list_of_features, y=tuc_tac, marker_color=color_book.get('TUC_TAC'), legendgroup = 1)
    trace3 = go.Bar(name='TB2', x=list_of_features, y=croc, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 1)
    trace4 = go.Bar(name='TB3', x=list_of_features, y=is3, marker_color=color_book.get('IS3'), legendgroup = 1)
    trace5 = go.Bar(name='TB4', x=list_of_features, y=coldpower, marker_color=color_book.get('COLDPOWER'), legendgroup = 1)
    trace6 = go.Bar(name='TB5', x=list_of_features, y=uta_pta, marker_color=color_book.get('UTA_PTA'), legendgroup = 1)
    trace7 = go.Bar(name='TB6', x=list_of_features, y=mertacor, marker_color=color_book.get('Mertacor'), legendgroup = 1)
    
    trace1_1 = go.Bar(name='AIB', x=list_of_features1, y=vv21_1, marker_color=color_book.get('VidyutVanika'), legendgroup = 2, showlegend=False)
    trace2_1 = go.Bar(name='TB1', x=list_of_features1, y=tuc_tac_1, marker_color=color_book.get('TUC_TAC'), legendgroup = 2, showlegend=False)
    trace3_1 = go.Bar(name='TB2', x=list_of_features1, y=croc_1, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 2, showlegend=False)
    trace4_1 = go.Bar(name='TB3', x=list_of_features1, y=is3_1, marker_color=color_book.get('IS3'), legendgroup = 2, showlegend=False)
    trace5_1 = go.Bar(name='TB4', x=list_of_features1, y=coldpower_1, marker_color=color_book.get('COLDPOWER'), legendgroup = 2, showlegend=False)
    trace6_1 = go.Bar(name='TB5', x=list_of_features1, y=uta_pta_1, marker_color=color_book.get('UTA_PTA'), legendgroup = 2, showlegend=False)
    trace7_1 = go.Bar(name='TB6', x=list_of_features1, y=mertacor_1, marker_color=color_book.get('Mertacor'), legendgroup = 2, showlegend=False)

    fig2.append_trace(trace1, row = 1, col = 1)
    fig2.append_trace(trace2, row = 1, col = 1)
    fig2.append_trace(trace3, row = 1, col = 1)
    fig2.append_trace(trace4, row = 1, col = 1)
    fig2.append_trace(trace5, row = 1, col = 1)
    fig2.append_trace(trace6, row = 1, col = 1)
    fig2.append_trace(trace7, row = 1, col = 1)
    
    fig2.append_trace(trace1_1, row = 1, col = 2)
    fig2.append_trace(trace2_1, row = 1, col = 2)
    fig2.append_trace(trace3_1, row = 1, col = 2)
    fig2.append_trace(trace4_1, row = 1, col = 2)
    fig2.append_trace(trace5_1, row = 1, col = 2)
    fig2.append_trace(trace6_1, row = 1, col = 2)
    fig2.append_trace(trace7_1, row = 1, col = 2)

    fig2.update_yaxes(title_text='Price ($/MWh)', row = 1, col = 1)
    fig2.update_yaxes(title_text='Quantity (MWh)', row = 1, col = 2)
    fig2.update_traces(marker_line_color='black', marker_line_width=1.0)
    
    fig2.update_annotations(font_size=24)
    fig2.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
#             title='Accounting Information for Regular Games',
            template='ggplot2',
            font=dict(size=24))
    
    for i in fig2['layout']['annotations']:
            i['font'] = dict(size=24)

    fig2.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
#             title='Accounting Information Overall',
            template='ggplot2')
    fig2.update_layout(legend = dict(font = dict(size = 40)), legend_title = dict(font = dict(size = 20)))

    fig2.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallAnalysisExtra.html')
    
####################################################################################################################

def overall_analysis_extra_plotting_game_size():
    
    number_of_brokers = 7

    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallAnalysisExtra.csv'
    broker_accounting = pd.read_csv(filename)
    
    game_sizes = [3, 5, 7]
    
    broker_accounting_groupby = broker_accounting.groupby('Game_Size')
    
    for game_size in game_sizes:
        
        broker_accounting_groupby_game_size = broker_accounting_groupby.get_group(game_size)
        list_of_brokers = list()
        list_of_features = ['Consumption', 'Production', 'Wholesale', 'Imbalance']
        list_of_features1 = ['Total Consumption', 'Total Production', 'Total Wholesale', 'Total Imbalance']
        
        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_game_size[col_broker].unique()[0]
            list_of_brokers.append(broker_name)

        columns = broker_accounting_groupby_game_size.iloc[:, 4:14].columns.tolist()
        
        start_index = 4
    
        vv21 = list()
        tuc_tac = list()
        croc = list()
        is3 = list()
        coldpower = list()
        uta_pta = list()
        mertacor = list()

        vv21_1 = list()
        tuc_tac_1 = list()
        croc_1 = list()
        is3_1 = list()
        coldpower_1 = list()
        uta_pta_1 = list()
        mertacor_1 = list()

        broker_map = {'VidyutVanika': vv21, 'TUC_TAC': tuc_tac, 'CrocodileAgent2020': croc, 'IS3': is3,
                      'COLDPOWER2021': coldpower, 'UTA_PTA2021': uta_pta, 'Mertacor2021': mertacor}

        broker_map1 = {'VidyutVanika': vv21_1, 'TUC_TAC': tuc_tac_1, 'CrocodileAgent2020': croc_1, 'IS3': is3_1,
                      'COLDPOWER2021': coldpower_1, 'UTA_PTA2021': uta_pta_1, 'Mertacor2021': mertacor_1}

        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_game_size[col_broker].unique()[0]

            dataframe = broker_accounting_groupby_game_size.iloc[:, start_index:(start_index+10)]
            dataframe.columns = columns

            bkr = broker_map.get(broker_name)

            bkr.append(dataframe['unit_con_price'].mean())
            bkr.append(dataframe['unit_pro_price'].mean())
            bkr.append(dataframe['unit_mkt_price'].mean())
            bkr.append(dataframe['unit_imb_price'].mean())

            bkr1 = broker_map1.get(broker_name)

            bkr1.append(dataframe['con_quan'].sum()*(-1))
            bkr1.append(dataframe['pro_quan'].sum()*(-1))
            bkr1.append(dataframe['mkt_quan'].sum()*(-1))
            bkr1.append(dataframe['imb_quan'].sum())

            start_index = start_index + 10

        num_rows = 1
        num_cols = 2

        fig2 = make_subplots(rows=num_rows, 
                             cols=num_cols,
                             subplot_titles=('Unit Price Comparison', 'Quantity Comparison'))

        trace1 = go.Bar(name='VidyutVanika21', x=list_of_features, y=vv21, marker_color=color_book.get('VidyutVanika'), legendgroup = 1)
        trace2 = go.Bar(name='TUC_TAC', x=list_of_features, y=tuc_tac, marker_color=color_book.get('TUC_TAC'), legendgroup = 1)
        trace3 = go.Bar(name='CrocodileAgent2021', x=list_of_features, y=croc, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 1)
        trace4 = go.Bar(name='IS3', x=list_of_features, y=is3, marker_color=color_book.get('IS3'), legendgroup = 1)
        trace5 = go.Bar(name='COLDPOWER2021', x=list_of_features, y=coldpower, marker_color=color_book.get('COLDPOWER'), legendgroup = 1)
        trace6 = go.Bar(name='UTA_PTA2021', x=list_of_features, y=uta_pta, marker_color=color_book.get('UTA_PTA'), legendgroup = 1)
        trace7 = go.Bar(name='Mertacor2021', x=list_of_features, y=mertacor, marker_color=color_book.get('Mertacor'), legendgroup = 1)

        trace1_1 = go.Bar(name='VidyutVanika21', x=list_of_features1, y=vv21_1, marker_color=color_book.get('VidyutVanika'), legendgroup = 2, showlegend=False)
        trace2_1 = go.Bar(name='TUC_TAC', x=list_of_features1, y=tuc_tac_1, marker_color=color_book.get('TUC_TAC'), legendgroup = 2, showlegend=False)
        trace3_1 = go.Bar(name='CrocodileAgent2021', x=list_of_features1, y=croc_1, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 2, showlegend=False)
        trace4_1 = go.Bar(name='IS3', x=list_of_features1, y=is3_1, marker_color=color_book.get('IS3'), legendgroup = 2, showlegend=False)
        trace5_1 = go.Bar(name='COLDPOWER2021', x=list_of_features1, y=coldpower_1, marker_color=color_book.get('COLDPOWER'), legendgroup = 2, showlegend=False)
        trace6_1 = go.Bar(name='UTA_PTA2021', x=list_of_features1, y=uta_pta_1, marker_color=color_book.get('UTA_PTA'), legendgroup = 2, showlegend=False)
        trace7_1 = go.Bar(name='Mertacor2021', x=list_of_features1, y=mertacor_1, marker_color=color_book.get('Mertacor'), legendgroup = 2, showlegend=False)

        fig2.append_trace(trace1, row = 1, col = 1)
        fig2.append_trace(trace2, row = 1, col = 1)
        fig2.append_trace(trace3, row = 1, col = 1)
        fig2.append_trace(trace4, row = 1, col = 1)
        fig2.append_trace(trace5, row = 1, col = 1)
        fig2.append_trace(trace6, row = 1, col = 1)
        fig2.append_trace(trace7, row = 1, col = 1)

        fig2.append_trace(trace1_1, row = 1, col = 2)
        fig2.append_trace(trace2_1, row = 1, col = 2)
        fig2.append_trace(trace3_1, row = 1, col = 2)
        fig2.append_trace(trace4_1, row = 1, col = 2)
        fig2.append_trace(trace5_1, row = 1, col = 2)
        fig2.append_trace(trace6_1, row = 1, col = 2)
        fig2.append_trace(trace7_1, row = 1, col = 2)

        fig2.update_yaxes(title_text='Price ($/MWh)', row = 1, col = 1)
        fig2.update_yaxes(title_text='Quantity', row = 1, col = 2)
        fig2.update_traces(marker_line_color='black', marker_line_width=1.0)
        fig2.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title='Accounting Information for Game-Size ' + str(game_size),
                template='ggplot2',
                font=dict(size=24))

        fig2.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallAnalysisExtra_'+ str(game_size) + '.html')

####################################################################################################################

def overall_analysis_extra_plotting_weather():
    
    number_of_brokers = 7

    filename = '/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_data/OverallAnalysisExtra.csv'
    broker_accounting = pd.read_csv(filename)
    
    weather_locations = ['denver', 'phoenix', 'minneapolis']
    
    broker_accounting_groupby = broker_accounting.groupby('Weather_Location')
    
    for location in weather_locations:
        
        broker_accounting_groupby_location = broker_accounting_groupby.get_group(location)
        list_of_brokers = list()
        list_of_features = ['Consumption', 'Production', 'Wholesale', 'Imbalance']
        list_of_features1 = ['Consumption', 'Production', 'Wholesale', 'Imbalance']
        
        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_location[col_broker].unique()[0]
            list_of_brokers.append(broker_name)

        columns = broker_accounting_groupby_location.iloc[:, 4:14].columns.tolist()
        
        start_index = 4
    
        vv21 = list()
        tuc_tac = list()
        croc = list()
        is3 = list()
        coldpower = list()
        uta_pta = list()
        mertacor = list()

        vv21_1 = list()
        tuc_tac_1 = list()
        croc_1 = list()
        is3_1 = list()
        coldpower_1 = list()
        uta_pta_1 = list()
        mertacor_1 = list()

        broker_map = {'VidyutVanika': vv21, 'TUC_TAC': tuc_tac, 'CrocodileAgent2020': croc, 'IS3': is3,
                      'COLDPOWER2021': coldpower, 'UTA_PTA2021': uta_pta, 'Mertacor2021': mertacor}

        broker_map1 = {'VidyutVanika': vv21_1, 'TUC_TAC': tuc_tac_1, 'CrocodileAgent2020': croc_1, 'IS3': is3_1,
                      'COLDPOWER2021': coldpower_1, 'UTA_PTA2021': uta_pta_1, 'Mertacor2021': mertacor_1}

        for ind in range(number_of_brokers):

            col_broker = 'broker' + str(ind)
            broker_name = broker_accounting_groupby_location[col_broker].unique()[0]

            dataframe = broker_accounting_groupby_location.iloc[:, start_index:(start_index+10)]
            dataframe.columns = columns

            bkr = broker_map.get(broker_name)

            bkr.append(dataframe['unit_con_price'].mean())
            bkr.append(dataframe['unit_pro_price'].mean())
            bkr.append(dataframe['unit_mkt_price'].mean())
            bkr.append(dataframe['unit_imb_price'].mean())

            bkr1 = broker_map1.get(broker_name)

            bkr1.append(dataframe['con_quan'].sum()*(-1))
            bkr1.append(dataframe['pro_quan'].sum()*(-1))
            bkr1.append(dataframe['mkt_quan'].sum()*(-1))
            bkr1.append(dataframe['imb_quan'].sum())

            start_index = start_index + 10

        num_rows = 1
        num_cols = 2

        fig2 = make_subplots(rows=num_rows, 
                             cols=num_cols,
                             vertical_spacing=0.5,
                             subplot_titles=('Unit Price Comparison', 'Quantity Comparison'))

        trace1 = go.Bar(name='AIB', x=list_of_features, y=vv21, marker_color=color_book.get('VidyutVanika'), legendgroup = 1)
        trace2 = go.Bar(name='TB1', x=list_of_features, y=tuc_tac, marker_color=color_book.get('TUC_TAC'), legendgroup = 1)
        trace3 = go.Bar(name='TB2', x=list_of_features, y=croc, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 1)
        trace4 = go.Bar(name='TB3', x=list_of_features, y=is3, marker_color=color_book.get('IS3'), legendgroup = 1)
        trace5 = go.Bar(name='TB4', x=list_of_features, y=coldpower, marker_color=color_book.get('COLDPOWER'), legendgroup = 1)
        trace6 = go.Bar(name='TB5', x=list_of_features, y=uta_pta, marker_color=color_book.get('UTA_PTA'), legendgroup = 1)
        trace7 = go.Bar(name='TB6', x=list_of_features, y=mertacor, marker_color=color_book.get('Mertacor'), legendgroup = 1)

        trace1_1 = go.Bar(name='AIB', x=list_of_features1, y=vv21_1, marker_color=color_book.get('VidyutVanika'), legendgroup = 2, showlegend=False)
        trace2_1 = go.Bar(name='TB1', x=list_of_features1, y=tuc_tac_1, marker_color=color_book.get('TUC_TAC'), legendgroup = 2, showlegend=False)
        trace3_1 = go.Bar(name='TB2', x=list_of_features1, y=croc_1, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 2, showlegend=False)
        trace4_1 = go.Bar(name='TB3', x=list_of_features1, y=is3_1, marker_color=color_book.get('IS3'), legendgroup = 2, showlegend=False)
        trace5_1 = go.Bar(name='TB4', x=list_of_features1, y=coldpower_1, marker_color=color_book.get('COLDPOWER'), legendgroup = 2, showlegend=False)
        trace6_1 = go.Bar(name='TB5', x=list_of_features1, y=uta_pta_1, marker_color=color_book.get('UTA_PTA'), legendgroup = 2, showlegend=False)
        trace7_1 = go.Bar(name='TB6', x=list_of_features1, y=mertacor_1, marker_color=color_book.get('Mertacor'), legendgroup = 2, showlegend=False)

        fig2.append_trace(trace1, row = 1, col = 1)
        fig2.append_trace(trace2, row = 1, col = 1)
        fig2.append_trace(trace3, row = 1, col = 1)
        fig2.append_trace(trace4, row = 1, col = 1)
        fig2.append_trace(trace5, row = 1, col = 1)
        fig2.append_trace(trace6, row = 1, col = 1)
        fig2.append_trace(trace7, row = 1, col = 1)

        fig2.append_trace(trace1_1, row = 1, col = 2)
        fig2.append_trace(trace2_1, row = 1, col = 2)
        fig2.append_trace(trace3_1, row = 1, col = 2)
        fig2.append_trace(trace4_1, row = 1, col = 2)
        fig2.append_trace(trace5_1, row = 1, col = 2)
        fig2.append_trace(trace6_1, row = 1, col = 2)
        fig2.append_trace(trace7_1, row = 1, col = 2)

        fig2.update_yaxes(title_text='Price ($/MWh)', row = 1, col = 1)
        fig2.update_yaxes(title_text='Quantity (MWh)', row = 1, col = 2)
        fig2.update_traces(marker_line_color='black', marker_line_width=1.0)
        fig2.update_annotations(font_size=22)
        fig2.update_layout(
                height=750, 
                width=1550, 
                barmode='group',
                title='Accounting Information for ' + location,
                template='ggplot2',
                font=dict(size=22))

        fig2.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallAnalysisExtra_'+ location + '.html')

   
    weather_locations = ['denver', 'phoenix', 'minneapolis']
    
    broker_accounting_groupby = broker_accounting.groupby('Weather_Location')
            
    broker_accounting_groupby_location1 = broker_accounting_groupby.get_group('denver')
    broker_accounting_groupby_location2 = broker_accounting_groupby.get_group('minneapolis')
    broker_accounting_groupby_location = pd.concat([broker_accounting_groupby_location1, broker_accounting_groupby_location2])
    list_of_brokers = list()

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting_groupby_location[col_broker].unique()[0]
        list_of_brokers.append(broker_name)

    columns = broker_accounting_groupby_location.iloc[:, 4:14].columns.tolist()
    
    start_index = 4
    
    vv21 = list()
    tuc_tac = list()
    croc = list()
    is3 = list()
    coldpower = list()
    uta_pta = list()
    mertacor = list()

    vv21_1 = list()
    tuc_tac_1 = list()
    croc_1 = list()
    is3_1 = list()
    coldpower_1 = list()
    uta_pta_1 = list()
    mertacor_1 = list()

    broker_map = {'VidyutVanika': vv21, 'TUC_TAC': tuc_tac, 'CrocodileAgent2020': croc, 'IS3': is3,
                  'COLDPOWER2021': coldpower, 'UTA_PTA2021': uta_pta, 'Mertacor2021': mertacor}

    broker_map1 = {'VidyutVanika': vv21_1, 'TUC_TAC': tuc_tac_1, 'CrocodileAgent2020': croc_1, 'IS3': is3_1,
                  'COLDPOWER2021': coldpower_1, 'UTA_PTA2021': uta_pta_1, 'Mertacor2021': mertacor_1}

    for ind in range(number_of_brokers):

        col_broker = 'broker' + str(ind)
        broker_name = broker_accounting_groupby_location[col_broker].unique()[0]

        dataframe = broker_accounting_groupby_location.iloc[:, start_index:(start_index+10)]
        dataframe.columns = columns

        bkr = broker_map.get(broker_name)

        bkr.append(dataframe['unit_con_price'].mean())
        bkr.append(dataframe['unit_pro_price'].mean())
        bkr.append(dataframe['unit_mkt_price'].mean())
        bkr.append(dataframe['unit_imb_price'].mean())

        bkr1 = broker_map1.get(broker_name)

        bkr1.append(dataframe['con_quan'].sum()*(-1))
        bkr1.append(dataframe['pro_quan'].sum()*(-1))
        bkr1.append(dataframe['mkt_quan'].sum()*(-1))
        bkr1.append(dataframe['imb_quan'].sum())

        start_index = start_index + 10

    num_rows = 1
    num_cols = 2

    fig2 = make_subplots(rows=num_rows, 
                         cols=num_cols,
                         subplot_titles=('Unit Price Comparison', 'Quantity Comparison'))

    trace1 = go.Bar(name='AIB', x=list_of_features, y=vv21, marker_color=color_book.get('VidyutVanika'), legendgroup = 1)
    trace2 = go.Bar(name='TB1', x=list_of_features, y=tuc_tac, marker_color=color_book.get('TUC_TAC'), legendgroup = 1)
    trace3 = go.Bar(name='TB2', x=list_of_features, y=croc, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 1)
    trace4 = go.Bar(name='TB3', x=list_of_features, y=is3, marker_color=color_book.get('IS3'), legendgroup = 1)
    trace5 = go.Bar(name='TB4', x=list_of_features, y=coldpower, marker_color=color_book.get('COLDPOWER'), legendgroup = 1)
    trace6 = go.Bar(name='TB5', x=list_of_features, y=uta_pta, marker_color=color_book.get('UTA_PTA'), legendgroup = 1)
    trace7 = go.Bar(name='TB6', x=list_of_features, y=mertacor, marker_color=color_book.get('Mertacor'), legendgroup = 1)

    trace1_1 = go.Bar(name='AIB', x=list_of_features1, y=vv21_1, marker_color=color_book.get('VidyutVanika'), legendgroup = 2, showlegend=False)
    trace2_1 = go.Bar(name='TB1', x=list_of_features1, y=tuc_tac_1, marker_color=color_book.get('TUC_TAC'), legendgroup = 2, showlegend=False)
    trace3_1 = go.Bar(name='TB2', x=list_of_features1, y=croc_1, marker_color=color_book.get('CrocodileAgent2020'), legendgroup = 2, showlegend=False)
    trace4_1 = go.Bar(name='TB3', x=list_of_features1, y=is3_1, marker_color=color_book.get('IS3'), legendgroup = 2, showlegend=False)
    trace5_1 = go.Bar(name='TB4', x=list_of_features1, y=coldpower_1, marker_color=color_book.get('COLDPOWER'), legendgroup = 2, showlegend=False)
    trace6_1 = go.Bar(name='TB5', x=list_of_features1, y=uta_pta_1, marker_color=color_book.get('UTA_PTA'), legendgroup = 2, showlegend=False)
    trace7_1 = go.Bar(name='TB6', x=list_of_features1, y=mertacor_1, marker_color=color_book.get('Mertacor'), legendgroup = 2, showlegend=False)

    fig2.append_trace(trace1, row = 1, col = 1)
    fig2.append_trace(trace2, row = 1, col = 1)
    fig2.append_trace(trace3, row = 1, col = 1)
    fig2.append_trace(trace4, row = 1, col = 1)
    fig2.append_trace(trace5, row = 1, col = 1)
    fig2.append_trace(trace6, row = 1, col = 1)
    fig2.append_trace(trace7, row = 1, col = 1)

    fig2.append_trace(trace1_1, row = 1, col = 2)
    fig2.append_trace(trace2_1, row = 1, col = 2)
    fig2.append_trace(trace3_1, row = 1, col = 2)
    fig2.append_trace(trace4_1, row = 1, col = 2)
    fig2.append_trace(trace5_1, row = 1, col = 2)
    fig2.append_trace(trace6_1, row = 1, col = 2)
    fig2.append_trace(trace7_1, row = 1, col = 2)

    fig2.update_yaxes(title_text='Price ($/MWh)', row = 1, col = 1)
    fig2.update_yaxes(title_text='Quantity (MWh)', row = 1, col = 2)
    fig2.update_traces(marker_line_color='black', marker_line_width=1.0)
    fig2.update_annotations(font_size=22)
    fig2.update_layout(
            height=750, 
            width=1550, 
            barmode='group',
            title='Accounting Information for Regular Games',
            template='ggplot2',
            font=dict(size=22))

    fig2.write_html('/mnt/d/PowerTAC/PowerTAC2021/finals_2021_analysis/advance_tournament_analysis_plots/OverallAnalysisExtra_Regular.html')

####################################################################################################################

overall_analysis_extra_plotting()
# overall_analysis_extra_plotting_game_size()
# overall_analysis_extra_plotting_weather()
